# %%
# Fast Code Repository Search using Ripgrep
import subprocess
import re
import os
import pandas as pd
from IPython.display import display
import time

# Configuration - MODIFY THESE VARIABLES
REPO_PATH = r"C:\python\erpnext"  # Change this to your repository path, e.g., "/home/user/erpnext"
SEARCH_TERM = "Task"  # Change to your search term

# Optional filters
FILE_PATTERN = "*.py"  # Set to None or "" for all files, or specify pattern like "*.py"
CASE_SENSITIVE = False  # Set to True for case-sensitive search

def search_with_ripgrep(repo_path, search_term, file_pattern=None, case_sensitive=False):
    """Use ripgrep to search for a term and return ranked results."""
    # Change to the repository directory
    original_dir = os.getcwd()
    os.chdir(repo_path)
    
    try:
        # Build ripgrep command
        cmd = ["rg", "--count"]
        
        # Add case insensitive flag if needed
        if not case_sensitive:
            cmd.append("-i")
        
        # Add file pattern if specified
        if file_pattern:
            cmd.extend(["-g", file_pattern])
        
        # Add search term and other options
        cmd.extend([search_term, "."])
        
        # Start time measurement
        start_time = time.time()
        
        # Execute ripgrep command
        result = subprocess.run(cmd, capture_output=True, text=True)
        
        # Calculate search time
        search_time = time.time() - start_time
        
        # Parse results
        results = []
        if result.returncode not in [0, 1]:  # 0: matches found, 1: no matches found
            raise Exception(f"Ripgrep error: {result.stderr}")
        
        # Process stdout lines to get file paths and counts
        for line in result.stdout.strip().split('\n'):
            if line:  # Skip empty lines
                # Format is: path/to/file:count
                parts = line.rsplit(':', 1)  # Split on last colon
                if len(parts) == 2:
                    file_path, count_str = parts
                    try:
                        count = int(count_str)
                        results.append((file_path, count))
                    except ValueError:
                        print(f"Warning: Couldn't parse count from {line}")
        
        # Sort by count (descending)
        results.sort(key=lambda x: x[1], reverse=True)
        
        return results, search_time
        
    finally:
        # Restore original directory
        os.chdir(original_dir)

# Check if ripgrep is installed
try:
    subprocess.run(["rg", "--version"], capture_output=True)
    print("✅ Ripgrep detected!")
except FileNotFoundError:
    print("❌ Ripgrep not found! Please install it: https://github.com/BurntSushi/ripgrep#installation")
    raise SystemExit("Ripgrep is required for this script.")

# Check if repository path exists
if not os.path.exists(REPO_PATH):
    print(f"❌ Repository path '{REPO_PATH}' does not exist. Please update the REPO_PATH variable.")
else:
    print(f"✅ Repository path: {REPO_PATH}")

# Execute the search
print(f"🔍 Searching for '{SEARCH_TERM}' in {FILE_PATTERN or 'all files'}...")
results, search_time = search_with_ripgrep(REPO_PATH, SEARCH_TERM, FILE_PATTERN, CASE_SENSITIVE)

# Display results
print(f"\n✨ Found {len(results)} files containing '{SEARCH_TERM}' in {search_time:.2f} seconds")
if results:
    print("\nRanked results (format: path/to/file count):")
    for file_path, count in results:
        print(f"{file_path} {count}")
    
    # Create DataFrame for interactive filtering (optional - requires pandas)
    df = pd.DataFrame(results, columns=['File Path', 'Occurrences'])
    print("\nDataFrame representation:")
    print(df)
else:
    print("No results found.")
# Out:
# ✅ Ripgrep detected!
# ✅ Repository path: C:\python\erpnext
# 🔍 Searching for 'Task' in *.py...
#
# ✨ Found 57 files containing 'Task' in 0.25 seconds
#
# Ranked results (format: path/to/file count):
# .\erpnext\projects\doctype\project\test_project.py 106
# .\erpnext\projects\doctype\task\task.py 99
# .\erpnext\projects\doctype\project\project.py 77
# .\erpnext\projects\doctype\task\test_task.py 63
# .\erpnext\setup\doctype\transaction_deletion_record\transaction_deletion_record.py 45
# .\erpnext\assets\doctype\asset_maintenance\asset_maintenance.py 36
# .\erpnext\patches\v13_0\update_project_template_tasks.py 21
# .\erpnext\projects\report\project_summary\project_summary.py 19
# .\erpnext\projects\report\delayed_tasks_summary\delayed_tasks_summary.py 18
# .\erpnext\templates\pages\projects.py 16
# .\erpnext\projects\report\delayed_tasks_summary\test_delayed_tasks_summary.py 15
# .\erpnext\projects\doctype\project_template\project_template.py 15
# .\erpnext\projects\doctype\timesheet\timesheet.py 13
# .\erpnext\projects\doctype\timesheet_detail\timesheet_detail.py 11
# .\erpnext\assets\doctype\asset_maintenance_log\asset_maintenance_log.py 10
# .\erpnext\projects\doctype\project_template\test_project_template.py 9
# .\erpnext\setup\doctype\transaction_deletion_record\test_transaction_deletion_record.py 9
# .\erpnext\config\projects.py 7
# .\erpnext\assets\doctype\asset_maintenance\test_asset_maintenance.py 7
# .\erpnext\patches\v15_0\update_task_assignee_email_field_in_asset_maintenance_log.py 6
# .\erpnext\setup\setup_wizard\setup_wizard.py 5
# .\erpnext\utilities\bulk_transaction.py 5
# .\erpnext\hooks.py 4
# .\erpnext\crm\utils.py 3
# .\erpnext\projects\utils.py 3
# .\erpnext\templates\pages\task_info.py 3
# .\erpnext\patches\v12_0\set_task_status.py 3
# .\erpnext\patches\v12_0\fix_percent_complete_for_projects.py 3
# .\erpnext\setup\default_energy_point_rules.py 2
# .\erpnext\crm\doctype\opportunity\opportunity.py 2
# .\erpnext\projects\report\daily_timesheet_summary\daily_timesheet_summary.py 2
# .\erpnext\projects\doctype\timesheet\test_timesheet.py 2
# .\erpnext\projects\doctype\task_depends_on\task_depends_on.py 2
# .\erpnext\projects\doctype\project_template_task\project_template_task.py 2
# .\erpnext\assets\doctype\asset_maintenance_task\asset_maintenance_task.py 2
# .\erpnext\projects\doctype\dependent_task\dependent_task.py 2
# .\erpnext\support\doctype\issue\issue.py 2
# .\erpnext\stock\doctype\stock_reconciliation\stock_reconciliation.py 2
# .\erpnext\patches\v11_0\refactor_autoname_naming.py 2
# .\erpnext\accounts\doctype\subscription\subscription.py 2
# .\erpnext\accounts\doctype\journal_entry\journal_entry.py 2
# .\erpnext\accounts\doctype\process_payment_reconciliation\process_payment_reconciliation.py 2
# .\erpnext\domains\services.py 1
# .\erpnext\domains\retail.py 1
# .\erpnext\domains\manufacturing.py 1
# .\erpnext\domains\distribution.py 1
# .\erpnext\setup\demo.py 1
# .\erpnext\utilities\activation.py 1
# .\erpnext\projects\doctype\task_type\test_task_type.py 1
# .\erpnext\projects\doctype\task_type\task_type.py 1
# .\erpnext\projects\doctype\task\task_dashboard.py 1
# .\erpnext\projects\doctype\project\project_dashboard.py 1
# .\erpnext\setup\doctype\company\company.py 1
# .\erpnext\assets\doctype\asset\asset.py 1
# .\erpnext\support\doctype\issue\issue_dashboard.py 1
# .\erpnext\startup\notifications.py 1
# .\erpnext\patches\v11_0\add_index_on_nestedset_doctypes.py 1
#
# DataFrame representation:
#                                             File Path  Occurrences
# 0   .\erpnext\projects\doctype\project\test_projec...          106
# 1             .\erpnext\projects\doctype\task\task.py           99
# 2       .\erpnext\projects\doctype\project\project.py           77
# 3        .\erpnext\projects\doctype\task\test_task.py           63
# 4   .\erpnext\setup\doctype\transaction_deletion_r...           45
# 5   .\erpnext\assets\doctype\asset_maintenance\ass...           36
# 6   .\erpnext\patches\v13_0\update_project_templat...           21
# 7   .\erpnext\projects\report\project_summary\proj...           19
# 8   .\erpnext\projects\report\delayed_tasks_summar...           18
# 9               .\erpnext\templates\pages\projects.py           16
# 10  .\erpnext\projects\report\delayed_tasks_summar...           15
# 11  .\erpnext\projects\doctype\project_template\pr...           15
# 12  .\erpnext\projects\doctype\timesheet\timesheet.py           13
# 13  .\erpnext\projects\doctype\timesheet_detail\ti...           11
# 14  .\erpnext\assets\doctype\asset_maintenance_log...           10
# 15  .\erpnext\projects\doctype\project_template\te...            9
# 16  .\erpnext\setup\doctype\transaction_deletion_r...            9
# 17                       .\erpnext\config\projects.py            7
# 18  .\erpnext\assets\doctype\asset_maintenance\tes...            7
# 19  .\erpnext\patches\v15_0\update_task_assignee_e...            6
# 20       .\erpnext\setup\setup_wizard\setup_wizard.py            5
# 21            .\erpnext\utilities\bulk_transaction.py            5
# 22                                 .\erpnext\hooks.py            4
# 23                             .\erpnext\crm\utils.py            3
# 24                        .\erpnext\projects\utils.py            3
# 25             .\erpnext\templates\pages\task_info.py            3
# 26         .\erpnext\patches\v12_0\set_task_status.py            3
# 27  .\erpnext\patches\v12_0\fix_percent_complete_f...            3
# 28      .\erpnext\setup\default_energy_point_rules.py            2
# 29   .\erpnext\crm\doctype\opportunity\opportunity.py            2
# 30  .\erpnext\projects\report\daily_timesheet_summ...            2
# 31  .\erpnext\projects\doctype\timesheet\test_time...            2
# 32  .\erpnext\projects\doctype\task_depends_on\tas...            2
# 33  .\erpnext\projects\doctype\project_template_ta...            2
# 34  .\erpnext\assets\doctype\asset_maintenance_tas...            2
# 35  .\erpnext\projects\doctype\dependent_task\depe...            2
# 36           .\erpnext\support\doctype\issue\issue.py            2
# 37  .\erpnext\stock\doctype\stock_reconciliation\s...            2
# 38  .\erpnext\patches\v11_0\refactor_autoname_nami...            2
# 39  .\erpnext\accounts\doctype\subscription\subscr...            2
# 40  .\erpnext\accounts\doctype\journal_entry\journ...            2
# 41  .\erpnext\accounts\doctype\process_payment_rec...            2
# 42                      .\erpnext\domains\services.py            1
# 43                        .\erpnext\domains\retail.py            1
# 44                 .\erpnext\domains\manufacturing.py            1
# 45                  .\erpnext\domains\distribution.py            1
# 46                            .\erpnext\setup\demo.py            1
# 47                  .\erpnext\utilities\activation.py            1
# 48  .\erpnext\projects\doctype\task_type\test_task...            1
# 49  .\erpnext\projects\doctype\task_type\task_type.py            1
# 50  .\erpnext\projects\doctype\task\task_dashboard.py            1
# 51  .\erpnext\projects\doctype\project\project_das...            1
# 52         .\erpnext\setup\doctype\company\company.py            1
# 53            .\erpnext\assets\doctype\asset\asset.py            1
# 54  .\erpnext\support\doctype\issue\issue_dashboar...            1
# 55                 .\erpnext\startup\notifications.py            1
# 56  .\erpnext\patches\v11_0\add_index_on_nestedset...            1
