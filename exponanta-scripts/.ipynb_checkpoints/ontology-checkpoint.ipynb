# %%
import sqlite3
import json

def load_tables(db_path):
    """Load all tables into a dict of {table_name: [rows as dicts]}"""
    conn = sqlite3.connect(db_path)
    conn.row_factory = sqlite3.Row
    cur = conn.cursor()

    tables = {}
    cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
    for (table_name,) in cur.fetchall():
        cur.execute(f"SELECT * FROM {table_name}")
        rows = [dict(r) for r in cur.fetchall()]
        tables[table_name] = rows

    conn.close()
    return tables

def build_tree(table_name, row, tables, fk_depth=0, child_depth=0, visited=None):
    """
    Build object tree with controlled depth expansion.

    - fk_depth: depth for foreign key expansion (limit = 1).
    - child_depth: depth for implicit parent-child expansion (limit = 3).
    - visited: set to prevent circular recursion.
    """
    if visited is None:
        visited = set()

    obj = dict(row)
    obj["_table"] = table_name  # keep schema info

    row_id = (table_name, row.get("name"))
    if row_id in visited:
        return obj
    visited.add(row_id)

    # -------------------------------
    # 1. Handle foreign key references (limit 1 level)
    # -------------------------------
    if fk_depth < 1:
        for field, value in row.items():
            if field.endswith("Name") and isinstance(value, str):
                ref_table = field[:-4]  # drop "Name" suffix
                if ref_table in tables:
                    ref_row = next((r for r in tables[ref_table] if r.get("name") == value), None)
                    if ref_row:
                        obj[field] = build_tree(
                            ref_table, ref_row, tables,
                            fk_depth=fk_depth + 1,
                            child_depth=child_depth,
                            visited=visited.copy()
                        )

    # -------------------------------
    # 2. Handle implicit children (limit 3 levels)
    # -------------------------------
    if child_depth < 3:
        for t_name, t_rows in tables.items():
            children = [
                build_tree(
                    t_name, child_row, tables,
                    fk_depth=0,  # reset FK depth for children
                    child_depth=child_depth + 1,
                    visited=visited.copy()
                )
                for child_row in t_rows
                if child_row.get("parentSchemaName") == table_name
                and child_row.get("parent") == row.get("name")
            ]
            if children:
                obj.setdefault(t_name, []).extend(children)

    return obj

def build_from_db(db_path, start_table, row_name=None):
    """Entry point: build tree for given table and optional row.name filter"""
    tables = load_tables(db_path)
    if start_table not in tables:
        raise ValueError(f"Table {start_table} not found in {db_path}")

    # pick row
    if row_name:
        row = next((r for r in tables[start_table] if r.get("name") == row_name), None)
        if not row:
            raise ValueError(f"Row with name={row_name} not found in {start_table}")
    else:
        row = tables[start_table][0]  # first row if not specified

    return build_tree(start_table, row, tables)

if __name__ == "__main__":
    db_path = "demo.db"
    start_table = "SalesInvoice"  # change this as needed
    row_name = None  # e.g. "INV-0001"

    tree = build_from_db(db_path, start_table, row_name)
    print(json.dumps(tree, indent=2))
# Out:
# {
#   "name": "SINV-1001",
#   "numberSeries": "SINV-",
#   "party": "Daniel",
#   "account": "Debtors",
#   "date": "2024-09-02T04:00:00.000Z",
#   "priceList": null,
#   "netTotal": "48367.00000000000",
#   "baseGrandTotal": "55183.42000000000",
#   "grandTotal": "55183.42000000000",
#   "setDiscountAmount": 0,
#   "discountAmount": "0.00000000000",
#   "discountPercent": 0.0,
#   "entryCurrency": "Party",
#   "currency": "INR",
#   "exchangeRate": 1.0,
#   "discountAfterTax": 0,
#   "makeAutoPayment": 0,
#   "makeAutoStockTransfer": 0,
#   "outstandingAmount": "0.00000000000",
#   "stockNotTransferred": 0.0,
#   "terms": "",
#   "attachment": null,
#   "isReturned": 0,
#   "isFullyReturned": 0,
#   "isSyncedWithErp": 0,
#   "backReference": null,
#   "returnAgainst": null,
#   "quote": null,
#   "loyaltyProgram": null,
#   "redeemLoyaltyPoints": 0,
#   "loyaltyPoints": 0,
#   "isPOS": 0,
#   "isPricingRuleApplied": 0,
#   "createdBy": "i771468@gmail.com",
#   "modifiedBy": "i771468@gmail.com",
#   "created": "2025-08-05T15:57:40.569Z",
#   "modified": "2025-08-05T15:58:20.012Z",
#   "submitted": 1,
#   "cancelled": 0,
#   "_table": "SalesInvoice",
#   "TaxSummary": [
#     {
#       "name": "4702gj-mdyq49ym",
#       "account": "CGST",
#       "from_account": null,
#       "rate": 6.0,
#       "amount": "3408.21000000000",
#       "idx": 0,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "taxes",
#       "_table": "TaxSummary"
#     },
#     {
#       "name": "1rugkv-mdyq49ym",
#       "account": "SGST",
#       "from_account": null,
#       "rate": 6.0,
#       "amount": "3408.21000000000",
#       "idx": 1,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "taxes",
#       "_table": "TaxSummary"
#     }
#   ],
#   "SalesInvoiceItem": [
#     {
#       "name": "yuzg3t-mdyq3dxl",
#       "item": "611 Jeans - PCH",
#       "itemCode": null,
#       "description": "Peach coloured 611s",
#       "rate": "10123.00000000000",
#       "transferUnit": "Unit",
#       "transferQuantity": 1.0,
#       "unit": "Unit",
#       "batch": null,
#       "quantity": 1.0,
#       "unitConversionFactor": 1.0,
#       "account": "Sales",
#       "tax": "GST-12",
#       "amount": "10123.00000000000",
#       "setItemDiscountAmount": 0,
#       "itemDiscountAmount": "0.00000000000",
#       "itemDiscountPercent": 0.0,
#       "hsnCode": 62034990,
#       "stockNotTransferred": 0.0,
#       "isFreeItem": 0,
#       "pricingRule": null,
#       "idx": 0,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "items",
#       "_table": "SalesInvoiceItem"
#     },
#     {
#       "name": "fyj9yn-mdyq3dxq",
#       "item": "Cryo Gloves",
#       "itemCode": null,
#       "description": "Keeps hands cool",
#       "rate": "7873.00000000000",
#       "transferUnit": "Unit",
#       "transferQuantity": 1.0,
#       "unit": "Unit",
#       "batch": null,
#       "quantity": 1.0,
#       "unitConversionFactor": 1.0,
#       "account": "Sales",
#       "tax": "GST-18",
#       "amount": "7873.00000000000",
#       "setItemDiscountAmount": 0,
#       "itemDiscountAmount": "0.00000000000",
#       "itemDiscountPercent": 0.0,
#       "hsnCode": 611693,
#       "stockNotTransferred": 0.0,
#       "isFreeItem": 0,
#       "pricingRule": null,
#       "idx": 1,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "items",
#       "_table": "SalesInvoiceItem"
#     },
#     {
#       "name": "2lx72a-mdyq3dxx",
#       "item": "Full Sleeve - COL",
#       "itemCode": null,
#       "description": "All color sleeved",
#       "rate": "1123.00000000000",
#       "transferUnit": "Unit",
#       "transferQuantity": 1.0,
#       "unit": "Unit",
#       "batch": null,
#       "quantity": 1.0,
#       "unitConversionFactor": 1.0,
#       "account": "Sales",
#       "tax": "GST-12",
#       "amount": "1123.00000000000",
#       "setItemDiscountAmount": 0,
#       "itemDiscountAmount": "0.00000000000",
#       "itemDiscountPercent": 0.0,
#       "hsnCode": 100820,
#       "stockNotTransferred": 0.0,
#       "isFreeItem": 0,
#       "pricingRule": null,
#       "idx": 2,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "items",
#       "_table": "SalesInvoiceItem"
#     },
#     {
#       "name": "zpnunn-mdyq3dy4",
#       "item": "Jacket - RAW",
#       "itemCode": null,
#       "description": "Raw baby skinned jackets",
#       "rate": "20248.00000000000",
#       "transferUnit": "Unit",
#       "transferQuantity": 1.0,
#       "unit": "Unit",
#       "batch": null,
#       "quantity": 1.0,
#       "unitConversionFactor": 1.0,
#       "account": "Sales",
#       "tax": "GST-12",
#       "amount": "20248.00000000000",
#       "setItemDiscountAmount": 0,
#       "itemDiscountAmount": "0.00000000000",
#       "itemDiscountPercent": 0.0,
#       "hsnCode": 100820,
#       "stockNotTransferred": 0.0,
#       "isFreeItem": 0,
#       "pricingRule": null,
#       "idx": 3,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "items",
#       "_table": "SalesInvoiceItem"
#     },
#     {
#       "name": "hwq53x-mdyq3dyd",
#       "item": "Cool Cloth",
#       "itemCode": null,
#       "description": "Some real \ud83c\udd92 cloth",
#       "rate": "9000.00000000000",
#       "transferUnit": "Meter",
#       "transferQuantity": 1.0,
#       "unit": "Meter",
#       "batch": null,
#       "quantity": 1.0,
#       "unitConversionFactor": 1.0,
#       "account": "Sales",
#       "tax": "GST-18",
#       "amount": "9000.00000000000",
#       "setItemDiscountAmount": 0,
#       "itemDiscountAmount": "0.00000000000",
#       "itemDiscountPercent": 0.0,
#       "hsnCode": 59111000,
#       "stockNotTransferred": 0.0,
#       "isFreeItem": 0,
#       "pricingRule": null,
#       "idx": 4,
#       "parent": "SINV-1001",
#       "parentSchemaName": "SalesInvoice",
#       "parentFieldname": "items",
#       "_table": "SalesInvoiceItem"
#     }
#   ]
# }

# %%
import sqlite3

conn = sqlite3.connect("demo.db")
cur = conn.cursor()

cur.execute("PRAGMA foreign_key_list('SalesInvoice')")
fks = cur.fetchall()
for fk in fks:
    print(fk)

conn.close()
# Out:
# (0, 0, 'LoyaltyProgram', 'loyaltyProgram', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (1, 0, 'SalesQuote', 'quote', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (2, 0, 'SalesInvoice', 'returnAgainst', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (3, 0, 'Shipment', 'backReference', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (4, 0, 'Currency', 'currency', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (5, 0, 'PriceList', 'priceList', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (6, 0, 'Account', 'account', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (7, 0, 'Party', 'party', 'name', 'CASCADE', 'RESTRICT', 'NONE')
# (8, 0, 'NumberSeries', 'numberSeries', 'name', 'CASCADE', 'RESTRICT', 'NONE')

# %%
import sqlite3
import json

# -----------------------------
# Step 1: Load all tables
# -----------------------------
def load_tables(db_path):
    conn = sqlite3.connect(db_path)
    conn.row_factory = sqlite3.Row
    cur = conn.cursor()

    tables = {}
    cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
    for (table_name,) in cur.fetchall():
        cur.execute(f"SELECT * FROM {table_name}")
        tables[table_name] = [dict(r) for r in cur.fetchall()]

    conn.close()
    return tables

# -----------------------------
# Step 2: Get PKs and explicit FKs
# -----------------------------
def get_primary_keys(conn, table):
    cur = conn.cursor()
    cur.execute(f"PRAGMA table_info('{table}')")
    return [col[1] for col in cur.fetchall() if col[5] > 0]

def get_foreign_keys(conn, table):
    cur = conn.cursor()
    cur.execute(f"PRAGMA foreign_key_list('{table}')")
    fks = []
    for fk in cur.fetchall():
        fks.append({
            "from": fk[3],       # column in this table
            "to_table": fk[2],   # referenced table
            "to_column": fk[4],  # referenced column
            "on_update": fk[5],
            "on_delete": fk[6]
        })
    return fks

# -----------------------------
# Step 3: Build nodes and edges
# -----------------------------
def build_ontology(db_path):
    conn = sqlite3.connect(db_path)
    conn.row_factory = sqlite3.Row
    tables = load_tables(db_path)

    nodes = {}
    edges = []

    # Nodes: each row is a node
    for t_name, rows in tables.items():
        pk_cols = get_primary_keys(conn, t_name)
        fks = get_foreign_keys(conn, t_name)
        for row in rows:
            node_id = f"{t_name}:{row.get('name')}"  # simple unique ID using name
            nodes[node_id] = {
                "id": node_id,
                "type": t_name,
                "pk": pk_cols,
                "attributes": row
            }

            # 1. Explicit FKs
            for fk in fks:
                fk_value = row.get(fk["from"])
                if fk_value is not None:
                    target_id = f"{fk['to_table']}:{fk_value}"
                    edges.append({
                        "from": node_id,
                        "to": target_id,
                        "type": "explicit_fk",
                        "on_update": fk["on_update"],
                        "on_delete": fk["on_delete"]
                    })

            # 2. Implicit FKs via *_Name or *_Id
            for col, val in row.items():
                if isinstance(val, str):
                    # simple heuristic
                    if col.endswith("Name") and col[:-4] in tables:
                        target_id = f"{col[:-4]}:{val}"
                        edges.append({
                            "from": node_id,
                            "to": target_id,
                            "type": "implicit_fk"
                        })
                    elif col.endswith("Id") and col[:-2] in tables:
                        target_id = f"{col[:-2]}:{val}"
                        edges.append({
                            "from": node_id,
                            "to": target_id,
                            "type": "implicit_fk"
                        })

            # 3. ERP parent-child relationship
            parent_table = row.get("parentSchemaName")
            parent_id = row.get("parent")
            if parent_table and parent_id:
                target_id = f"{parent_table}:{parent_id}"
                edges.append({
                    "from": node_id,
                    "to": target_id,
                    "type": "parent_child"
                })

    conn.close()
    ontology = {
        "nodes": list(nodes.values()),
        "edges": edges
    }
    return ontology

# -----------------------------
# Step 4: Save ontology as JSON
# -----------------------------
if __name__ == "__main__":
    db_path = "demo.db"
    ontology = build_ontology(db_path)
    with open("ontology.json", "w") as f:
        json.dump(ontology, f, indent=2)
    print("Ontology saved as ontology.json")
