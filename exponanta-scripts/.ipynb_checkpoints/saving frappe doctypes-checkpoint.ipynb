# %%
import os
import json
from pathlib import Path

# Configuration
BASE_DIR = Path(r"C:\python\erpnext\erpnext")  # Base folder to crawl
OUTPUT_FILE = "erpnext_doctype_tree.json"

def crawl_json_files(base_dir):
    """Find all doctype JSON files"""
    json_files = []
    base_path = Path(base_dir)
    
    for json_file in base_path.rglob("*.json"):
        try:
            # Skip non-doctype directories
            if any(skip in str(json_file) for skip in [
                'node_modules', '.git', '__pycache__', 'builds', 'logs', 'public', 'assets'
            ]):
                continue
                
            with open(json_file, "r", encoding="utf-8") as f:
                data = json.load(f)
                
            if data.get("doctype") == "DocType" and data.get("name"):
                json_files.append({
                    "name": data.get("name"),
                    "file": str(json_file),
                    "data": data
                })
        except:
            continue
    
    return json_files

def find_true_children(parent_name, all_doctypes):
    """Find only TRUE children - Table fields and parent field references"""
    children = []
    
    # Find parent data
    parent_data = None
    for dt in all_doctypes:
        if dt["name"] == parent_name:
            parent_data = dt["data"]
            break
    
    if not parent_data:
        return children
    
    # 1. Table fields in parent -> true children
    for field in parent_data.get("fields", []):
        if field.get("fieldtype") == "Table" and field.get("options"):
            child_name = field["options"]
            
            # Find child doctype
            for dt in all_doctypes:
                if dt["name"] == child_name:
                    children.append({
                        "name": child_name,
                        "file": dt["file"],
                        "type": "table_child",
                        "field": field.get("fieldname"),
                        "children": find_true_children(child_name, all_doctypes)
                    })
                    break
    
    # 2. Find doctypes that have "parent" field pointing to this parent
    for dt in all_doctypes:
        for field in dt["data"].get("fields", []):
            if (field.get("fieldname") == "parent" and 
                field.get("options") == parent_name):
                
                children.append({
                    "name": dt["name"],
                    "file": dt["file"],
                    "type": "parent_child",
                    "field": "parent",
                    "children": find_true_children(dt["name"], all_doctypes)
                })
                break
    
    # 3. Find doctypes with naming pattern suggesting parent-child (like "User Group Member" -> "User Group")
    for dt in all_doctypes:
        dt_name = dt["name"]
        # Skip if already processed or is the parent itself
        if any(child["name"] == dt_name for child in children) or dt_name == parent_name:
            continue
            
        # Check if child name contains parent name and has a Link field to parent
        if parent_name in dt_name and dt_name != parent_name:
            for field in dt["data"].get("fields", []):
                if (field.get("fieldtype") == "Link" and 
                    field.get("options") == parent_name):
                    
                    children.append({
                        "name": dt_name,
                        "file": dt["file"],
                        "type": "named_child",
                        "field": field.get("fieldname"),
                        "children": find_true_children(dt_name, all_doctypes)
                    })
                    break
    
    # 4. Add lookups at the end (Link fields from this parent to other doctypes)
    for field in parent_data.get("fields", []):
        if field.get("fieldtype") == "Link" and field.get("options"):
            lookup_name = field["options"]
            
            # Skip if already added as a true child
            if any(child["name"] == lookup_name for child in children):
                continue
            
            # Verify lookup doctype exists
            for dt in all_doctypes:
                if dt["name"] == lookup_name:
                    children.append({
                        "name": lookup_name,
                        "file": dt["file"],
                        "type": "lookup",
                        "field": field.get("fieldname"),
                        "children": []
                    })
                    break
    
    return children

def find_root_doctypes(all_doctypes):
    """Find root doctypes - those not referenced as true children"""
    all_names = {dt["name"] for dt in all_doctypes}
    true_children = set()
    
    for dt in all_doctypes:
        # Table field options are true children
        for field in dt["data"].get("fields", []):
            if field.get("fieldtype") == "Table" and field.get("options"):
                true_children.add(field["options"])
        
        # Doctypes with "parent" field are true children
        for field in dt["data"].get("fields", []):
            if field.get("fieldname") == "parent" and field.get("options"):
                true_children.add(dt["name"])
                break
    
    # Also check for naming pattern children (like "User Group Member" -> "User Group")
    for dt in all_doctypes:
        dt_name = dt["name"]
        for other_dt in all_doctypes:
            other_name = other_dt["name"]
            # If this doctype's name contains another doctype's name
            if other_name in dt_name and dt_name != other_name:
                # And has a Link field to that doctype
                for field in dt["data"].get("fields", []):
                    if (field.get("fieldtype") == "Link" and 
                        field.get("options") == other_name):
                        true_children.add(dt_name)
                        break
    
    return all_names - true_children

def build_tree(all_doctypes):
    """Build the tree structure"""
    root_names = find_root_doctypes(all_doctypes)
    tree = []
    
    print(f"Found {len(root_names)} root doctypes: {sorted(list(root_names))}")
    
    for dt in all_doctypes:
        if dt["name"] in root_names:
            children = find_true_children(dt["name"], all_doctypes)
            
            tree.append({
                "name": dt["name"],
                "file": dt["file"],
                "type": "root",
                "module": dt["data"].get("module"),
                "children": children
            })
    
    return tree

def print_tree(tree, indent=0):
    """Print tree structure"""
    for node in tree:
        prefix = "  " * indent
        type_info = f" [{node['type']}]"
        if node.get('field') and node['type'] != 'root':
            type_info += f" (field: {node['field']})"
        
        print(f"{prefix}{node['name']}{type_info}")
        if node.get("children"):
            print_tree(node["children"], indent + 1)

# Main execution
if __name__ == "__main__":
    print("Starting Frappe DocType crawler...")
    
    # Get all doctypes
    all_doctypes = crawl_json_files(BASE_DIR)
    print(f"Found {len(all_doctypes)} doctype files")
    
    if not all_doctypes:
        print("No doctype files found. Check BASE_DIR path.")
        exit(1)
    
    # Build tree
    tree = build_tree(all_doctypes)
    
    # Save to JSON
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(tree, f, indent=2, ensure_ascii=False)
    
    print(f"\nTree saved to {OUTPUT_FILE}")
    print("\nTree structure:")
    print_tree(tree)
# Out:
# Starting Frappe DocType crawler...
# Found 468 doctype files
# Found 241 root doctypes: ['Account', 'Accounting Dimension', 'Accounting Dimension Filter', 'Accounting Period', 'Accounts Settings', 'Activity Cost', 'Activity Type', 'Advance Payment Ledger Entry', 'Appointment', 'Appointment Booking Settings', 'Authorization Control', 'Authorization Rule', 'Availability Of Slots', 'BOM', 'BOM Creator', 'Bank', 'Bank Account Subtype', 'Bank Account Type', 'Bank Clearance', 'Bank Reconciliation Tool', 'Bank Transaction', 'Batch', 'Bin', 'Bisect Accounting Statements', 'Bisect Nodes', 'Blanket Order', 'Branch', 'Brand', 'Budget', 'Bulk Transaction Log', 'Bulk Transaction Log Detail', 'Buying Settings', 'CRM Settings', 'Call Log', 'Campaign', 'Campaign Item', 'Cashier Closing', 'Chart of Accounts Importer', 'Cheque Print Template', 'Code List', 'Common Code', 'Communication Medium', 'Company', 'Competitor', 'Contract', 'Contract Template', 'Cost Center', 'Coupon Code', 'Currency Exchange', 'Currency Exchange Settings', 'Customer', 'Customer Group', 'Customs Tariff Number', 'Delivery Note', 'Delivery Settings', 'Delivery Trip', 'Department', 'Designation', 'Downtime Entry', 'Driver', 'Dunning', 'Dunning Type', 'Email Digest', 'Email Digest Recipient', 'Employee', 'Employee Group', 'Exchange Rate Revaluation', 'Finance Book', 'Fiscal Year', 'GL Entry', 'Global Defaults', 'Holiday List', 'Import Supplier Invoice', 'Incoming Call Settings', 'Incoterm', 'Industry Type', 'Installation Note', 'Inventory Dimension', 'Invoice Discounting', 'Issue', 'Issue Priority', 'Issue Type', 'Item', 'Item Attribute', 'Item Group', 'Item Tax Template', 'Item Variant', 'Item Variant Settings', 'Item Website Specification', 'Job Card', 'Journal Entry', 'Journal Entry Template', 'Landed Cost Voucher', 'Lead', 'Ledger Health', 'Ledger Health Monitor', 'Ledger Merge', 'Lost Reason Detail', 'Lower Deduction Certificate', 'Loyalty Point Entry', 'Loyalty Point Entry Redemption', 'Loyalty Program', 'Maintenance Schedule', 'Maintenance Visit', 'Manufacturer', 'Manufacturing Settings', 'Market Segment', 'Material Request', 'Mode of Payment', 'Monthly Distribution', 'Non Conformance', 'Opening Invoice Creation Tool', 'Operation', 'Opportunity', 'Opportunity Lost Reason', 'Opportunity Type', 'POS Closing Entry', 'POS Invoice', 'POS Invoice Merge Log', 'POS Opening Entry', 'POS Profile', 'POS Settings', 'Packing Slip', 'Party Link', 'Party Specific Item', 'Party Type', 'Payment Entry', 'Payment Ledger Entry', 'Payment Order', 'Payment Reconciliation', 'Payment Request', 'Payment Term', 'Payment Terms Template', 'Period Closing Voucher', 'Pick List', 'Plaid Settings', 'Plant Floor', 'Price List', 'Pricing Rule', 'Print Heading', 'Process Payment Reconciliation', 'Process Statement Of Accounts CC', 'Product Bundle', 'Production Plan', 'Project', 'Project Template', 'Project Type', 'Projects Settings', 'Promotional Scheme', 'Prospect', 'Purchase Invoice', 'Purchase Order', 'Purchase Receipt', 'Purchase Taxes and Charges Template', 'Putaway Rule', 'Quality Action', 'Quality Feedback', 'Quality Feedback Template', 'Quality Goal', 'Quality Inspection', 'Quality Inspection Parameter', 'Quality Inspection Parameter Group', 'Quality Inspection Template', 'Quality Meeting', 'Quality Procedure', 'Quality Review', 'Quick Stock Balance', 'Quotation', 'Quotation Lost Reason', 'Rename Tool', 'Repost Accounting Ledger', 'Repost Accounting Ledger Settings', 'Repost Payment Ledger', 'Request for Quotation', 'Routing', 'SMS Center', 'Sales Invoice', 'Sales Order', 'Sales Partner', 'Sales Partner Type', 'Sales Person', 'Sales Stage', 'Sales Taxes and Charges Template', 'Selling Settings', 'Serial No', 'Serial and Batch Bundle', 'Service Level Agreement', 'Share Transfer', 'Share Type', 'Shareholder', 'Shipment', 'Shipment Parcel Template', 'Shipping Rule', 'South Africa VAT Settings', 'Stock Closing Balance', 'Stock Closing Entry', 'Stock Entry', 'Stock Entry Type', 'Stock Ledger Entry', 'Stock Reconciliation', 'Stock Reposting Settings', 'Stock Res ...
#
# Tree saved to erpnext_doctype_tree.json
#
# Tree structure:
# Account [root]
#   Accounting Dimension Detail [named_child] (field: offsetting_account)
#     Company [lookup] (field: company)
#     Account [lookup] (field: offsetting_account)
#   Account Closing Balance [named_child] (field: account)
#     Account [lookup] (field: account)
#     Cost Center [lookup] (field: cost_center)
#     Project [lookup] (field: project)
#     Company [lookup] (field: company)
#     Finance Book [lookup] (field: finance_book)
#     Period Closing Voucher [lookup] (field: period_closing_voucher)
#   Applicable On Account [named_child] (field: applicable_on_account)
#     Account [lookup] (field: applicable_on_account)
#   Bank Account [named_child] (field: account)
#     Account [lookup] (field: account)
#     Bank [lookup] (field: bank)
#     Bank Account Type [lookup] (field: account_type)
#     Bank Account Subtype [lookup] (field: account_subtype)
#     Company [lookup] (field: company)
#   Budget Account [named_child] (field: account)
#     Account [lookup] (field: account)
#   Exchange Rate Revaluation Account [named_child] (field: account)
#     Account [lookup] (field: account)
#   Journal Entry Account [named_child] (field: account)
#     Account [lookup] (field: account)
#     Cost Center [lookup] (field: cost_center)
#     Project [lookup] (field: project)
#     Bank Account [lookup] (field: bank_account)
#   Journal Entry Template Account [named_child] (field: account)
#     Account [lookup] (field: account)
#   Ledger Merge Accounts [named_child] (field: account)
#     Account [lookup] (field: account)
#   Mode of Payment Account [named_child] (field: default_account)
#     Company [lookup] (field: company)
#     Account [lookup] (field: default_account)
#   Party Account [named_child] (field: account)
#     Company [lookup] (field: company)
#     Account [lookup] (field: account)
#   Payment Gateway Account [named_child] (field: payment_account)
#     Account [lookup] (field: payment_account)
#   Process Deferred Accounting [named_child] (field: account)
#     Process Deferred Accounting [lookup] (field: amended_from)
#     Account [lookup] (field: account)
#     Company [lookup] (field: company)
#   Process Statement Of Accounts [named_child] (field: account)
#     Process Statement Of Accounts Customer [table_child] (field: customers)
#       Customer [lookup] (field: customer)
#     Company [lookup] (field: company)
#     Account [lookup] (field: account)
#     Finance Book [lookup] (field: finance_book)
#     Terms and Conditions [lookup] (field: terms_and_conditions)
#     Payment Terms Template [lookup] (field: payment_terms_template)
#     Sales Partner [lookup] (field: sales_partner)
#     Sales Person [lookup] (field: sales_person)
#     Territory [lookup] (field: territory)
#   South Africa VAT Account [named_child] (field: account)
#     Account [lookup] (field: account)
#   Tax Withholding Account [named_child] (field: account)
#     Company [lookup] (field: company)
#     Account [lookup] (field: account)
#   UAE VAT Account [named_child] (field: account)
#     Account [lookup] (field: account)
#   Company [lookup] (field: company)
#   Account [lookup] (field: parent_account)
# Accounting Dimension [root]
#   Accounting Dimension Detail [table_child] (field: dimension_defaults)
#     Company [lookup] (field: company)
#     Account [lookup] (field: offsetting_account)
# Accounting Dimension Filter [root]
#   Applicable On Account [table_child] (field: accounts)
#     Account [lookup] (field: applicable_on_account)
#   Allowed Dimension [table_child] (field: dimensions)
#   Company [lookup] (field: company)
# Accounting Period [root]
#   Closed Document [table_child] (field: closed_documents)
#   Company [lookup] (field: company)
# Accounts Settings [root]
# Advance Payment Ledger Entry [root]
#   Company [lookup] (field: company)
# Bank [root]
#   Bank Transaction Mapping [table_child] (field: bank_transaction_mapping)
#   Bank Account [named_child] (field: bank)
#     Account [lookup] (field: account)
#     Bank [lookup] (field: bank)
#     Bank Account Type [lookup] (field: account_type)
#     Bank Account Subtype [lookup] (field: account_subtype)
#     Company [lookup] (field: company)
#   Bank Guarantee [named_child] (field: bank)
#     Customer [lookup] (field: customer)
#     Supplier [lookup] (field: supplier)
#     Project [lookup] (field: project)
#     Bank [lookup] (field: bank)
#     Bank Account [lookup] (field: bank_account)
#     Account [lookup] (field: account)
#     Bank Guarantee [lookup] (field: amended_from)
#   Bank Statement Import [named_child] (field: bank)
#     Company [lookup] (field: company)
#     Bank Account [lookup] (field: bank_account)
#     Bank [lookup] (field: bank)
# Bank Account Subtype [root]
# Bank Account Type [root]
# Bank Clearance [root]
#   Bank Clearance Detail [table_child] (field: payment_entries)
#   Account [lookup] (field: account)
#   Bank Account [lookup] (field: bank_account)
# Bank Reconciliation Tool [root]
#   Company [lookup] (field: company)
#   Bank Account [lookup] (field: bank_account)
# Bank Transaction [root]
#   Bank Transaction Payments [table_child] (field: payment_entries)
#   Bank Account [lookup] (field: bank_account)
#   Company [lookup] (field: company)
#   Bank Transaction [lookup] (field: amended_from)
# Bisect Accounting Statements [root]
#   Bisect Nodes [lookup] (field: current_node)
#   Company [lookup] (field: company)
# Bisect Nodes [root]
#   Bisect Nodes [lookup] (field: root)
# Budget [root]
#   Budget Account [table_child] (field: accounts)
#     Account [lookup] (field: account)
#   Company [lookup] (field: company)
#   Cost Center [lookup] (field: cost_center)
#   Project [lookup] (field: project)
#   Fiscal Year [lookup] (field: fiscal_year)
#   Monthly Distribution [lookup] (field: monthly_distribution)
#   Budget [lookup] (field: amended_from)
# Campaign Item [root]
# Cashier Closing [root]
#   Cashier Closing Payments [table_child] (field: payments)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Cashier Closing [lookup] (field: amended_from)
# Chart of Accounts Importer [root]
#   Company [lookup] (field: company)
# Cheque Print Template [root]
# Cost Center [root]
#   Cost Center Allocation [named_child] (field: main_cost_center)
#     Cost Center Allocation Percentage [table_child] (field: allocation_percentages)
#       Cost Center [lookup] (field: cost_center)
#     Cost Center [lookup] (field: main_cost_center)
#     Company [lookup] (field: company)
#     Cost Center Allocation [lookup] (field: amended_from)
#   Cost Center Allocation Percentage [named_child] (field: cost_center)
#     Cost Center [lookup] (field: cost_center)
#   PSOA Cost Center [named_child] (field: cost_center_name)
#     Cost Center [lookup] (field: cost_center_name)
#   Cost Center [lookup] (field: parent_cost_center)
#   Company [lookup] (field: company)
# Coupon Code [root]
#   Customer [lookup] (field: customer)
#   Pricing Rule [lookup] (field: pricing_rule)
#   Coupon Code [lookup] (field: amended_from)
# Currency Exchange Settings [root]
#   Currency Exchange Settings Details [table_child] (field: req_params)
#   Currency Exchange Settings Result [table_child] (field: result_key)
# Dunning [root]
#   Overdue Payment [table_child] (field: overdue_payments)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
#     Sales Invoice [lookup] (field: sales_invoice)
#   Company [lookup] (field: company)
#   Dunning Type [lookup] (field: dunning_type)
#   Dunning [lookup] (field: amended_from)
#   Customer [lookup] (field: customer)
#   Account [lookup] (field: income_account)
#   Cost Center [lookup] (field: cost_center)
# Dunning Type [root]
#   Dunning Letter Text [table_child] (field: dunning_letter_text)
#   Account [lookup] (field: income_account)
#   Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
# Exchange Rate Revaluation [root]
#   Exchange Rate Revaluation Account [table_child] (field: accounts)
#     Account [lookup] (field: account)
#   Company [lookup] (field: company)
#   Exchange Rate Revaluation [lookup] (field: amended_from)
# Finance Book [root]
# Fiscal Year [root]
#   Fiscal Year Company [table_child] (field: companies)
#     Company [lookup] (field: company)
# GL Entry [root]
#   Account [lookup] (field: account)
#   Cost Center [lookup] (field: cost_center)
#   Project [lookup] (field: project)
#   Fiscal Year [lookup] (field: fiscal_year)
#   Company [lookup] (field: company)
#   Finance Book [lookup] (field: finance_book)
# Invoice Discounting [root]
#   Discounted Invoice [table_child] (field: invoices)
#     Sales Invoice [lookup] (field: sales_invoice)
#     Customer [lookup] (field: customer)
#     Account [lookup] (field: debit_to)
#   Company [lookup] (field: company)
#   Account [lookup] (field: short_term_loan)
#   Invoice Discounting [lookup] (field: amended_from)
# Item Tax Template [root]
#   Item Tax Template Detail [table_child] (field: taxes)
#     Account [lookup] (field: tax_type)
#   Company [lookup] (field: company)
# Journal Entry [root]
#   Journal Entry Account [table_child] (field: accounts)
#     Account [lookup] (field: account)
#     Cost Center [lookup] (field: cost_center)
#     Project [lookup] (field: project)
#     Bank Account [lookup] (field: bank_account)
#   Company [lookup] (field: company)
#   Finance Book [lookup] (field: finance_book)
#   Journal Entry [lookup] (field: inter_company_journal_entry_reference)
#   Print Heading [lookup] (field: select_print_heading)
#   Mode of Payment [lookup] (field: mode_of_payment)
#   Payment Order [lookup] (field: payment_order)
#   Stock Entry [lookup] (field: stock_entry)
#   Journal Entry Template [lookup] (field: from_template)
#   Tax Withholding Category [lookup] (field: tax_withholding_category)
#   Process Deferred Accounting [lookup] (field: process_deferred_accounting)
# Journal Entry Template [root]
#   Journal Entry Template Account [table_child] (field: accounts)
#     Account [lookup] (field: account)
#   Company [lookup] (field: company)
# Ledger Health [root]
# Ledger Health Monitor [root]
#   Ledger Health Monitor Company [table_child] (field: companies)
#     Company [lookup] (field: company)
# Ledger Merge [root]
#   Ledger Merge Accounts [table_child] (field: merge_accounts)
#     Account [lookup] (field: account)
#   Account [lookup] (field: account)
#   Company [lookup] (field: company)
# Loyalty Point Entry [root]
#   Loyalty Program [lookup] (field: loyalty_program)
#   Customer [lookup] (field: customer)
#   Loyalty Point Entry [lookup] (field: redeem_against)
#   Company [lookup] (field: company)
# Loyalty Point Entry Redemption [root]
# Loyalty Program [root]
#   Loyalty Program Collection [table_child] (field: collection_rules)
#   Customer Group [lookup] (field: customer_group)
#   Territory [lookup] (field: customer_territory)
#   Account [lookup] (field: expense_account)
#   Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
# Mode of Payment [root]
#   Mode of Payment Account [table_child] (field: accounts)
#     Company [lookup] (field: company)
#     Account [lookup] (field: default_account)
# Monthly Distribution [root]
#   Monthly Distribution Percentage [table_child] (field: percentages)
#   Fiscal Year [lookup] (field: fiscal_year)
# Opening Invoice Creation Tool [root]
#   Opening Invoice Creation Tool Item [table_child] (field: invoices)
#     Account [lookup] (field: temporary_opening_account)
#     Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
#   Cost Center [lookup] (field: cost_center)
# Party Link [root]
# Payment Entry [root]
#   Payment Entry Reference [table_child] (field: references)
#     Payment Term [lookup] (field: payment_term)
#     Account [lookup] (field: account)
#     Payment Request [lookup] (field: payment_request)
#   Payment Entry Deduction [table_child] (field: deductions)
#     Account [lookup] (field: account)
#     Cost Center [lookup] (field: cost_center)
#   Advance Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
#   Cost Center [lookup] (field: cost_center)
#   Mode of Payment [lookup] (field: mode_of_payment)
#   Account [lookup] (field: paid_from)
#   Project [lookup] (field: project)
#   Print Heading [lookup] (field: print_heading)
#   Payment Order [lookup] (field: payment_order)
#   Payment Entry [lookup] (field: amended_from)
#   Bank Account [lookup] (field: bank_account)
#   Tax Withholding Category [lookup] (field: tax_withholding_category)
#   Purchase Taxes and Charges Template [lookup] (field: purchase_taxes_and_charges_template)
#   Sales Taxes and Charges Template [lookup] (field: sales_taxes_and_charges_template)
# Payment Ledger Entry [root]
#   Account [lookup] (field: account)
#   Company [lookup] (field: company)
#   Cost Center [lookup] (field: cost_center)
#   Finance Book [lookup] (field: finance_book)
# Payment Order [root]
#   Payment Order Reference [table_child] (field: references)
#     Supplier [lookup] (field: supplier)
#     Payment Request [lookup] (field: payment_request)
#     Mode of Payment [lookup] (field: mode_of_payment)
#     Bank Account [lookup] (field: bank_account)
#     Account [lookup] (field: account)
#   Company [lookup] (field: company)
#   Supplier [lookup] (field: party)
#   Payment Order [lookup] (field: amended_from)
#   Bank Account [lookup] (field: company_bank_account)
#   Bank [lookup] (field: company_bank)
# Payment Reconciliation [root]
#   Payment Reconciliation Payment [table_child] (field: payments)
#     Cost Center [lookup] (field: cost_center)
#   Payment Reconciliation Invoice [table_child] (field: invoices)
#   Payment Reconciliation Allocation [table_child] (field: allocation)
#     Account [lookup] (field: difference_account)
#     Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
#   Account [lookup] (field: receivable_payable_account)
#   Cost Center [lookup] (field: cost_center)
# Payment Request [root]
#   Subscription Plan Detail [table_child] (field: subscription_plans)
#     Subscription Plan [lookup] (field: plan)
#   Mode of Payment [lookup] (field: mode_of_payment)
#   Bank Account [lookup] (field: bank_account)
#   Bank [lookup] (field: bank)
#   Cost Center [lookup] (field: cost_center)
#   Project [lookup] (field: project)
#   Payment Gateway Account [lookup] (field: payment_gateway_account)
#   Payment Order [lookup] (field: payment_order)
#   Payment Request [lookup] (field: amended_from)
#   Company [lookup] (field: company)
# Payment Term [root]
#   Payment Terms Template Detail [named_child] (field: payment_term)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Mode of Payment [lookup] (field: mode_of_payment)
# Payment Terms Template [root]
#   Payment Terms Template Detail [table_child] (field: terms)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
# Period Closing Voucher [root]
#   Fiscal Year [lookup] (field: fiscal_year)
#   Period Closing Voucher [lookup] (field: amended_from)
#   Company [lookup] (field: company)
#   Account [lookup] (field: closing_account_head)
# POS Closing Entry [root]
#   POS Closing Entry Detail [table_child] (field: payment_reconciliation)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   POS Closing Entry Taxes [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#   POS Invoice Reference [table_child] (field: pos_transactions)
#     POS Invoice [lookup] (field: pos_invoice)
#     Customer [lookup] (field: customer)
#   Company [lookup] (field: company)
#   POS Profile [lookup] (field: pos_profile)
#   POS Closing Entry [lookup] (field: amended_from)
#   POS Opening Entry [lookup] (field: pos_opening_entry)
# POS Invoice [root]
#   POS Invoice Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     Item Group [lookup] (field: item_group)
#     UOM [lookup] (field: stock_uom)
#     Item Tax Template [lookup] (field: item_tax_template)
#     Account [lookup] (field: income_account)
#     Finance Book [lookup] (field: finance_book)
#     Warehouse [lookup] (field: warehouse)
#     Quality Inspection [lookup] (field: quality_inspection)
#     Batch [lookup] (field: batch_no)
#     Sales Order [lookup] (field: sales_order)
#     Delivery Note [lookup] (field: delivery_note)
#     Cost Center [lookup] (field: cost_center)
#     Project [lookup] (field: project)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Pricing Rule Detail [table_child] (field: pricing_rules)
#     Pricing Rule [lookup] (field: pricing_rule)
#   Packed Item [table_child] (field: packed_items)
#     Item [lookup] (field: parent_item)
#     Warehouse [lookup] (field: warehouse)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: uom)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Sales Invoice Timesheet [table_child] (field: timesheets)
#     Timesheet [lookup] (field: time_sheet)
#     Activity Type [lookup] (field: activity_type)
#   Sales Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Sales Invoice Advance [table_child] (field: advances)
#   Payment Schedule [table_child] (field: payment_schedule)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Sales Invoice Payment [table_child] (field: payments)
#     Mode of Payment [lookup] (field: mode_of_payment)
#     Account [lookup] (field: account)
#   Sales Team [table_child] (field: sales_team)
#     Sales Person [lookup] (field: sales_person)
#   POS Invoice Reference [named_child] (field: pos_invoice)
#     POS Invoice [lookup] (field: pos_invoice)
#     Customer [lookup] (field: customer)
#   Customer [lookup] (field: customer)
#   POS Profile [lookup] (field: pos_profile)
#   Company [lookup] (field: company)
#   POS Invoice [lookup] (field: amended_from)
#   Project [lookup] (field: project)
#   Cost Center [lookup] (field: cost_center)
#   Territory [lookup] (field: territory)
#   Price List [lookup] (field: selling_price_list)
#   Warehouse [lookup] (field: set_warehouse)
#   Sales Taxes and Charges Template [lookup] (field: taxes_and_charges)
#   Shipping Rule [lookup] (field: shipping_rule)
#   Tax Category [lookup] (field: tax_category)
#   Loyalty Program [lookup] (field: loyalty_program)
#   Account [lookup] (field: loyalty_redemption_account)
#   Payment Terms Template [lookup] (field: payment_terms_template)
#   Terms and Conditions [lookup] (field: tc_name)
#   Print Heading [lookup] (field: select_print_heading)
#   Purchase Invoice [lookup] (field: inter_company_invoice_reference)
#   Customer Group [lookup] (field: customer_group)
#   Sales Partner [lookup] (field: sales_partner)
#   Sales Invoice [lookup] (field: consolidated_invoice)
#   Coupon Code [lookup] (field: coupon_code)
# POS Invoice Merge Log [root]
#   POS Invoice Reference [table_child] (field: pos_invoices)
#     POS Invoice [lookup] (field: pos_invoice)
#     Customer [lookup] (field: customer)
#   Customer [lookup] (field: customer)
#   POS Invoice Merge Log [lookup] (field: amended_from)
#   Sales Invoice [lookup] (field: consolidated_invoice)
#   POS Closing Entry [lookup] (field: pos_closing_entry)
#   Customer Group [lookup] (field: customer_group)
# POS Opening Entry [root]
#   POS Opening Entry Detail [table_child] (field: balance_details)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Company [lookup] (field: company)
#   POS Profile [lookup] (field: pos_profile)
#   POS Opening Entry [lookup] (field: amended_from)
# POS Profile [root]
#   POS Profile User [table_child] (field: applicable_for_users)
#   POS Payment Method [table_child] (field: payments)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   POS Item Group [table_child] (field: item_groups)
#     Item Group [lookup] (field: item_group)
#   POS Customer Group [table_child] (field: customer_groups)
#     Customer Group [lookup] (field: customer_group)
#   Customer [lookup] (field: customer)
#   Company [lookup] (field: company)
#   Terms and Conditions [lookup] (field: tc_name)
#   Print Heading [lookup] (field: select_print_heading)
#   Price List [lookup] (field: selling_price_list)
#   Account [lookup] (field: write_off_account)
#   Cost Center [lookup] (field: write_off_cost_center)
#   Sales Taxes and Charges Template [lookup] (field: taxes_and_charges)
#   Tax Category [lookup] (field: tax_category)
#   Warehouse [lookup] (field: warehouse)
#   Project [lookup] (field: project)
# POS Settings [root]
#   POS Field [table_child] (field: invoice_fields)
#   POS Search Fields [table_child] (field: pos_search_fields)
# Pricing Rule [root]
#   Pricing Rule Item Code [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: uom)
#   Pricing Rule Item Group [table_child] (field: item_groups)
#     Item Group [lookup] (field: item_group)
#     UOM [lookup] (field: uom)
#   Pricing Rule Brand [table_child] (field: brands)
#     Brand [lookup] (field: brand)
#     UOM [lookup] (field: uom)
#   Pricing Rule Detail [named_child] (field: pricing_rule)
#     Pricing Rule [lookup] (field: pricing_rule)
#   Warehouse [lookup] (field: warehouse)
#   Item [lookup] (field: other_item_code)
#   Item Group [lookup] (field: other_item_group)
#   Brand [lookup] (field: other_brand)
#   Customer [lookup] (field: customer)
#   Customer Group [lookup] (field: customer_group)
#   Territory [lookup] (field: territory)
#   Sales Partner [lookup] (field: sales_partner)
#   Supplier [lookup] (field: supplier)
#   Supplier Group [lookup] (field: supplier_group)
#   Company [lookup] (field: company)
#   Price List [lookup] (field: for_price_list)
#   UOM [lookup] (field: free_item_uom)
#   Promotional Scheme [lookup] (field: promotional_scheme)
# Process Payment Reconciliation [root]
#   Process Payment Reconciliation Log [named_child] (field: process_pr)
#     Process Payment Reconciliation Log Allocations [table_child] (field: allocations)
#       Account [lookup] (field: difference_account)
#     Process Payment Reconciliation [lookup] (field: process_pr)
#   Company [lookup] (field: company)
#   Account [lookup] (field: receivable_payable_account)
#   Cost Center [lookup] (field: cost_center)
#   Process Payment Reconciliation [lookup] (field: amended_from)
# Process Statement Of Accounts CC [root]
# Promotional Scheme [root]
#   Pricing Rule Item Code [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: uom)
#   Pricing Rule Item Group [table_child] (field: item_groups)
#     Item Group [lookup] (field: item_group)
#     UOM [lookup] (field: uom)
#   Pricing Rule Brand [table_child] (field: brands)
#     Brand [lookup] (field: brand)
#     UOM [lookup] (field: uom)
#   Promotional Scheme Price Discount [table_child] (field: price_discount_slabs)
#     Price List [lookup] (field: for_price_list)
#     Warehouse [lookup] (field: warehouse)
#   Promotional Scheme Product Discount [table_child] (field: product_discount_slabs)
#     Item [lookup] (field: free_item)
#     UOM [lookup] (field: free_item_uom)
#     Warehouse [lookup] (field: warehouse)
#   Item [lookup] (field: other_item_code)
#   Item Group [lookup] (field: other_item_group)
#   Brand [lookup] (field: other_brand)
#   Company [lookup] (field: company)
# Purchase Invoice [root]
#   Purchase Invoice Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: stock_uom)
#     Warehouse [lookup] (field: warehouse)
#     Quality Inspection [lookup] (field: quality_inspection)
#     Batch [lookup] (field: batch_no)
#     Account [lookup] (field: expense_account)
#     Item Tax Template [lookup] (field: item_tax_template)
#     Project [lookup] (field: project)
#     Cost Center [lookup] (field: cost_center)
#     Brand [lookup] (field: brand)
#     Item Group [lookup] (field: item_group)
#     Purchase Order [lookup] (field: purchase_order)
#     BOM [lookup] (field: bom)
#     Purchase Receipt [lookup] (field: purchase_receipt)
#     Manufacturer [lookup] (field: manufacturer)
#     Product Bundle [lookup] (field: product_bundle)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#     Material Request [lookup] (field: material_request)
#   Pricing Rule Detail [table_child] (field: pricing_rules)
#     Pricing Rule [lookup] (field: pricing_rule)
#   Purchase Receipt Item Supplied [table_child] (field: supplied_items)
#     Item [lookup] (field: main_item_code)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: stock_uom)
#     Purchase Order [lookup] (field: purchase_order)
#   Purchase Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Purchase Invoice Advance [table_child] (field: advances)
#   Payment Schedule [table_child] (field: payment_schedule)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Advance Tax [table_child] (field: advance_tax)
#     Account [lookup] (field: account_head)
#   Tax Withheld Vouchers [table_child] (field: tax_withheld_vouchers)
#   Supplier [lookup] (field: supplier)
#   Company [lookup] (field: company)
#   Cost Center [lookup] (field: cost_center)
#   Purchase Invoice [lookup] (field: amended_from)
#   Price List [lookup] (field: buying_price_list)
#   Warehouse [lookup] (field: set_warehouse)
#   Tax Category [lookup] (field: tax_category)
#   Shipping Rule [lookup] (field: shipping_rule)
#   Purchase Taxes and Charges Template [lookup] (field: taxes_and_charges)
#   Mode of Payment [lookup] (field: mode_of_payment)
#   Account [lookup] (field: cash_bank_account)
#   Payment Terms Template [lookup] (field: payment_terms_template)
#   Terms and Conditions [lookup] (field: tc_name)
#   Print Heading [lookup] (field: select_print_heading)
#   Sales Invoice [lookup] (field: inter_company_invoice_reference)
#   Tax Withholding Category [lookup] (field: tax_withholding_category)
#   Project [lookup] (field: project)
#   Subscription [lookup] (field: subscription)
#   Incoterm [lookup] (field: incoterm)
#   Supplier Group [lookup] (field: supplier_group)
# Purchase Taxes and Charges Template [root]
#   Purchase Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
#   Tax Category [lookup] (field: tax_category)
# Repost Accounting Ledger [root]
#   Repost Accounting Ledger Items [table_child] (field: vouchers)
#   Company [lookup] (field: company)
#   Repost Accounting Ledger [lookup] (field: amended_from)
# Repost Accounting Ledger Settings [root]
#   Repost Allowed Types [table_child] (field: allowed_types)
# Repost Payment Ledger [root]
#   Repost Payment Ledger Items [table_child] (field: repost_vouchers)
#   Repost Payment Ledger [lookup] (field: amended_from)
#   Company [lookup] (field: company)
# Sales Invoice [root]
#   Sales Invoice Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: stock_uom)
#     Account [lookup] (field: income_account)
#     Item Tax Template [lookup] (field: item_tax_template)
#     Cost Center [lookup] (field: cost_center)
#     Warehouse [lookup] (field: warehouse)
#     Quality Inspection [lookup] (field: quality_inspection)
#     Batch [lookup] (field: batch_no)
#     Item Group [lookup] (field: item_group)
#     Sales Order [lookup] (field: sales_order)
#     Delivery Note [lookup] (field: delivery_note)
#     Finance Book [lookup] (field: finance_book)
#     Project [lookup] (field: project)
#     Purchase Order [lookup] (field: purchase_order)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#     POS Invoice [lookup] (field: pos_invoice)
#   Pricing Rule Detail [table_child] (field: pricing_rules)
#     Pricing Rule [lookup] (field: pricing_rule)
#   Packed Item [table_child] (field: packed_items)
#     Item [lookup] (field: parent_item)
#     Warehouse [lookup] (field: warehouse)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: uom)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Sales Invoice Timesheet [table_child] (field: timesheets)
#     Timesheet [lookup] (field: time_sheet)
#     Activity Type [lookup] (field: activity_type)
#   Sales Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Sales Invoice Advance [table_child] (field: advances)
#   Payment Schedule [table_child] (field: payment_schedule)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Sales Invoice Payment [table_child] (field: payments)
#     Mode of Payment [lookup] (field: mode_of_payment)
#     Account [lookup] (field: account)
#   Sales Team [table_child] (field: sales_team)
#     Sales Person [lookup] (field: sales_person)
#   Customer [lookup] (field: customer)
#   Project [lookup] (field: project)
#   POS Profile [lookup] (field: pos_profile)
#   Company [lookup] (field: company)
#   Cost Center [lookup] (field: cost_center)
#   Sales Invoice [lookup] (field: amended_from)
#   Territory [lookup] (field: territory)
#   Price List [lookup] (field: selling_price_list)
#   Warehouse [lookup] (field: set_warehouse)
#   Sales Taxes and Charges Template [lookup] (field: taxes_and_charges)
#   Shipping Rule [lookup] (field: shipping_rule)
#   Tax Category [lookup] (field: tax_category)
#   Loyalty Program [lookup] (field: loyalty_program)
#   Account [lookup] (field: loyalty_redemption_account)
#   Payment Terms Template [lookup] (field: payment_terms_template)
#   Terms and Conditions [lookup] (field: tc_name)
#   Print Heading [lookup] (field: select_print_heading)
#   Purchase Invoice [lookup] (field: inter_company_invoice_reference)
#   Customer Group [lookup] (field: customer_group)
#   Sales Partner [lookup] (field: sales_partner)
#   Subscription [lookup] (field: subscription)
#   Incoterm [lookup] (field: incoterm)
#   Coupon Code [lookup] (field: coupon_code)
# Sales Taxes and Charges Template [root]
#   Sales Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
#   Tax Category [lookup] (field: tax_category)
# Shareholder [root]
#   Share Balance [table_child] (field: share_balance)
#     Share Type [lookup] (field: share_type)
#   Company [lookup] (field: company)
# Share Transfer [root]
#   Shareholder [lookup] (field: from_shareholder)
#   Account [lookup] (field: equity_or_liability_account)
#   Share Type [lookup] (field: share_type)
#   Company [lookup] (field: company)
#   Share Transfer [lookup] (field: amended_from)
# Share Type [root]
# Shipping Rule [root]
#   Shipping Rule Condition [table_child] (field: conditions)
#   Shipping Rule Country [table_child] (field: countries)
#   Company [lookup] (field: company)
#   Account [lookup] (field: account)
#   Cost Center [lookup] (field: cost_center)
# Subscription [root]
#   Subscription Plan Detail [table_child] (field: plans)
#     Subscription Plan [lookup] (field: plan)
#   Process Subscription [named_child] (field: subscription)
#     Process Subscription [lookup] (field: amended_from)
#     Subscription [lookup] (field: subscription)
#   Sales Taxes and Charges Template [lookup] (field: sales_tax_template)
#   Purchase Taxes and Charges Template [lookup] (field: purchase_tax_template)
#   Cost Center [lookup] (field: cost_center)
#   Company [lookup] (field: company)
# Subscription Invoice [root]
# Subscription Plan [root]
#   Subscription Plan Detail [named_child] (field: plan)
#     Subscription Plan [lookup] (field: plan)
#   Item [lookup] (field: item)
#   Price List [lookup] (field: price_list)
#   Payment Gateway Account [lookup] (field: payment_gateway)
#   Cost Center [lookup] (field: cost_center)
# Subscription Settings [root]
# Tax Category [root]
# Tax Rule [root]
#   Sales Taxes and Charges Template [lookup] (field: sales_tax_template)
#   Purchase Taxes and Charges Template [lookup] (field: purchase_tax_template)
#   Customer [lookup] (field: customer)
#   Supplier [lookup] (field: supplier)
#   Item [lookup] (field: item)
#   Tax Category [lookup] (field: tax_category)
#   Customer Group [lookup] (field: customer_group)
#   Supplier Group [lookup] (field: supplier_group)
#   Item Group [lookup] (field: item_group)
#   Company [lookup] (field: company)
# Tax Withholding Category [root]
#   Tax Withholding Rate [table_child] (field: rates)
#   Tax Withholding Account [table_child] (field: accounts)
#     Company [lookup] (field: company)
#     Account [lookup] (field: account)
# Unreconcile Payment [root]
#   Unreconcile Payment Entries [table_child] (field: allocations)
#   Unreconcile Payment [lookup] (field: amended_from)
#   Company [lookup] (field: company)
# Bulk Transaction Log [root]
# Bulk Transaction Log Detail [root]
# Buying Settings [root]
#   Supplier Group [lookup] (field: supplier_group)
#   Price List [lookup] (field: buying_price_list)
# Purchase Order [root]
#   Purchase Order Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: stock_uom)
#     Warehouse [lookup] (field: warehouse)
#     Project [lookup] (field: project)
#     Material Request [lookup] (field: material_request)
#     Sales Order [lookup] (field: sales_order)
#     Supplier Quotation [lookup] (field: supplier_quotation)
#     Supplier Quotation Item [lookup] (field: supplier_quotation_item)
#     Blanket Order [lookup] (field: blanket_order)
#     Item Group [lookup] (field: item_group)
#     Brand [lookup] (field: brand)
#     BOM [lookup] (field: bom)
#     Account [lookup] (field: expense_account)
#     Cost Center [lookup] (field: cost_center)
#     Item Tax Template [lookup] (field: item_tax_template)
#     Manufacturer [lookup] (field: manufacturer)
#     Production Plan [lookup] (field: production_plan)
#     Product Bundle [lookup] (field: product_bundle)
#     Job Card [lookup] (field: job_card)
#   Pricing Rule Detail [table_child] (field: pricing_rules)
#     Pricing Rule [lookup] (field: pricing_rule)
#   Purchase Order Item Supplied [table_child] (field: supplied_items)
#     Item [lookup] (field: main_item_code)
#     UOM [lookup] (field: stock_uom)
#     Warehouse [lookup] (field: reserve_warehouse)
#   Purchase Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Payment Schedule [table_child] (field: payment_schedule)
#     Payment Term [lookup] (field: payment_term)
#     Mode of Payment [lookup] (field: mode_of_payment)
#   Supplier [lookup] (field: supplier)
#   Company [lookup] (field: company)
#   Purchase Order [lookup] (field: amended_from)
#   Customer [lookup] (field: customer)
#   Price List [lookup] (field: buying_price_list)
#   Warehouse [lookup] (field: set_warehouse)
#   Purchase Taxes and Charges Template [lookup] (field: taxes_and_charges)
#   Shipping Rule [lookup] (field: shipping_rule)
#   Payment Terms Template [lookup] (field: payment_terms_template)
#   Terms and Conditions [lookup] (field: tc_name)
#   Supplier Quotation [lookup] (field: ref_sq)
#   Sales Order [lookup] (field: inter_company_order_reference)
#   Print Heading [lookup] (field: select_print_heading)
#   Tax Category [lookup] (field: tax_category)
#   Tax Withholding Category [lookup] (field: tax_withholding_category)
#   Cost Center [lookup] (field: cost_center)
#   Project [lookup] (field: project)
#   Incoterm [lookup] (field: incoterm)
# Request for Quotation [root]
#   Request for Quotation Supplier [table_child] (field: suppliers)
#     Supplier [lookup] (field: supplier)
#   Request for Quotation Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: uom)
#     Warehouse [lookup] (field: warehouse)
#     Project [lookup] (field: project_name)
#     Material Request [lookup] (field: material_request)
#     Brand [lookup] (field: brand)
#     Item Group [lookup] (field: item_group)
#   Company [lookup] (field: company)
#   Supplier [lookup] (field: vendor)
#   Terms and Conditions [lookup] (field: tc_name)
#   Print Heading [lookup] (field: select_print_heading)
#   Opportunity [lookup] (field: opportunity)
#   Request for Quotation [lookup] (field: amended_from)
#   Incoterm [lookup] (field: incoterm)
# Supplier [root]
#   Allowed To Transact With [table_child] (field: companies)
#     Company [lookup] (field: company)
#   Party Account [table_child] (field: accounts)
#     Company [lookup] (field: company)
#     Account [lookup] (field: account)
#   Portal User [table_child] (field: portal_users)
#   Supplier Item [named_child] (field: supplier)
#     Supplier [lookup] (field: supplier)
#   Request for Quotation Supplier [named_child] (field: supplier)
#     Supplier [lookup] (field: supplier)
#   Supplier Quotation [named_child] (field: supplier)
#     Supplier Quotation Item [table_child] (field: items)
#       Item [lookup] (field: item_code)
#       UOM [lookup] (field: stock_uom)
#       Warehouse [lookup] (field: warehouse)
#       Project [lookup] (field: project)
#       Material Request [lookup] (field: material_request)
#       Sales Order [lookup] (field: sales_order)
#       Request for Quotation [lookup] (field: request_for_quotation)
#       Item Tax Template [lookup] (field: item_tax_template)
#       Brand [lookup] (field: brand)
#       Item Group [lookup] (field: item_group)
#       Manufacturer [lookup] (field: manufacturer)
#       Cost Center [lookup] (field: cost_center)
#     Pricing Rule Detail [table_child] (field: pricing_rules)
#       Pricing Rule [lookup] (field: pricing_rule)
#     Purchase Taxes and Charges [table_child] (field: taxes)
#       Account [lookup] (field: account_head)
#       Cost Center [lookup] (field: cost_center)
#     Supplier [lookup] (field: supplier)
#     Supplier Quotation [lookup] (field: amended_from)
#     Company [lookup] (field: company)
#     Price List [lookup] (field: buying_price_list)
#     Tax Category [lookup] (field: tax_category)
#     Shipping Rule [lookup] (field: shipping_rule)
#     Purchase Taxes and Charges Template [lookup] (field: taxes_and_charges)
#     Terms and Conditions [lookup] (field: tc_name)
#     Print Heading [lookup] (field: select_print_heading)
#     Opportunity [lookup] (field: opportunity)
#     Incoterm [lookup] (field: incoterm)
#     Cost Center [lookup] (field: cost_center)
#     Project [lookup] (field: project)
#   Supplier Scorecard [named_child] (field: supplier)
#     Supplier Scorecard Scoring Standing [table_child] (field: standings)
#       Supplier Scorecard Standing [lookup] (field: standing_name)
#       Employee [lookup] (field: employee_link)
#     Supplier Scorecard Scoring Criteria [table_child] (field: criteria)
#       Supplier Scorecard Criteria [lookup] (field: criteria_name)
#     Supplier Scorecard Period [named_child] (field: scorecard)
#       Supplier Scorecard Scoring Criteria [table_child] (field: criteria)
#         Supplier Scorecard Criteria [lookup] (field: criteria_name)
#       Supplier Scorecard Scoring Variable [table_child] (field: variables)
#         Supplier Scorecard Variable [lookup] (field: variable_label)
#       Supplier [lookup] (field: supplier)
#       Supplier Scorecard [lookup] (field: scorecard)
#       Supplier Scorecard Period [lookup] (field: amended_from)
#     Supplier [lookup] (field: supplier)
#     Employee [lookup] (field: employee)
#   Supplier Scorecard Period [named_child] (field: supplier)
#     Supplier Scorecard Scoring Criteria [table_child] (field: criteria)
#       Supplier Scorecard Criteria [lookup] (field: criteria_name)
#     Supplier Scorecard Scoring Variable [table_child] (field: variables)
#       Supplier Scorecard Variable [lookup] (field: variable_label)
#     Supplier [lookup] (field: supplier)
#     Supplier Scorecard [lookup] (field: scorecard)
#     Supplier Scorecard Period [lookup] (field: amended_from)
#   Item Supplier [named_child] (field: supplier)
#     Supplier [lookup] (field: supplier)
#   Bank Account [lookup] (field: default_bank_account)
#   Tax Category [lookup] (field: tax_category)
#   Tax Withholding Category [lookup] (field: tax_withholding_category)
#   Company [lookup] (field: represents_company)
#   Supplier Group [lookup] (field: supplier_group)
#   Price List [lookup] (field: default_price_list)
#   Payment Terms Template [lookup] (field: payment_terms)
# Supplier Scorecard Criteria [root]
# Supplier Scorecard Standing [root]
#   Employee [lookup] (field: employee_link)
# Supplier Scorecard Variable [root]
# Communication Medium [root]
#   Communication Medium Timeslot [table_child] (field: timeslots)
#     Employee Group [lookup] (field: employee_group)
#   Employee Group [lookup] (field: catch_all)
#   Supplier [lookup] (field: provider)
# Appointment [root]
# Appointment Booking Settings [root]
#   Appointment Booking Slots [table_child] (field: availability_of_slots)
#   Holiday List [lookup] (field: holiday_list)
# Availability Of Slots [root]
# Campaign [root]
#   Campaign Email Schedule [table_child] (field: campaign_schedules)
#   Email Campaign [named_child] (field: campaign_name)
#     Campaign [lookup] (field: campaign_name)
# Competitor [root]
#   Competitor Detail [named_child] (field: competitor)
#     Competitor [lookup] (field: competitor)
# Contract [root]
#   Contract Fulfilment Checklist [table_child] (field: fulfilment_terms)
#     Contract Fulfilment Checklist [lookup] (field: amended_from)
#   Contract Template [lookup] (field: contract_template)
#   Contract [lookup] (field: amended_from)
# Contract Template [root]
#   Contract Template Fulfilment Terms [table_child] (field: fulfilment_terms)
# CRM Settings [root]
# Lead [root]
#   CRM Note [table_child] (field: notes)
#   Prospect Lead [named_child] (field: lead)
#     Lead [lookup] (field: lead)
#   Customer [lookup] (field: customer)
#   Market Segment [lookup] (field: market_segment)
#   Industry Type [lookup] (field: industry)
#   Company [lookup] (field: company)
#   Territory [lookup] (field: territory)
# Lost Reason Detail [root]
#   Opportunity Lost Reason [lookup] (field: lost_reason)
# Market Segment [root]
# Opportunity [root]
#   Opportunity Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     Item Group [lookup] (field: item_group)
#     Brand [lookup] (field: brand)
#     UOM [lookup] (field: uom)
#   CRM Note [table_child] (field: notes)
#   Prospect Opportunity [named_child] (field: opportunity)
#     Opportunity [lookup] (field: opportunity)
#   Opportunity Type [lookup] (field: opportunity_type)
#   Sales Stage [lookup] (field: sales_stage)
#   Territory [lookup] (field: territory)
#   Customer Group [lookup] (field: customer_group)
#   Company [lookup] (field: company)
#   Opportunity [lookup] (field: amended_from)
#   Industry Type [lookup] (field: industry)
#   Market Segment [lookup] (field: market_segment)
# Opportunity Lost Reason [root]
#   Opportunity Lost Reason Detail [named_child] (field: lost_reason)
#     Opportunity Lost Reason [lookup] (field: lost_reason)
# Opportunity Type [root]
# Prospect [root]
#   Prospect Opportunity [table_child] (field: opportunities)
#     Opportunity [lookup] (field: opportunity)
#   Prospect Lead [table_child] (field: leads)
#     Lead [lookup] (field: lead)
#   CRM Note [table_child] (field: notes)
#   Industry Type [lookup] (field: industry)
#   Market Segment [lookup] (field: market_segment)
#   Customer Group [lookup] (field: customer_group)
#   Territory [lookup] (field: territory)
#   Company [lookup] (field: company)
# Sales Stage [root]
# Code List [root]
#   Common Code [lookup] (field: default_common_code)
# Common Code [root]
#   Code List [lookup] (field: code_list)
# Plaid Settings [root]
# Maintenance Schedule [root]
#   Maintenance Schedule Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     Sales Person [lookup] (field: sales_person)
#     Sales Order [lookup] (field: sales_order)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Maintenance Schedule Detail [table_child] (field: schedules)
#     Item [lookup] (field: item_code)
#     Sales Person [lookup] (field: sales_person)
#     Maintenance Schedule Item [lookup] (field: item_reference)
#   Customer [lookup] (field: customer)
#   Territory [lookup] (field: territory)
#   Customer Group [lookup] (field: customer_group)
#   Company [lookup] (field: company)
#   Maintenance Schedule [lookup] (field: amended_from)
# Maintenance Visit [root]
#   Maintenance Visit Purpose [table_child] (field: purposes)
#     Item [lookup] (field: item_code)
#     Serial No [lookup] (field: serial_no)
#     Sales Person [lookup] (field: service_person)
#   Customer [lookup] (field: customer)
#   Maintenance Visit [lookup] (field: amended_from)
#   Company [lookup] (field: company)
# ...
#     Supplier [lookup] (field: supplier)
#   Landed Cost Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     Cost Center [lookup] (field: cost_center)
#   Landed Cost Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: expense_account)
#   Company [lookup] (field: company)
#   Landed Cost Voucher [lookup] (field: amended_from)
# Manufacturer [root]
#   Item Manufacturer [named_child] (field: manufacturer)
#     Manufacturer [lookup] (field: manufacturer)
#     Item [lookup] (field: item_code)
# Material Request [root]
#   Material Request Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: uom)
#     Warehouse [lookup] (field: warehouse)
#     Item Group [lookup] (field: item_group)
#     Brand [lookup] (field: brand)
#     Sales Order [lookup] (field: sales_order)
#     Project [lookup] (field: project)
#     Production Plan [lookup] (field: production_plan)
#     Account [lookup] (field: expense_account)
#     Cost Center [lookup] (field: cost_center)
#     Manufacturer [lookup] (field: manufacturer)
#     BOM [lookup] (field: bom_no)
#   Production Plan Material Request [named_child] (field: material_request)
#     Material Request [lookup] (field: material_request)
#   Customer [lookup] (field: customer)
#   Company [lookup] (field: company)
#   Material Request [lookup] (field: amended_from)
#   Print Heading [lookup] (field: select_print_heading)
#   Terms and Conditions [lookup] (field: tc_name)
#   Job Card [lookup] (field: job_card)
#   Warehouse [lookup] (field: set_warehouse)
#   Work Order [lookup] (field: work_order)
# Packing Slip [root]
#   Packing Slip Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: stock_uom)
#   Delivery Note [lookup] (field: delivery_note)
#   UOM [lookup] (field: net_weight_uom)
#   Packing Slip [lookup] (field: amended_from)
# Pick List [root]
#   Pick List Item [table_child] (field: locations)
#     Warehouse [lookup] (field: warehouse)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: stock_uom)
#     Item [lookup] (field: item_code)
#     Sales Order [lookup] (field: sales_order)
#     Material Request [lookup] (field: material_request)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Company [lookup] (field: company)
#   Warehouse [lookup] (field: parent_warehouse)
#   Customer [lookup] (field: customer)
#   Work Order [lookup] (field: work_order)
#   Pick List [lookup] (field: amended_from)
#   Material Request [lookup] (field: material_request)
# Price List [root]
#   Price List Country [table_child] (field: countries)
# Purchase Receipt [root]
#   Purchase Receipt Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: uom)
#     Warehouse [lookup] (field: warehouse)
#     Quality Inspection [lookup] (field: quality_inspection)
#     Purchase Order [lookup] (field: purchase_order)
#     Item Tax Template [lookup] (field: item_tax_template)
#     Project [lookup] (field: project)
#     Cost Center [lookup] (field: cost_center)
#     BOM [lookup] (field: bom)
#     Brand [lookup] (field: brand)
#     Item Group [lookup] (field: item_group)
#     Material Request [lookup] (field: material_request)
#     Account [lookup] (field: expense_account)
#     Manufacturer [lookup] (field: manufacturer)
#     Putaway Rule [lookup] (field: putaway_rule)
#     Purchase Invoice [lookup] (field: purchase_invoice)
#     Product Bundle [lookup] (field: product_bundle)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#     Batch [lookup] (field: batch_no)
#     Sales Order [lookup] (field: sales_order)
#   Pricing Rule Detail [table_child] (field: pricing_rules)
#     Pricing Rule [lookup] (field: pricing_rule)
#   Purchase Receipt Item Supplied [table_child] (field: supplied_items)
#     Item [lookup] (field: main_item_code)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: stock_uom)
#     Purchase Order [lookup] (field: purchase_order)
#   Purchase Taxes and Charges [table_child] (field: taxes)
#     Account [lookup] (field: account_head)
#     Cost Center [lookup] (field: cost_center)
#   Supplier [lookup] (field: supplier)
#   Company [lookup] (field: company)
#   Purchase Receipt [lookup] (field: return_against)
#   Price List [lookup] (field: buying_price_list)
#   Warehouse [lookup] (field: set_warehouse)
#   Tax Category [lookup] (field: tax_category)
#   Shipping Rule [lookup] (field: shipping_rule)
#   Purchase Taxes and Charges Template [lookup] (field: taxes_and_charges)
#   Terms and Conditions [lookup] (field: tc_name)
#   Project [lookup] (field: project)
#   Print Heading [lookup] (field: select_print_heading)
#   Delivery Note [lookup] (field: inter_company_reference)
#   Cost Center [lookup] (field: cost_center)
#   Incoterm [lookup] (field: incoterm)
#   Subcontracting Receipt [lookup] (field: subcontracting_receipt)
# Putaway Rule [root]
#   Item [lookup] (field: item_code)
#   Warehouse [lookup] (field: warehouse)
#   UOM [lookup] (field: stock_uom)
#   Company [lookup] (field: company)
# Quality Inspection [root]
#   Quality Inspection Reading [table_child] (field: readings)
#     Quality Inspection Parameter [lookup] (field: specification)
#     Quality Inspection Parameter Group [lookup] (field: parameter_group)
#   Item [lookup] (field: item_code)
#   Serial No [lookup] (field: item_serial_no)
#   Batch [lookup] (field: batch_no)
#   BOM [lookup] (field: bom_no)
#   Quality Inspection [lookup] (field: amended_from)
#   Quality Inspection Template [lookup] (field: quality_inspection_template)
#   Company [lookup] (field: company)
# Quality Inspection Parameter [root]
#   Item Quality Inspection Parameter [named_child] (field: specification)
#     Quality Inspection Parameter [lookup] (field: specification)
#     Quality Inspection Parameter Group [lookup] (field: parameter_group)
#   Quality Inspection Parameter Group [lookup] (field: parameter_group)
# Quality Inspection Parameter Group [root]
# Quality Inspection Template [root]
#   Item Quality Inspection Parameter [table_child] (field: item_quality_inspection_parameter)
#     Quality Inspection Parameter [lookup] (field: specification)
#     Quality Inspection Parameter Group [lookup] (field: parameter_group)
# Quick Stock Balance [root]
#   Warehouse [lookup] (field: warehouse)
#   Item [lookup] (field: item)
# Serial and Batch Bundle [root]
#   Serial and Batch Entry [table_child] (field: entries)
#     Serial No [lookup] (field: serial_no)
#     Batch [lookup] (field: batch_no)
#     Warehouse [lookup] (field: warehouse)
#   Company [lookup] (field: company)
#   Item Group [lookup] (field: item_group)
#   Item [lookup] (field: item_code)
#   Serial and Batch Bundle [lookup] (field: amended_from)
#   Warehouse [lookup] (field: warehouse)
# Serial No [root]
#   Item [lookup] (field: item_code)
#   Item Group [lookup] (field: item_group)
#   Brand [lookup] (field: brand)
#   Employee [lookup] (field: employee)
#   Company [lookup] (field: company)
#   Work Order [lookup] (field: work_order)
#   Warehouse [lookup] (field: warehouse)
#   Batch [lookup] (field: batch_no)
# Shipment [root]
#   Shipment Parcel [table_child] (field: shipment_parcel)
#   Shipment Delivery Note [table_child] (field: shipment_delivery_note)
#     Delivery Note [lookup] (field: delivery_note)
#   Company [lookup] (field: pickup_company)
#   Customer [lookup] (field: pickup_customer)
#   Supplier [lookup] (field: pickup_supplier)
#   Shipment Parcel Template [lookup] (field: parcel_template)
#   Shipment [lookup] (field: amended_from)
#   Incoterm [lookup] (field: incoterm)
# Shipment Parcel Template [root]
# Stock Closing Balance [root]
#   Item [lookup] (field: item_code)
#   Warehouse [lookup] (field: warehouse)
#   Company [lookup] (field: company)
#   UOM [lookup] (field: stock_uom)
#   Item Group [lookup] (field: item_group)
#   Stock Closing Entry [lookup] (field: stock_closing_entry)
#   Batch [lookup] (field: batch_no)
# Stock Closing Entry [root]
#   Company [lookup] (field: company)
#   Stock Closing Entry [lookup] (field: amended_from)
# Stock Entry [root]
#   Stock Entry Detail [table_child] (field: items)
#     Warehouse [lookup] (field: s_warehouse)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: uom)
#     Batch [lookup] (field: batch_no)
#     Quality Inspection [lookup] (field: quality_inspection)
#     Account [lookup] (field: expense_account)
#     Cost Center [lookup] (field: cost_center)
#     BOM [lookup] (field: bom_no)
#     Material Request [lookup] (field: material_request)
#     Material Request Item [lookup] (field: material_request_item)
#     Stock Entry [lookup] (field: against_stock_entry)
#     Purchase Receipt [lookup] (field: reference_purchase_receipt)
#     Project [lookup] (field: project)
#     Putaway Rule [lookup] (field: putaway_rule)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Landed Cost Taxes and Charges [table_child] (field: additional_costs)
#     Account [lookup] (field: expense_account)
#   Stock Entry Type [lookup] (field: stock_entry_type)
#   Stock Entry [lookup] (field: outgoing_stock_entry)
#   Company [lookup] (field: company)
#   Work Order [lookup] (field: work_order)
#   Purchase Order [lookup] (field: purchase_order)
#   Subcontracting Order [lookup] (field: subcontracting_order)
#   Delivery Note [lookup] (field: delivery_note_no)
#   Sales Invoice [lookup] (field: sales_invoice_no)
#   Purchase Receipt [lookup] (field: purchase_receipt_no)
#   BOM [lookup] (field: bom_no)
#   Warehouse [lookup] (field: from_warehouse)
#   Supplier [lookup] (field: supplier)
#   Print Heading [lookup] (field: select_print_heading)
#   Project [lookup] (field: project)
#   Job Card [lookup] (field: job_card)
#   Journal Entry [lookup] (field: credit_note)
#   Pick List [lookup] (field: pick_list)
# Stock Entry Type [root]
# Stock Ledger Entry [root]
#   Item [lookup] (field: item_code)
#   Warehouse [lookup] (field: warehouse)
#   UOM [lookup] (field: stock_uom)
#   Project [lookup] (field: project)
#   Company [lookup] (field: company)
#   Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
# Stock Reconciliation [root]
#   Stock Reconciliation Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     Warehouse [lookup] (field: warehouse)
#     Batch [lookup] (field: batch_no)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#     Item Group [lookup] (field: item_group)
#   Company [lookup] (field: company)
#   Account [lookup] (field: expense_account)
#   Cost Center [lookup] (field: cost_center)
#   Stock Reconciliation [lookup] (field: amended_from)
#   Warehouse [lookup] (field: set_warehouse)
# Stock Reposting Settings [root]
# Stock Reservation Entry [root]
#   Serial and Batch Entry [table_child] (field: sb_entries)
#     Serial No [lookup] (field: serial_no)
#     Batch [lookup] (field: batch_no)
#     Warehouse [lookup] (field: warehouse)
#   Item [lookup] (field: item_code)
#   Warehouse [lookup] (field: warehouse)
#   UOM [lookup] (field: stock_uom)
#   Project [lookup] (field: project)
#   Company [lookup] (field: company)
#   Stock Reservation Entry [lookup] (field: amended_from)
# Stock Settings [root]
#   Item Group [lookup] (field: item_group)
#   UOM [lookup] (field: stock_uom)
#   Warehouse [lookup] (field: default_warehouse)
# UOM Category [root]
# Warehouse [root]
#   Production Plan Material Request Warehouse [named_child] (field: warehouse)
#     Warehouse [lookup] (field: warehouse)
#   Company [lookup] (field: company)
#   Account [lookup] (field: account)
#   Warehouse [lookup] (field: parent_warehouse)
#   Warehouse Type [lookup] (field: warehouse_type)
# Warehouse Type [root]
# Subcontracting Order [root]
#   Subcontracting Order Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: stock_uom)
#     Warehouse [lookup] (field: warehouse)
#     Account [lookup] (field: expense_account)
#     Manufacturer [lookup] (field: manufacturer)
#     BOM [lookup] (field: bom)
#     Cost Center [lookup] (field: cost_center)
#     Project [lookup] (field: project)
#     Material Request [lookup] (field: material_request)
#     Job Card [lookup] (field: job_card)
#   Subcontracting Order Service Item [table_child] (field: service_items)
#     Item [lookup] (field: item_code)
#     Material Request [lookup] (field: material_request)
#   Subcontracting Order Supplied Item [table_child] (field: supplied_items)
#     Item [lookup] (field: main_item_code)
#     UOM [lookup] (field: stock_uom)
#     Warehouse [lookup] (field: reserve_warehouse)
#   Landed Cost Taxes and Charges [table_child] (field: additional_costs)
#     Account [lookup] (field: expense_account)
#   Purchase Order [lookup] (field: purchase_order)
#   Supplier [lookup] (field: supplier)
#   Warehouse [lookup] (field: supplier_warehouse)
#   Company [lookup] (field: company)
#   Subcontracting Order [lookup] (field: amended_from)
#   Print Heading [lookup] (field: select_print_heading)
#   Cost Center [lookup] (field: cost_center)
#   Project [lookup] (field: project)
# Subcontracting Receipt [root]
#   Subcontracting Receipt Item [table_child] (field: items)
#     Item [lookup] (field: item_code)
#     UOM [lookup] (field: stock_uom)
#     Warehouse [lookup] (field: warehouse)
#     Quality Inspection [lookup] (field: quality_inspection)
#     Subcontracting Order [lookup] (field: subcontracting_order)
#     Batch [lookup] (field: batch_no)
#     BOM [lookup] (field: bom)
#     Brand [lookup] (field: brand)
#     Account [lookup] (field: expense_account)
#     Manufacturer [lookup] (field: manufacturer)
#     Project [lookup] (field: project)
#     Cost Center [lookup] (field: cost_center)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#     Purchase Order [lookup] (field: purchase_order)
#     Job Card [lookup] (field: job_card)
#   Subcontracting Receipt Supplied Item [table_child] (field: supplied_items)
#     Item [lookup] (field: main_item_code)
#     Batch [lookup] (field: batch_no)
#     UOM [lookup] (field: stock_uom)
#     Subcontracting Order [lookup] (field: subcontracting_order)
#     Serial and Batch Bundle [lookup] (field: serial_and_batch_bundle)
#   Landed Cost Taxes and Charges [table_child] (field: additional_costs)
#     Account [lookup] (field: expense_account)
#   Supplier [lookup] (field: supplier)
#   Company [lookup] (field: company)
#   Warehouse [lookup] (field: set_warehouse)
#   Subcontracting Receipt [lookup] (field: amended_from)
#   Print Heading [lookup] (field: select_print_heading)
#   Cost Center [lookup] (field: cost_center)
#   Project [lookup] (field: project)
# Issue [root]
#   Customer [lookup] (field: customer)
#   Issue Priority [lookup] (field: priority)
#   Issue Type [lookup] (field: issue_type)
#   Service Level Agreement [lookup] (field: service_level_agreement)
#   Lead [lookup] (field: lead)
#   Project [lookup] (field: project)
#   Company [lookup] (field: company)
#   Issue [lookup] (field: issue_split_from)
# Issue Priority [root]
# Issue Type [root]
# Service Level Agreement [root]
#   Service Day [table_child] (field: support_and_resolution)
#   Service Level Priority [table_child] (field: priorities)
#     Issue Priority [lookup] (field: priority)
#   Pause SLA On Status [table_child] (field: pause_sla_on)
#   SLA Fulfilled On Status [table_child] (field: sla_fulfilled_on)
#   Holiday List [lookup] (field: holiday_list)
#   Issue Priority [lookup] (field: default_priority)
# Support Settings [root]
#   Support Search Source [table_child] (field: search_apis)
# Warranty Claim [root]
#   Serial No [lookup] (field: serial_no)
#   Customer [lookup] (field: customer)
#   Item [lookup] (field: item_code)
#   Territory [lookup] (field: territory)
#   Customer Group [lookup] (field: customer_group)
#   Company [lookup] (field: company)
#   Warranty Claim [lookup] (field: amended_from)
# Call Log [root]
#   Customer [lookup] (field: customer)
#   Telephony Call Type [lookup] (field: type_of_call)
#   Employee [lookup] (field: call_received_by)
# Incoming Call Settings [root]
#   Incoming Call Handling Schedule [table_child] (field: call_handling_schedule)
#     Employee Group [lookup] (field: agent_group)
# Telephony Call Type [root]
#   Telephony Call Type [lookup] (field: amended_from)
# Voice Call Settings [root]
# Rename Tool [root]
# Video [root]
# Video Settings [root]

# %%
import os
import json
from pathlib import Path

# Configuration
BASE_DIR = Path(r"C:\python\erpnext\erpnext")
OUTPUT_FILE = "erpnext_doctype_permissions.json"

def crawl_json_files(base_dir):
    """Find all doctype JSON files and group by permissions"""
    without_permissions = []
    with_permissions = []
    
    for json_file in Path(base_dir).rglob("*.json"):
        try:
            if any(skip in str(json_file) for skip in [
                'node_modules', '.git', '__pycache__', 'builds', 'logs', 'public', 'assets'
            ]):
                continue
                
            with open(json_file, "r", encoding="utf-8") as f:
                data = json.load(f)
                
            if data.get("doctype") == "DocType" and data.get("name"):
                doctype_info = {"name": data["name"], "file": str(json_file)}
                
                permissions = data.get("permissions", [])
                if permissions and len(permissions) > 0:
                    with_permissions.append(doctype_info)
                else:
                    without_permissions.append(doctype_info)
        except:
            continue
    
    return without_permissions, with_permissions

if __name__ == "__main__":
    without_perms, with_perms = crawl_json_files(BASE_DIR)
    
    results = {
        "doctypes_without_permissions": sorted(without_perms, key=lambda x: x["name"]),
        "doctypes_with_permissions": sorted(with_perms, key=lambda x: x["name"])
    }
    
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2)
    
    print(f"WITHOUT permissions: {len(without_perms)}")
    print(f"WITH permissions: {len(with_perms)}")
    print(f"Total: {len(without_perms) + len(with_perms)}")
    print(f"Results saved to: {OUTPUT_FILE}")
    
    # Debug: print structure
    print(f"Keys in results: {list(results.keys())}")
    print(f"Items in without_permissions: {len(results['doctypes_without_permissions'])}")
    print(f"Items in with_permissions: {len(results['doctypes_with_permissions'])}")
# Out:
# WITHOUT permissions: 218
# WITH permissions: 250
# Total: 468
# Results saved to: erpnext_doctype_permissions.json
# Keys in results: ['doctypes_without_permissions', 'doctypes_with_permissions']
# Items in without_permissions: 218
# Items in with_permissions: 250

# %%
import os
import json
from pathlib import Path

# Configuration
BASE_DIR = Path(r"C:\python\frappe\frappe")  # Base folder to crawl
OUTPUT_FILE = "frappe_doctype_tree.json"
TREE_TXT_FILE = "frappe_doctype_tree_with_permissions.txt"

def crawl_json_files(base_dir):
    """Find all doctype JSON files"""
    json_files = []
    base_path = Path(base_dir)
    
    for json_file in base_path.rglob("*.json"):
        try:
            # Skip non-doctype directories
            if any(skip in str(json_file) for skip in [
                'node_modules', '.git', '__pycache__', 'builds', 'logs', 'public', 'assets'
            ]):
                continue
                
            with open(json_file, "r", encoding="utf-8") as f:
                data = json.load(f)
                
            if data.get("doctype") == "DocType" and data.get("name"):
                json_files.append({
                    "name": data.get("name"),
                    "file": str(json_file),
                    "data": data
                })
        except:
            continue
    
    return json_files

def has_permissions(doctype_data):
    """Check if doctype has any permissions defined"""
    permissions = doctype_data.get("permissions", [])
    return permissions and len(permissions) > 0

def find_true_children(parent_name, all_doctypes):
    """Find only TRUE children - Table fields and parent field references"""
    children = []
    
    # Find parent data
    parent_data = None
    for dt in all_doctypes:
        if dt["name"] == parent_name:
            parent_data = dt["data"]
            break
    
    if not parent_data:
        return children
    
    # 1. Table fields in parent -> true children
    for field in parent_data.get("fields", []):
        if field.get("fieldtype") == "Table" and field.get("options"):
            child_name = field["options"]
            
            # Find child doctype
            for dt in all_doctypes:
                if dt["name"] == child_name:
                    children.append({
                        "name": child_name,
                        "file": dt["file"],
                        "type": "table_child",
                        "field": field.get("fieldname"),
                        "children": find_true_children(child_name, all_doctypes)
                    })
                    break
    
    # 2. Find doctypes that have "parent" field pointing to this parent
    for dt in all_doctypes:
        for field in dt["data"].get("fields", []):
            if (field.get("fieldname") == "parent" and 
                field.get("options") == parent_name):
                
                children.append({
                    "name": dt["name"],
                    "file": dt["file"],
                    "type": "parent_child",
                    "field": "parent",
                    "children": find_true_children(dt["name"], all_doctypes)
                })
                break
    
    # 3. Find doctypes with naming pattern suggesting parent-child (like "User Group Member" -> "User Group")
    for dt in all_doctypes:
        dt_name = dt["name"]
        # Skip if already processed or is the parent itself
        if any(child["name"] == dt_name for child in children) or dt_name == parent_name:
            continue
            
        # Check if child name contains parent name and has a Link field to parent
        if parent_name in dt_name and dt_name != parent_name:
            for field in dt["data"].get("fields", []):
                if (field.get("fieldtype") == "Link" and 
                    field.get("options") == parent_name):
                    
                    children.append({
                        "name": dt_name,
                        "file": dt["file"],
                        "type": "named_child",
                        "field": field.get("fieldname"),
                        "children": find_true_children(dt_name, all_doctypes)
                    })
                    break
    
    # 4. Add lookups at the end (Link fields from this parent to other doctypes)
    for field in parent_data.get("fields", []):
        if field.get("fieldtype") == "Link" and field.get("options"):
            lookup_name = field["options"]
            
            # Skip if already added as a true child
            if any(child["name"] == lookup_name for child in children):
                continue
            
            # Verify lookup doctype exists
            for dt in all_doctypes:
                if dt["name"] == lookup_name:
                    children.append({
                        "name": lookup_name,
                        "file": dt["file"],
                        "type": "lookup",
                        "field": field.get("fieldname"),
                        "children": []
                    })
                    break
    
    return children

def find_root_doctypes(all_doctypes):
    """Find root doctypes - those not referenced as true children"""
    all_names = {dt["name"] for dt in all_doctypes}
    true_children = set()
    
    for dt in all_doctypes:
        # Table field options are true children
        for field in dt["data"].get("fields", []):
            if field.get("fieldtype") == "Table" and field.get("options"):
                true_children.add(field["options"])
        
        # Doctypes with "parent" field are true children
        for field in dt["data"].get("fields", []):
            if field.get("fieldname") == "parent" and field.get("options"):
                true_children.add(dt["name"])
                break
    
    # Also check for naming pattern children (like "User Group Member" -> "User Group")
    for dt in all_doctypes:
        dt_name = dt["name"]
        for other_dt in all_doctypes:
            other_name = other_dt["name"]
            # If this doctype's name contains another doctype's name
            if other_name in dt_name and dt_name != other_name:
                # And has a Link field to that doctype
                for field in dt["data"].get("fields", []):
                    if (field.get("fieldtype") == "Link" and 
                        field.get("options") == other_name):
                        true_children.add(dt_name)
                        break
    
    return all_names - true_children

def build_tree(all_doctypes):
    """Build the tree structure"""
    root_names = find_root_doctypes(all_doctypes)
    tree = []
    
    print(f"Found {len(root_names)} root doctypes: {sorted(list(root_names))}")
    
    for dt in all_doctypes:
        if dt["name"] in root_names:
            children = find_true_children(dt["name"], all_doctypes)
            
            tree.append({
                "name": dt["name"],
                "file": dt["file"],
                "type": "root",
                "module": dt["data"].get("module"),
                "children": children
            })
    
    return tree

def print_tree(tree, indent=0):
    """Print tree structure"""
    for node in tree:
        prefix = "  " * indent
        type_info = f" [{node['type']}]"
        if node.get('field') and node['type'] != 'root':
            type_info += f" (field: {node['field']})"
        
        print(f"{prefix}{node['name']}{type_info}")
        if node.get("children"):
            print_tree(node["children"], indent + 1)

def print_tree_with_permissions(tree, all_doctypes, file_handle, indent=0):
    """Print tree structure with permissions tags to file"""
    for node in tree:
        prefix = "  " * indent
        type_info = f" [{node['type']}]"
        if node.get('field') and node['type'] != 'root':
            type_info += f" (field: {node['field']})"
        
        # Find doctype data and check for permissions
        permissions_tag = ""
        for dt in all_doctypes:
            if dt["name"] == node["name"]:
                if has_permissions(dt["data"]):
                    permissions_tag = " <PERMISSIONS>"
                break
        
        line = f"{prefix}{node['name']}{type_info}{permissions_tag}\n"
        file_handle.write(line)
        
        if node.get("children"):
            print_tree_with_permissions(node["children"], all_doctypes, file_handle, indent + 1)

# Main execution
if __name__ == "__main__":
    print("Starting Frappe DocType crawler...")
    
    # Get all doctypes
    all_doctypes = crawl_json_files(BASE_DIR)
    print(f"Found {len(all_doctypes)} doctype files")
    
    if not all_doctypes:
        print("No doctype files found. Check BASE_DIR path.")
        exit(1)
    
    # Build tree
    tree = build_tree(all_doctypes)
    
    # Save to JSON
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(tree, f, indent=2, ensure_ascii=False)
    
    # Save tree with permissions to TXT
    with open(TREE_TXT_FILE, "w", encoding="utf-8") as f:
        print_tree_with_permissions(tree, all_doctypes, f)
    
    print(f"\nTree saved to {OUTPUT_FILE}")
    print(f"Tree with permissions saved to {TREE_TXT_FILE}")
    print("\nTree structure:")
    print_tree(tree)
# Out:
# Starting Frappe DocType crawler...
# Found 272 doctype files
# Found 177 root doctypes: ['About Us Settings', 'Access Log', 'Activity Log', 'Address', 'Address Template', 'Assignment Rule', 'Audit Trail', 'Auto Repeat', 'Blog Category', 'Blog Post', 'Blog Settings', 'Blogger', 'Bulk Update', 'Calendar View', 'Changelog Feed', 'Client Script', 'Color', 'Comment', 'Communication', 'Connected App', 'Console Log', 'Contact', 'Contact Us Settings', 'Country', 'Currency', 'Custom DocPerm', 'Custom Field', 'Custom HTML Block', 'Custom Role', 'Customize Form', 'Dashboard', 'Dashboard Chart', 'Dashboard Chart Source', 'Dashboard Settings', 'Data Export', 'Data Import', 'Deleted Document', 'Desktop Icon', 'Discussion Reply', 'Discussion Topic', 'DocShare', 'DocType', 'Document Follow', 'Document Naming Rule', 'Document Naming Settings', 'Document Share Key', 'Domain', 'Domain Settings', 'Dropbox Settings', 'Email Account', 'Email Domain', 'Email Flag Queue', 'Email Group', 'Email Queue', 'Email Rule', 'Email Template', 'Email Unsubscribe', 'Energy Point Log', 'Energy Point Rule', 'Energy Point Settings', 'Error Log', 'Event', 'File', 'Form Tour', 'Gender', 'Geolocation Settings', 'Global Search Settings', 'Google Calendar', 'Google Contacts', 'Google Drive', 'Google Settings', 'Help Article', 'Help Category', 'Installed Applications', 'Integration Request', 'Kanban Board', 'LDAP Settings', 'Language', 'Letter Head', 'List Filter', 'List View Settings', 'Log Settings', 'Milestone', 'Milestone Tracker', 'Module Def', 'Module Onboarding', 'Module Profile', 'Navbar Settings', 'Network Printer Settings', 'Newsletter', 'Note', 'Notification', 'Notification Log', 'Notification Settings', 'Notification Subscribed Document', 'Number Card', 'OAuth Authorization Code', 'OAuth Bearer Token', 'OAuth Client', 'OAuth Provider Settings', 'Onboarding Permission', 'Onboarding Step', 'Package', 'Package Import', 'Page', 'Patch Log', 'Permission Inspector', 'Permission Log', 'Personal Data Deletion Request', 'Personal Data Download Request', 'Portal Settings', 'Prepared Report', 'Print Format', 'Print Format Field Template', 'Print Heading', 'Print Settings', 'Print Style', 'Property Setter', 'Push Notification Settings', 'RQ Job', 'RQ Worker', 'Recorder', 'Reminder', 'Report', 'Role', 'Role Profile', 'Route History', 'S3 Backup Settings', 'SMS Log', 'SMS Settings', 'Salutation', 'Scheduled Job Log', 'Scheduled Job Type', 'Scheduler Event', 'Server Script', 'Session Default Settings', 'Slack Webhook URL', 'Social Link Settings', 'Social Login Key', 'Submission Queue', 'Success Action', 'System Console', 'System Health Report', 'System Settings', 'Tag', 'ToDo', 'Token Cache', 'Transaction Log', 'Translation', 'UTM Campaign', 'UTM Medium', 'UTM Source', 'Unhandled Email', 'User', 'User Group', 'User Type', 'Version', 'View Log', 'Web Form', 'Web Page', 'Web Page View', 'Web Template', 'Webhook', 'Website Route Meta', 'Website Script', 'Website Settings', 'Website Sidebar', 'Website Slideshow', 'Website Theme', 'Workflow', 'Workflow Action', 'Workflow Action Master', 'Workflow State', 'Workspace', 'Workspace Settings', 'new-doctype-1', 'new-doctype-2']
#
# Tree saved to frappe_doctype_tree.json
# Tree with permissions saved to frappe_doctype_tree_with_permissions.txt
#
# Tree structure:
# Assignment Rule [root]
#   Assignment Rule Day [table_child] (field: assignment_days)
#   DocType [lookup] (field: document_type)
#   User [lookup] (field: last_user)
# Auto Repeat [root]
#   Auto Repeat Day [table_child] (field: repeat_on_days)
#   DocType [lookup] (field: reference_doctype)
#   Email Template [lookup] (field: template)
#   Print Format [lookup] (field: print_format)
# Milestone [root]
#   DocType [lookup] (field: reference_type)
#   Milestone Tracker [lookup] (field: milestone_tracker)
# Milestone Tracker [root]
#   DocType [lookup] (field: document_type)
# Reminder [root]
#   User [lookup] (field: user)
#   DocType [lookup] (field: reminder_doctype)
# Address [root]
#   Dynamic Link [table_child] (field: links)
#     DocType [lookup] (field: link_doctype)
#   Country [lookup] (field: country)
# Address Template [root]
#   Country [lookup] (field: country)
# Contact [root]
#   Dynamic Link [table_child] (field: links)
#     DocType [lookup] (field: link_doctype)
#   Contact Email [table_child] (field: email_ids)
#   Contact Phone [table_child] (field: phone_nos)
#   User [lookup] (field: user)
#   Salutation [lookup] (field: salutation)
#   Gender [lookup] (field: gender)
#   Address [lookup] (field: address)
#   Google Contacts [lookup] (field: google_contacts)
# Gender [root]
# Salutation [root]
# Access Log [root]
#   User [lookup] (field: user)
# Activity Log [root]
#   DocType [lookup] (field: reference_doctype)
#   User [lookup] (field: user)
# Audit Trail [root]
#   DocType [lookup] (field: doctype_name)
# Comment [root]
#   DocType [lookup] (field: reference_doctype)
# Communication [root]
#   Communication Link [table_child] (field: timeline_links)
#     DocType [lookup] (field: link_doctype)
#   DocType [lookup] (field: reference_doctype)
#   Email Account [lookup] (field: email_account)
#   Communication [lookup] (field: in_reply_to)
#   User [lookup] (field: user)
#   Email Template [lookup] (field: email_template)
# Custom DocPerm [root]
#   Role [lookup] (field: role)
# Custom Role [root]
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   Page [lookup] (field: page)
#   Report [lookup] (field: report)
# Data Export [root]
#   DocType [lookup] (field: reference_doctype)
# Data Import [root]
#   Data Import Log [named_child] (field: data_import)
#     Data Import [lookup] (field: data_import)
#   DocType [lookup] (field: reference_doctype)
# Deleted Document [root]
# DocShare [root]
#   User [lookup] (field: user)
#   DocType [lookup] (field: share_doctype)
# DocType [root]
#   DocField [table_child] (field: fields)
#   DocPerm [table_child] (field: permissions)
#     Role [lookup] (field: role)
#   DocType Action [table_child] (field: actions)
#   DocType Link [table_child] (field: links)
#     DocType [lookup] (field: link_doctype)
#   DocType State [table_child] (field: states)
#   DocType Layout [named_child] (field: document_type)
#     DocType Layout Field [table_child] (field: fields)
#     DocType [lookup] (field: document_type)
#   Global Search DocType [named_child] (field: document_type)
#     DocType [lookup] (field: document_type)
#   Module Def [lookup] (field: module)
#   Domain [lookup] (field: restrict_to_domain)
#   Email Template [lookup] (field: default_email_template)
# Document Naming Rule [root]
#   Document Naming Rule Condition [table_child] (field: conditions)
#   DocType [lookup] (field: document_type)
# Document Naming Settings [root]
#   Amended Document Naming Settings [table_child] (field: amend_naming_override)
#     DocType [lookup] (field: document_type)
# Document Share Key [root]
#   DocType [lookup] (field: reference_doctype)
# Domain [root]
#   Has Domain [named_child] (field: domain)
#     Domain [lookup] (field: domain)
# Domain Settings [root]
#   Has Domain [table_child] (field: active_domains)
#     Domain [lookup] (field: domain)
# Error Log [root]
#   DocType [lookup] (field: reference_doctype)
# File [root]
#   File [lookup] (field: folder)
#   DocType [lookup] (field: attached_to_doctype)
# Installed Applications [root]
#   Installed Application [table_child] (field: installed_applications)
# Language [root]
#   Language [lookup] (field: based_on)
# Log Settings [root]
# Module Def [root]
#   Domain [lookup] (field: restrict_to_domain)
#   Package [lookup] (field: package)
# Module Profile [root]
#   Block Module [table_child] (field: block_modules)
# Navbar Settings [root]
#   Navbar Item [table_child] (field: settings_dropdown)
#   Navbar Item [table_child] (field: help_dropdown)
# Package [root]
#   Package Release [named_child] (field: package)
#     Package [lookup] (field: package)
# Package Import [root]
# Page [root]
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   Role Permission for Page and Report [named_child] (field: page)
#     Has Role [table_child] (field: roles)
#       Role [lookup] (field: role)
#     Page [lookup] (field: page)
#     Report [lookup] (field: report)
#   Module Def [lookup] (field: module)
#   Domain [lookup] (field: restrict_to_domain)
# Patch Log [root]
# Permission Inspector [root]
#   DocType [lookup] (field: ref_doctype)
#   User [lookup] (field: user)
# Permission Log [root]
#   User [lookup] (field: changed_by)
#   DocType [lookup] (field: for_doctype)
# Prepared Report [root]
# Recorder [root]
#   Recorder Query [table_child] (field: sql_queries)
#   Recorder Suggested Index [table_child] (field: suggested_indexes)
# Report [root]
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   Report Filter [table_child] (field: filters)
#   Report Column [table_child] (field: columns)
#   Role Permission for Page and Report [named_child] (field: report)
#     Has Role [table_child] (field: roles)
#       Role [lookup] (field: role)
#     Page [lookup] (field: page)
#     Report [lookup] (field: report)
#   Auto Email Report [named_child] (field: report)
#     Report [lookup] (field: report)
#     User [lookup] (field: user)
#     Email Account [lookup] (field: sender)
#   DocType [lookup] (field: ref_doctype)
#   Module Def [lookup] (field: module)
#   Letter Head [lookup] (field: letter_head)
# Role [root]
#   Has Role [named_child] (field: role)
#     Role [lookup] (field: role)
#   Role Replication [named_child] (field: existing_role)
#     Role [lookup] (field: existing_role)
#   OAuth Client Role [named_child] (field: role)
#     Role [lookup] (field: role)
#   Workflow Action Permitted Role [named_child] (field: role)
#     Role [lookup] (field: role)
#   Domain [lookup] (field: restrict_to_domain)
# Role Profile [root]
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   User Role Profile [named_child] (field: role_profile)
#     Role Profile [lookup] (field: role_profile)
# RQ Job [root]
# RQ Worker [root]
#   RQ Job [lookup] (field: current_job_id)
# Scheduled Job Log [root]
#   Scheduled Job Type [lookup] (field: scheduled_job_type)
# Scheduled Job Type [root]
#   Server Script [lookup] (field: server_script)
#   Scheduler Event [lookup] (field: scheduler_event)
# Scheduler Event [root]
#   DocType [lookup] (field: scheduled_against)
# Server Script [root]
#   DocType [lookup] (field: reference_doctype)
#   Module Def [lookup] (field: module)
# Session Default Settings [root]
#   Session Default [table_child] (field: session_defaults)
#     DocType [lookup] (field: ref_doctype)
# SMS Log [root]
# SMS Settings [root]
#   SMS Parameter [table_child] (field: parameters)
# Submission Queue [root]
#   RQ Job [lookup] (field: job_id)
#   DocType [lookup] (field: ref_doctype)
# Success Action [root]
#   DocType [lookup] (field: ref_doctype)
# System Settings [root]
#   Country [lookup] (field: country)
#   Language [lookup] (field: language)
#   Email Template [lookup] (field: welcome_email_template)
#   Currency [lookup] (field: currency)
# Transaction Log [root]
#   Transaction Log [lookup] (field: amended_from)
# Translation [root]
#   Language [lookup] (field: language)
# User [root]
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   User Email [table_child] (field: user_emails)
#     Email Account [lookup] (field: email_account)
#   Block Module [table_child] (field: block_modules)
#   DefaultValue [table_child] (field: defaults)
#   User Social Login [table_child] (field: social_logins)
#   Assignment Rule User [named_child] (field: user)
#     User [lookup] (field: user)
#   Log Setting User [named_child] (field: user)
#     User [lookup] (field: user)
#   User Group Member [named_child] (field: user)
#     User [lookup] (field: user)
#   User Permission [named_child] (field: user)
#     User [lookup] (field: user)
#     DocType [lookup] (field: allow)
#   Language [lookup] (field: language)
#   Role Profile [lookup] (field: role_profile_name)
#   Gender [lookup] (field: gender)
#   User Type [lookup] (field: user_type)
#   Module Profile [lookup] (field: module_profile)
#   Workspace [lookup] (field: default_workspace)
# User Group [root]
# User Type [root]
#   User Document Type [table_child] (field: user_doctypes)
#     DocType [lookup] (field: document_type)
#   User Select Document Type [table_child] (field: select_doctypes)
#     DocType [lookup] (field: document_type)
#   User Type Module [table_child] (field: user_type_modules)
#     Module Def [lookup] (field: module)
#   User Select Document Type [table_child] (field: custom_select_doctypes)
#     DocType [lookup] (field: document_type)
#   Role [lookup] (field: role)
#   DocType [lookup] (field: apply_user_permission_on)
# Version [root]
#   DocType [lookup] (field: ref_doctype)
# View Log [root]
#   DocType [lookup] (field: reference_doctype)
# new-doctype-2 [root]
# new-doctype-1 [root]
# Client Script [root]
#   DocType [lookup] (field: dt)
#   Module Def [lookup] (field: module)
# Customize Form [root]
#   Customize Form Field [table_child] (field: fields)
#   DocType Link [table_child] (field: links)
#     DocType [lookup] (field: link_doctype)
#   DocType Action [table_child] (field: actions)
#   DocType State [table_child] (field: states)
#   DocType [lookup] (field: doc_type)
#   Print Format [lookup] (field: default_print_format)
#   Email Template [lookup] (field: default_email_template)
# Custom Field [root]
#   DocType [lookup] (field: dt)
#   Module Def [lookup] (field: module)
# Property Setter [root]
#   DocType [lookup] (field: doc_type)
#   Module Def [lookup] (field: module)
# Bulk Update [root]
#   DocType [lookup] (field: document_type)
# Calendar View [root]
#   DocType [lookup] (field: reference_doctype)
# Changelog Feed [root]
# Console Log [root]
# Custom HTML Block [root]
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
# Dashboard [root]
#   Dashboard Chart Link [table_child] (field: charts)
#     Dashboard Chart [lookup] (field: chart)
#   Number Card Link [table_child] (field: cards)
#     Number Card [lookup] (field: card)
#   Module Def [lookup] (field: module)
# Dashboard Chart [root]
#   Dashboard Chart Field [table_child] (field: y_axis)
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   Dashboard Chart Link [named_child] (field: chart)
#     Dashboard Chart [lookup] (field: chart)
#   Dashboard Chart Source [lookup] (field: source)
#   DocType [lookup] (field: document_type)
#   Report [lookup] (field: report_name)
#   Module Def [lookup] (field: module)
#   Currency [lookup] (field: currency)
# Dashboard Chart Source [root]
#   Module Def [lookup] (field: module)
# Dashboard Settings [root]
#   User [lookup] (field: user)
# Desktop Icon [root]
#   DocType [lookup] (field: _doctype)
#   Report [lookup] (field: _report)
# Event [root]
#   Event Participants [table_child] (field: event_participants)
#     DocType [lookup] (field: reference_doctype)
#   Google Calendar [lookup] (field: google_calendar)
# Form Tour [root]
#   Form Tour Step [table_child] (field: steps)
#     Form Tour [lookup] (field: next_form_tour)
#   DocType [lookup] (field: reference_doctype)
#   Module Def [lookup] (field: module)
#   Dashboard [lookup] (field: dashboard_name)
#   Workspace [lookup] (field: workspace_name)
#   Page [lookup] (field: page_name)
#   Report [lookup] (field: report_name)
# Global Search Settings [root]
#   Global Search DocType [table_child] (field: allowed_in_global_search)
#     DocType [lookup] (field: document_type)
# Kanban Board [root]
#   Kanban Board Column [table_child] (field: columns)
#   DocType [lookup] (field: reference_doctype)
# List Filter [root]
#   DocType [lookup] (field: reference_doctype)
#   User [lookup] (field: for_user)
# List View Settings [root]
# Module Onboarding [root]
#   Onboarding Step Map [table_child] (field: steps)
#     Onboarding Step [lookup] (field: step)
#   Module Def [lookup] (field: module)
# Note [root]
#   Note Seen By [table_child] (field: seen_by)
#     User [lookup] (field: user)
# Notification Log [root]
#   User [lookup] (field: for_user)
#   DocType [lookup] (field: document_type)
# Notification Settings [root]
#   User [lookup] (field: user)
# Notification Subscribed Document [root]
#   DocType [lookup] (field: document)
# Number Card [root]
#   Number Card Link [named_child] (field: card)
#     Number Card [lookup] (field: card)
#   Workspace Number Card [named_child] (field: number_card_name)
#     Number Card [lookup] (field: number_card_name)
#   DocType [lookup] (field: document_type)
#   Module Def [lookup] (field: module)
#   Report [lookup] (field: report_name)
#   Currency [lookup] (field: currency)
# Onboarding Permission [root]
#   Role [lookup] (field: role)
# Onboarding Step [root]
#   Onboarding Step Map [named_child] (field: step)
#     Onboarding Step [lookup] (field: step)
#   DocType [lookup] (field: reference_document)
#   Report [lookup] (field: reference_report)
#   Form Tour [lookup] (field: form_tour)
# Route History [root]
#   User [lookup] (field: user)
# System Console [root]
# System Health Report [root]
#   System Health Report Workers [table_child] (field: background_workers)
#   System Health Report Queue [table_child] (field: queue_status)
#   System Health Report Errors [table_child] (field: top_errors)
#   System Health Report Tables [table_child] (field: top_db_tables)
#   System Health Report Failing Jobs [table_child] (field: failing_scheduled_jobs)
#     Scheduled Job Type [lookup] (field: scheduled_job_type)
#   Scheduled Job Type [lookup] (field: oldest_unscheduled_job)
# Tag [root]
#   Tag Link [named_child] (field: tag)
#     Tag [lookup] (field: tag)
#     DocType [lookup] (field: document_type)
# ToDo [root]
#   DocType [lookup] (field: reMAIN_rence_type)
#   Role [lookup] (field: role)
#   User [lookup] (field: assigned_by)
#   Assignment Rule [lookup] (field: assignment_rule)
# Workspace [root]
#   Workspace Chart [table_child] (field: charts)
#     Dashboard Chart [lookup] (field: chart_name)
#   Workspace Shortcut [table_child] (field: shortcuts)
#     Domain [lookup] (field: restrict_to_domain)
#     Kanban Board [lookup] (field: kanban_board)
#     DocType [lookup] (field: report_ref_doctype)
#   Workspace Link [table_child] (field: links)
#     Country [lookup] (field: only_for)
#     DocType [lookup] (field: report_ref_doctype)
#   Has Role [table_child] (field: roles)
#     Role [lookup] (field: role)
#   Workspace Quick List [table_child] (field: quick_lists)
#     DocType [lookup] (field: document_type)
#   Workspace Number Card [table_child] (field: number_cards)
#     Number Card [lookup] (field: number_card_name)
#   Workspace Custom Block [table_child] (field: custom_blocks)
#     Custom HTML Block [lookup] (field: custom_block_name)
#   Domain [lookup] (field: restrict_to_domain)
#   Module Def [lookup] (field: module)
#   Workspace [lookup] (field: parent_page)
# Workspace Settings [root]
# Document Follow [root]
#   DocType [lookup] (field: ref_doctype)
#   User [lookup] (field: user)
# Email Account [root]
#   IMAP Folder [table_child] (field: imap_folder)
#     DocType [lookup] (field: append_to)
#   Email Domain [lookup] (field: domain)
#   DocType [lookup] (field: append_to)
#   Connected App [lookup] (field: connected_app)
#   User [lookup] (field: connected_user)
# Email Domain [root]
# Email Flag Queue [root]
# Email Group [root]
#   Email Group Member [named_child] (field: email_group)
#     Email Group [lookup] (field: email_group)
#   Newsletter Email Group [named_child] (field: email_group)
#     Email Group [lookup] (field: email_group)
#   Email Template [lookup] (field: confirmation_email_template)
# Email Queue [root]
#   Email Queue Recipient [table_child] (field: recipients)
#   DocType [lookup] (field: reference_doctype)
#   Communication [lookup] (field: communication)
#   Email Account [lookup] (field: email_account)
# Email Rule [root]
# Email Template [root]
# Email Unsubscribe [root]
#   DocType [lookup] (field: reference_doctype)
# Newsletter [root]
#   Newsletter Email Group [table_child] (field: email_group)
#     Email Group [lookup] (field: email_group)
#   Newsletter Attachment [table_child] (field: attachments)
#   UTM Campaign [lookup] (field: campaign)
# Notification [root]
#   Notification Recipient [table_child] (field: recipients)
#     Role [lookup] (field: receiver_by_role)
#   Slack Webhook URL [lookup] (field: slack_webhook_url)
#   DocType [lookup] (field: document_type)
#   Module Def [lookup] (field: module)
#   Email Account [lookup] (field: sender)
#   Print Format [lookup] (field: print_format)
# Unhandled Email [root]
#   Email Account [lookup] (field: email_account)
# Country [root]
# Currency [root]
# Connected App [root]
#   OAuth Scope [table_child] (field: scopes)
#   Query Parameters [table_child] (field: query_parameters)
# Dropbox Settings [root]
# Geolocation Settings [root]
# Google Calendar [root]
#   User [lookup] (field: user)
# Google Contacts [root]
# Google Drive [root]
# Google Settings [root]
# Integration Request [root]
#   DocType [lookup] (field: reference_doctype)
# LDAP Settings [root]
#   LDAP Group Mapping [table_child] (field: ldap_groups)
#     Role [lookup] (field: erpnext_role)
#   Role [lookup] (field: default_role)
#   User Type [lookup] (field: default_user_type)
# OAuth Authorization Code [root]
#   OAuth Client [lookup] (field: client)
#   User [lookup] (field: user)
# OAuth Bearer Token [root]
#   OAuth Client [lookup] (field: client)
#   User [lookup] (field: user)
# OAuth Client [root]
#   User [lookup] (field: user)
# OAuth Provider Settings [root]
# Push Notification Settings [root]
# S3 Backup Settings [root]
# Slack Webhook URL [root]
# Social Login Key [root]
# Token Cache [root]
#   OAuth Scope [table_child] (field: scopes)
#   User [lookup] (field: user)
#   Connected App [lookup] (field: connected_app)
# Webhook [root]
#   Webhook Header [table_child] (field: webhook_headers)
#   Webhook Data [table_child] (field: webhook_data)
#   Webhook Request Log [named_child] (field: webhook)
#     User [lookup] (field: user)
#     Webhook [lookup] (field: webhook)
#   DocType [lookup] (field: webhook_doctype)
# Letter Head [root]
# Network Printer Settings [root]
# Print Format [root]
#   DocType [lookup] (field: doc_type)
#   Module Def [lookup] (field: module)
#   Language [lookup] (field: default_print_language)
# Print Format Field Template [root]
#   DocType [lookup] (field: document_type)
#   Module Def [lookup] (field: module)
# Print Heading [root]
# Print Settings [root]
#   Print Style [lookup] (field: print_style)
# Print Style [root]
# Energy Point Log [root]
#   User [lookup] (field: user)
#   Energy Point Rule [lookup] (field: rule)
#   DocType [lookup] (field: reference_doctype)
#   Energy Point Log [lookup] (field: revert_of)
# Energy Point Rule [root]
#   DocType [lookup] (field: reference_doctype)
# Energy Point Settings [root]
#   Review Level [table_child] (field: review_levels)
#     Role [lookup] (field: role)
# About Us Settings [root]
#   Company History [table_child] (field: company_history)
#   About Us Team Member [table_child] (field: team_members)
# Blogger [root]
#   User [lookup] (field: user)
# Blog Category [root]
# Blog Post [root]
#   Blog Category [lookup] (field: blog_category)
#   Blogger [lookup] (field: blogger)
# Blog Settings [root]
# Color [root]
# Contact Us Settings [root]
# Discussion Reply [root]
#   Discussion Topic [lookup] (field: topic)
# Discussion Topic [root]
#   DocType [lookup] (field: reference_doctype)
# Help Article [root]
#   Help Category [lookup] (field: category)
# Help Category [root]
# Personal Data Deletion Request [root]
#   Personal Data Deletion Step [table_child] (field: deletion_steps)
# Personal Data Download Request [root]
#   User [lookup] (field: user)
#   Personal Data Download Request [lookup] (field: amended_from)
# Portal Settings [root]
#   Portal Menu Item [table_child] (field: menu)
#     DocType [lookup] (field: reference_doctype)
#     Role [lookup] (field: role)
#   Portal Menu Item [table_child] (field: custom_menu)
#     DocType [lookup] (field: reference_doctype)
#     Role [lookup] (field: role)
#   Role [lookup] (field: default_role)
# Social Link Settings [root]
# UTM Campaign [root]
# UTM Medium [root]
# UTM Source [root]
# Website Route Meta [root]
#   Website Meta Tag [table_child] (field: meta_tags)
# Website Script [root]
# Website Settings [root]
#   Top Bar Item [table_child] (field: top_bar_items)
#   Top Bar Item [table_child] (field: footer_items)
#   Website Route Redirect [table_child] (field: route_redirects)
#   Website Theme [lookup] (field: website_theme)
#   Web Template [lookup] (field: navbar_template)
# Website Sidebar [root]
#   Website Sidebar Item [table_child] (field: sidebar_items)
# Website Slideshow [root]
#   Website Slideshow Item [table_child] (field: slideshow_items)
# Website Theme [root]
#   Website Theme Ignore App [table_child] (field: ignored_apps)
#   Module Def [lookup] (field: module)
#   Color [lookup] (field: primary_color)
# Web Form [root]
#   Web Form Field [table_child] (field: web_form_fields)
#   Web Form List Column [table_child] (field: list_columns)
#   DocType [lookup] (field: doc_type)
#   Module Def [lookup] (field: module)
#   Print Format [lookup] (field: print_format)
#   Website Sidebar [lookup] (field: website_sidebar)
# Web Page [root]
#   Web Page Block [table_child] (field: page_blocks)
#     Web Template [lookup] (field: web_template)
#   Website Slideshow [lookup] (field: slideshow)
#   Website Sidebar [lookup] (field: website_sidebar)
#   Module Def [lookup] (field: module)
# Web Page View [root]
# Web Template [root]
#   Web Template Field [table_child] (field: fields)
#   Module Def [lookup] (field: module)
# Workflow [root]
#   Workflow Document State [table_child] (field: states)
#     Workflow State [lookup] (field: state)
#     Role [lookup] (field: allow_edit)
#     Email Template [lookup] (field: next_action_email_template)
#   Workflow Transition [table_child] (field: transitions)
#     Workflow State [lookup] (field: state)
#     Workflow Action Master [lookup] (field: action)
#     Role [lookup] (field: allowed)
#   DocType [lookup] (field: document_type)
# Workflow Action [root]
#   DocType [lookup] (field: reference_doctype)
#   User [lookup] (field: user)
#   Role [lookup] (field: completed_by_role)
# Workflow Action Master [root]
# Workflow State [root]
