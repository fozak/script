# %%
#!pip install glob

# %%
import sqlite3

db_path = "demo.db"
output_file = "demo_dump.sql"

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

with open(output_file, "w", encoding="utf-8") as f:
    # List all tables
    f.write("-- List of tables\n")
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = [row[0] for row in cursor.fetchall()]
    for table in tables:
        f.write(f"\n-- Table: {table}\n")
        # Get first 4 rows
        cursor.execute(f"SELECT * FROM {table} LIMIT 4;")
        rows = cursor.fetchall()
        for row in rows:
            f.write(f"{row}\n")

conn.close()
print(f"Written to {output_file}")
# Out:
# Written to demo_dump.sql

# %%
import sqlite3
import json

def get_complete_schema(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    schema_info = {}
    
    # Get all tables
    cursor.execute("""
        SELECT name FROM sqlite_master 
        WHERE type='table' AND name NOT LIKE 'sqlite_%'
        ORDER BY name
    """)
    
    tables = [row[0] for row in cursor.fetchall()]
    
    for table in tables:
        print(f"\n-- Table: {table}")
        
        # Get CREATE TABLE statement
        cursor.execute("""
            SELECT sql FROM sqlite_master 
            WHERE type='table' AND name=?
        """, (table,))
        
        create_sql = cursor.fetchone()[0]
        print(f"CREATE: {create_sql}")
        
        # Get column info
        cursor.execute(f"PRAGMA table_info({table})")
        columns = cursor.fetchall()
        
        print("COLUMNS:")
        for col in columns:
            print(f"  {col[1]} {col[2]} {'NOT NULL' if col[3] else 'NULL'} {'PK' if col[5] else ''}")
        
        # Get foreign keys
        cursor.execute(f"PRAGMA foreign_key_list({table})")
        foreign_keys = cursor.fetchall()
        
        if foreign_keys:
            print("FOREIGN KEYS:")
            for fk in foreign_keys:
                print(f"  {fk[3]} -> {fk[2]}.{fk[4]}")
        
        # Get indexes
        cursor.execute(f"PRAGMA index_list({table})")
        indexes = cursor.fetchall()
        
        if indexes:
            print("INDEXES:")
            for idx in indexes:
                cursor.execute(f"PRAGMA index_info({idx[1]})")
                idx_cols = cursor.fetchall()
                cols = [col[2] for col in idx_cols]
                print(f"  {idx[1]}: {', '.join(cols)} {'UNIQUE' if idx[2] else ''}")
        
        # Sample data (first 3 rows)
        cursor.execute(f"SELECT * FROM {table} LIMIT 3")
        sample_data = cursor.fetchall()
        
        if sample_data:
            print("SAMPLE DATA:")
            cursor.execute(f"PRAGMA table_info({table})")
            col_names = [col[1] for col in cursor.fetchall()]
            
            for row in sample_data:
                row_dict = dict(zip(col_names, row))
                print(f"  {row_dict}")
        
        # Store structured info
        schema_info[table] = {
            'create_sql': create_sql,
            'columns': columns,
            'foreign_keys': foreign_keys,
            'indexes': indexes,
            'sample_data': sample_data
        }
    
    conn.close()
    return schema_info

# Usage
if __name__ == "__main__":
    db_path = "demo.db"  # Replace with your DB path
    schema = get_complete_schema(db_path)
    
    # Optional: Save to JSON file
    with open('schema_analysis.json', 'w') as f:
        json.dump(schema, f, indent=2, default=str)
    
    print(f"\nSchema analysis saved to schema_analysis.json")
# Out:
# -- Table: Account
# CREATE: CREATE TABLE `Account` (`name` text not null, `rootType` text not null, `parentAccount` text, `accountType` text, `isGroup` boolean default '0', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, `lft` integer not null, `rgt` integer not null, foreign key(`parentAccount`) references `Account`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   rootType TEXT NOT NULL
#   parentAccount TEXT NULL
#   accountType TEXT NULL
#   isGroup boolean NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   lft INTEGER NOT NULL
#   rgt INTEGER NOT NULL
# FOREIGN KEYS:
#   parentAccount -> Account.name
# INDEXES:
#   sqlite_autoindex_Account_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'Application of Funds (Assets)', 'rootType': 'Asset', 'parentAccount': None, 'accountType': '', 'isGroup': 1, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:27.185Z', 'modified': '2025-08-05T15:57:27.185Z', 'lft': 0, 'rgt': 0}
#   {'name': 'Current Assets', 'rootType': 'Asset', 'parentAccount': 'Application of Funds (Assets)', 'accountType': '', 'isGroup': 1, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:27.191Z', 'modified': '2025-08-05T15:57:27.191Z', 'lft': 0, 'rgt': 0}
#   {'name': 'Accounts Receivable', 'rootType': 'Asset', 'parentAccount': 'Current Assets', 'accountType': '', 'isGroup': 1, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:27.196Z', 'modified': '2025-08-05T15:57:27.196Z', 'lft': 0, 'rgt': 0}
#
# -- Table: AccountingLedgerEntry
# CREATE: CREATE TABLE `AccountingLedgerEntry` (`name` text not null, `date` datetime, `party` text, `account` text not null, `debit` text, `credit` text, `referenceType` text, `referenceName` text, `reverted` boolean default '0', `reverts` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`party`) references `Party`(`name`) on delete RESTRICT on update CASCADE, foreign key(`account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, foreign key(`reverts`) references `AccountingLedgerEntry`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   date datetime NULL
#   party TEXT NULL
#   account TEXT NOT NULL
#   debit TEXT NULL
#   credit TEXT NULL
#   referenceType TEXT NULL
#   referenceName TEXT NULL
#   reverted boolean NULL
#   reverts TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   reverts -> AccountingLedgerEntry.name
#   account -> Account.name
#   party -> Party.name
# INDEXES:
#   sqlite_autoindex_AccountingLedgerEntry_1: name UNIQUE
# SAMPLE DATA:
#   {'name': '000000001', 'date': '2025-02-05T00:00:00.000Z', 'party': None, 'account': 'Supreme Bank', 'debit': '5055069.00000000000', 'credit': '0.00000000000', 'referenceType': 'JournalEntry', 'referenceName': 'JV-1001', 'reverted': 0, 'reverts': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:39.909Z', 'modified': '2025-08-05T15:57:39.909Z'}
#   {'name': '000000002', 'date': '2025-02-05T00:00:00.000Z', 'party': None, 'account': 'Secured Loans', 'debit': '0.00000000000', 'credit': '5055069.00000000000', 'referenceType': 'JournalEntry', 'referenceName': 'JV-1001', 'reverted': 0, 'reverts': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:39.913Z', 'modified': '2025-08-05T15:57:39.913Z'}
#   {'name': '000000003', 'date': '2025-02-05T00:00:00.000Z', 'party': None, 'account': 'Cash', 'debit': '1516520.70000000000', 'credit': '0.00000000000', 'referenceType': 'JournalEntry', 'referenceName': 'JV-1002', 'reverted': 0, 'reverts': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:39.939Z', 'modified': '2025-08-05T15:57:39.939Z'}
#
# -- Table: Address
# CREATE: CREATE TABLE `Address` (`name` text not null, `addressLine1` text not null, `addressLine2` text, `city` text not null, `country` text not null, `state` text, `postalCode` text, `emailAddress` text, `phone` text, `fax` text, `addressDisplay` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, `pos` text, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   addressLine1 TEXT NOT NULL
#   addressLine2 TEXT NULL
#   city TEXT NOT NULL
#   country TEXT NOT NULL
#   state TEXT NULL
#   postalCode TEXT NULL
#   emailAddress TEXT NULL
#   phone TEXT NULL
#   fax TEXT NULL
#   addressDisplay TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   pos TEXT NULL
# INDEXES:
#   sqlite_autoindex_Address_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'New Address 01', 'addressLine1': '1st Column, Fitzgerald Bridge', 'addressLine2': None, 'city': 'Pune', 'country': 'India', 'state': 'Maharashtra', 'postalCode': '411001', 'emailAddress': None, 'phone': None, 'fax': None, 'addressDisplay': '1st Column, Fitzgerald Bridge, Pune, Maharashtra, India, 411001', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:58:54.271Z', 'modified': '2025-08-05T15:58:54.271Z', 'pos': 'Maharashtra'}
#
# -- Table: AppliedCouponCodes
# CREATE: CREATE TABLE `AppliedCouponCodes` (`name` text not null, `coupons` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`coupons`) references `CouponCode`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   coupons TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   coupons -> CouponCode.name
# INDEXES:
#   sqlite_autoindex_AppliedCouponCodes_1: name UNIQUE
#
# -- Table: Batch
# CREATE: CREATE TABLE `Batch` (`name` text not null, `item` text, `expiryDate` date, `manufactureDate` date, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NULL
#   expiryDate date NULL
#   manufactureDate date NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_Batch_1: name UNIQUE
#
# -- Table: ClosingAmounts
# CREATE: CREATE TABLE `ClosingAmounts` (`name` text not null, `paymentMethod` text not null, `openingAmount` text, `closingAmount` text, `expectedAmount` text, `differenceAmount` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   paymentMethod TEXT NOT NULL
#   openingAmount TEXT NULL
#   closingAmount TEXT NULL
#   expectedAmount TEXT NULL
#   differenceAmount TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_ClosingAmounts_1: name UNIQUE
#
# -- Table: ClosingCash
# CREATE: CREATE TABLE `ClosingCash` (`name` text not null, `denomination` text not null, `count` integer not null default '0', `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   denomination TEXT NOT NULL
#   count INTEGER NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_ClosingCash_1: name UNIQUE
#
# -- Table: CollectionRulesItems
# CREATE: CREATE TABLE `CollectionRulesItems` (`name` text not null, `tierName` text, `collectionFactor` float, `minimumTotalSpent` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   tierName TEXT NULL
#   collectionFactor float NULL
#   minimumTotalSpent TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_CollectionRulesItems_1: name UNIQUE
#
# -- Table: Color
# CREATE: CREATE TABLE `Color` (`name` text not null, `hexvalue` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   hexvalue TEXT NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_Color_1: name UNIQUE
#
# -- Table: CouponCode
# CREATE: CREATE TABLE `CouponCode` (`name` text not null, `couponName` text not null, `isEnabled` boolean not null default '1', `pricingRule` text not null, `minAmount` text, `maxAmount` text, `validFrom` date not null, `validTo` date not null, `maximumUse` integer not null default '0', `used` integer not null default '0', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`pricingRule`) references `PricingRule`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   couponName TEXT NOT NULL
#   isEnabled boolean NOT NULL
#   pricingRule TEXT NOT NULL
#   minAmount TEXT NULL
#   maxAmount TEXT NULL
#   validFrom date NOT NULL
#   validTo date NOT NULL
#   maximumUse INTEGER NOT NULL
#   used INTEGER NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   pricingRule -> PricingRule.name
# INDEXES:
#   sqlite_autoindex_CouponCode_1: name UNIQUE
#
# -- Table: Currency
# CREATE: CREATE TABLE `Currency` (`name` text not null, `fraction` text, `fractionUnits` integer, `smallestValue` text, `symbol` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   fraction TEXT NULL
#   fractionUnits INTEGER NULL
#   smallestValue TEXT NULL
#   symbol TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_Currency_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'AFN', 'fraction': 'Pul', 'fractionUnits': 100, 'smallestValue': '0.01000000000', 'symbol': '؋', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:26.609Z', 'modified': '2025-08-05T15:57:26.609Z'}
#   {'name': 'ALL', 'fraction': 'Qindarkë', 'fractionUnits': 100, 'smallestValue': '0.01000000000', 'symbol': 'L', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:26.610Z', 'modified': '2025-08-05T15:57:26.610Z'}
#   {'name': 'DZD', 'fraction': 'Santeem', 'fractionUnits': 100, 'smallestValue': '0.01000000000', 'symbol': 'د.ج', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:26.611Z', 'modified': '2025-08-05T15:57:26.611Z'}
#
# -- Table: CustomField
# CREATE: CREATE TABLE `CustomField` (`name` text not null, `label` text not null, `fieldname` text not null, `fieldtype` text not null default 'Data', `isRequired` boolean default '0', `default` text, `section` text default 'Default', `tab` text default 'Custom', `options` text, `target` text, `references` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   label TEXT NOT NULL
#   fieldname TEXT NOT NULL
#   fieldtype TEXT NOT NULL
#   isRequired boolean NULL
#   default TEXT NULL
#   section TEXT NULL
#   tab TEXT NULL
#   options TEXT NULL
#   target TEXT NULL
#   references TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_CustomField_1: name UNIQUE
#
# -- Table: CustomForm
# CREATE: CREATE TABLE `CustomForm` (`name` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_CustomForm_1: name UNIQUE
#
# -- Table: DefaultCashDenominations
# CREATE: CREATE TABLE `DefaultCashDenominations` (`name` text not null, `denomination` text not null, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   denomination TEXT NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_DefaultCashDenominations_1: name UNIQUE
#
# -- Table: ERPNextSyncQueue
# CREATE: CREATE TABLE `ERPNextSyncQueue` (`name` text not null, `referenceType` text not null, `documentName` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   referenceType TEXT NOT NULL
#   documentName TEXT NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_ERPNextSyncQueue_1: name UNIQUE
#
# -- Table: FetchFromERPNextQueue
# CREATE: CREATE TABLE `FetchFromERPNextQueue` (`name` text not null, `referenceType` text not null, `documentName` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   referenceType TEXT NOT NULL
#   documentName TEXT NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_FetchFromERPNextQueue_1: name UNIQUE
#
# -- Table: IntegrationErrorLog
# CREATE: CREATE TABLE `IntegrationErrorLog` (`name` text not null, `data` text, `error` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   data TEXT NULL
#   error TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_IntegrationErrorLog_1: name UNIQUE
#
# -- Table: Item
# CREATE: CREATE TABLE "Item" (`image` text, `name` text NOT NULL, `itemCode` text, `itemGroup` text, `for` text NOT NULL DEFAULT 'Both', `itemType` text DEFAULT 'Product', `unit` text DEFAULT 'Unit', `rate` text, `description` text, `incomeAccount` text NOT NULL, `expenseAccount` text NOT NULL, `tax` text, `hsnCode` text, `barcode` text, `trackItem` boolean DEFAULT '0', `hasBatch` boolean DEFAULT '0', `hasSerialNumber` boolean DEFAULT '0', `createdBy` text NOT NULL, `modifiedBy` text NOT NULL, `created` datetime NOT NULL, `modified` datetime NOT NULL, FOREIGN KEY (`itemGroup`) REFERENCES `ItemGroup` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`unit`) REFERENCES `UOM` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`incomeAccount`) REFERENCES `Account` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`expenseAccount`) REFERENCES `Account` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`tax`) REFERENCES `Tax` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, PRIMARY KEY (`name`))
# COLUMNS:
#   image TEXT NULL
#   name TEXT NOT NULL PK
#   itemCode TEXT NULL
#   itemGroup TEXT NULL
#   for TEXT NOT NULL
#   itemType TEXT NULL
#   unit TEXT NULL
#   rate TEXT NULL
#   description TEXT NULL
#   incomeAccount TEXT NOT NULL
#   expenseAccount TEXT NOT NULL
#   tax TEXT NULL
#   hsnCode TEXT NULL
#   barcode TEXT NULL
#   trackItem boolean NULL
#   hasBatch boolean NULL
#   hasSerialNumber boolean NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   tax -> Tax.name
#   expenseAccount -> Account.name
#   incomeAccount -> Account.name
#   unit -> UOM.name
#   itemGroup -> ItemGroup.name
# INDEXES:
#   sqlite_autoindex_Item_1: name UNIQUE
# SAMPLE DATA:
#   {'image': None, 'name': 'Dry-Cleaning', 'itemCode': None, 'itemGroup': None, 'for': 'Sales', 'itemType': 'Service', 'unit': 'Unit', 'rate': '69.00000000000', 'description': None, 'incomeAccount': 'Service', 'expenseAccount': 'Cost of Goods Sold', 'tax': 'GST-18', 'hsnCode': '999712', 'barcode': None, 'trackItem': 0, 'hasBatch': 0, 'hasSerialNumber': 0, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.667Z', 'modified': '2025-08-05T15:57:28.667Z'}
#   {'image': None, 'name': 'Electricity', 'itemCode': None, 'itemGroup': None, 'for': 'Purchases', 'itemType': 'Service', 'unit': 'Day', 'rate': '6000.00000000000', 'description': 'Bzz Bzz', 'incomeAccount': 'Service', 'expenseAccount': 'Utility Expenses', 'tax': 'GST-0', 'hsnCode': '271600', 'barcode': None, 'trackItem': 0, 'hasBatch': 0, 'hasSerialNumber': 0, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.673Z', 'modified': '2025-08-05T15:57:28.673Z'}
#   {'image': None, 'name': 'Marketing - Video', 'itemCode': None, 'itemGroup': None, 'for': 'Purchases', 'itemType': 'Product', 'unit': 'Unit', 'rate': '15000.00000000000', 'description': 'One single video', 'incomeAccount': 'Sales', 'expenseAccount': 'Marketing Expenses', 'tax': 'GST-18', 'hsnCode': '998371', 'barcode': None, 'trackItem': 0, 'hasBatch': 0, 'hasSerialNumber': 0, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.680Z', 'modified': '2025-08-05T15:57:28.680Z'}
#
# -- Table: ItemEnquiry
# CREATE: CREATE TABLE `ItemEnquiry` (`name` text not null, `item` text not null, `customer` text, `contact` text, `description` text, `similarProduct` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   customer TEXT NULL
#   contact TEXT NULL
#   description TEXT NULL
#   similarProduct TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_ItemEnquiry_1: name UNIQUE
#
# -- Table: ItemGroup
# CREATE: CREATE TABLE `ItemGroup` (`name` text not null, `tax` text, `hsnCode` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`tax`) references `Tax`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   tax TEXT NULL
#   hsnCode TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   tax -> Tax.name
# INDEXES:
#   sqlite_autoindex_ItemGroup_1: name UNIQUE
#
# -- Table: JournalEntry
# CREATE: CREATE TABLE `JournalEntry` (`name` text not null, `numberSeries` text not null default 'JV-', `entryType` text not null, `date` date not null, `referenceNumber` text, `referenceDate` date, `userRemark` text, `attachment` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, `submitted` boolean not null, `cancelled` boolean not null, foreign key(`numberSeries`) references `NumberSeries`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   numberSeries TEXT NOT NULL
#   entryType TEXT NOT NULL
#   date date NOT NULL
#   referenceNumber TEXT NULL
#   referenceDate date NULL
#   userRemark TEXT NULL
#   attachment TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   submitted boolean NOT NULL
#   cancelled boolean NOT NULL
# FOREIGN KEYS:
#   numberSeries -> NumberSeries.name
# INDEXES:
#   sqlite_autoindex_JournalEntry_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'JV-1001', 'numberSeries': 'JV-', 'entryType': 'Bank Entry', 'date': '2025-02-05', 'referenceNumber': None, 'referenceDate': None, 'userRemark': None, 'attachment': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:39.859Z', 'modified': '2025-08-05T15:57:39.903Z', 'submitted': 1, 'cancelled': 0}
#   {'name': 'JV-1002', 'numberSeries': 'JV-', 'entryType': 'Cash Entry', 'date': '2025-02-05', 'referenceNumber': None, 'referenceDate': None, 'userRemark': None, 'attachment': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:39.917Z', 'modified': '2025-08-05T15:57:39.933Z', 'submitted': 1, 'cancelled': 0}
#
# -- Table: JournalEntryAccount
# CREATE: CREATE TABLE `JournalEntryAccount` (`name` text not null, `account` text not null, `debit` text, `credit` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   account TEXT NOT NULL
#   debit TEXT NULL
#   credit TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   account -> Account.name
# INDEXES:
#   sqlite_autoindex_JournalEntryAccount_1: name UNIQUE
# SAMPLE DATA:
#   {'name': '9sm5iq-mdyq3ez4', 'account': 'Supreme Bank', 'debit': '5055069.00000000000', 'credit': '0.00000000000', 'idx': 0, 'parent': 'JV-1001', 'parentSchemaName': 'JournalEntry', 'parentFieldname': 'accounts'}
#   {'name': 'io3iow-mdyq3ez5', 'account': 'Secured Loans', 'debit': '0.00000000000', 'credit': '5055069.00000000000', 'idx': 1, 'parent': 'JV-1001', 'parentSchemaName': 'JournalEntry', 'parentFieldname': 'accounts'}
#   {'name': 'imvvi8-mdyq3ez6', 'account': 'Cash', 'debit': '1516520.70000000000', 'credit': '0.00000000000', 'idx': 0, 'parent': 'JV-1002', 'parentSchemaName': 'JournalEntry', 'parentFieldname': 'accounts'}
#
# -- Table: Lead
# CREATE: CREATE TABLE `Lead` (`name` text not null, `status` text not null default 'Open', `email` text, `mobile` text, `address` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`address`) references `Address`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   status TEXT NOT NULL
#   email TEXT NULL
#   mobile TEXT NULL
#   address TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   address -> Address.name
# INDEXES:
#   sqlite_autoindex_Lead_1: name UNIQUE
#
# -- Table: Location
# CREATE: CREATE TABLE `Location` (`name` text not null, `address` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`address`) references `Address`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   address TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   address -> Address.name
# INDEXES:
#   sqlite_autoindex_Location_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'Stores', 'address': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.030Z', 'modified': '2025-08-05T15:57:28.030Z'}
#
# -- Table: LoyaltyPointEntry
# CREATE: CREATE TABLE `LoyaltyPointEntry` (`name` text not null, `loyaltyProgram` text not null, `loyaltyProgramTier` text, `customer` text not null, `invoice` text not null, `loyaltyPoints` integer, `purchaseAmount` text not null, `expiryDate` date, `postingDate` date, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`customer`) references `Party`(`name`) on delete RESTRICT on update CASCADE, foreign key(`invoice`) references `SalesInvoice`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   loyaltyProgram TEXT NOT NULL
#   loyaltyProgramTier TEXT NULL
#   customer TEXT NOT NULL
#   invoice TEXT NOT NULL
#   loyaltyPoints INTEGER NULL
#   purchaseAmount TEXT NOT NULL
#   expiryDate date NULL
#   postingDate date NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   invoice -> SalesInvoice.name
#   customer -> Party.name
# INDEXES:
#   sqlite_autoindex_LoyaltyPointEntry_1: name UNIQUE
#
# -- Table: LoyaltyProgram
# CREATE: CREATE TABLE `LoyaltyProgram` (`name` text not null, `fromDate` date not null, `toDate` date not null, `isEnabled` boolean not null default '1', `conversionFactor` float not null default '1', `expiryDuration` integer not null default '1', `expenseAccount` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`expenseAccount`) references `Account`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   fromDate date NOT NULL
#   toDate date NOT NULL
#   isEnabled boolean NOT NULL
#   conversionFactor float NOT NULL
#   expiryDuration INTEGER NOT NULL
#   expenseAccount TEXT NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   expenseAccount -> Account.name
# INDEXES:
#   sqlite_autoindex_LoyaltyProgram_1: name UNIQUE
#
# -- Table: NumberSeries
# CREATE: CREATE TABLE `NumberSeries` (`name` text not null, `start` integer not null default '1001', `padZeros` integer not null default '4', `referenceType` text not null default '-', `current` integer not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   start INTEGER NOT NULL
#   padZeros INTEGER NOT NULL
#   referenceType TEXT NOT NULL
#   current INTEGER NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_NumberSeries_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'PAY-', 'start': 1001, 'padZeros': 4, 'referenceType': 'Payment', 'current': 1378, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.035Z', 'modified': '2025-08-05T15:58:54.175Z'}
#   {'name': 'JV-', 'start': 1001, 'padZeros': 4, 'referenceType': 'JournalEntry', 'current': 1002, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.074Z', 'modified': '2025-08-05T15:57:39.919Z'}
#   {'name': 'PRLE-', 'start': 1001, 'padZeros': 4, 'referenceType': 'PricingRule', 'current': 0, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.112Z', 'modified': '2025-08-05T15:57:28.112Z'}
#
# -- Table: OpeningAmounts
# CREATE: CREATE TABLE `OpeningAmounts` (`name` text not null, `paymentMethod` text not null, `amount` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   paymentMethod TEXT NOT NULL
#   amount TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_OpeningAmounts_1: name UNIQUE
#
# -- Table: OpeningCash
# CREATE: CREATE TABLE `OpeningCash` (`name` text not null, `denomination` text not null, `count` integer not null default '0', `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   denomination TEXT NOT NULL
#   count INTEGER NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_OpeningCash_1: name UNIQUE
#
# -- Table: POSClosingShift
# CREATE: CREATE TABLE `POSClosingShift` (`name` text not null, `closingDate` datetime, `openingShift` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`openingShift`) references `POSOpeningShift`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   closingDate datetime NULL
#   openingShift TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   openingShift -> POSOpeningShift.name
# INDEXES:
#   sqlite_autoindex_POSClosingShift_1: name UNIQUE
#
# -- Table: POSOpeningShift
# CREATE: CREATE TABLE `POSOpeningShift` (`name` text not null, `openingDate` datetime, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   openingDate datetime NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_POSOpeningShift_1: name UNIQUE
#
# -- Table: POSProfile
# CREATE: CREATE TABLE `POSProfile` (`name` text, `posCustomer` text, `inventory` text not null, `posPrintTemplate` text, `posUI` text not null default 'Classic', `isShiftOpen` boolean default '0', `itemVisibility` text not null default 'Inventory Items', `canChangeRate` boolean default '0', `hideUnavailableItems` boolean default '0', `canEditDiscount` boolean default '0', `ignorePricingRule` boolean default '0', `saveButtonColour` text default '#9575cd', `cancelButtonColour` text default '#e86674', `submitButtonColour` text default '#00bcd4', `heldButtonColour` text default '#ff9800', `returnButtonColour` text default '#00bcd4', `buyButtonColour` text default '#66bb6a', `payButtonColour` text default '#66bb6a', `payAndPrintButtonColour` text default '#ff9800', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`posCustomer`) references `Party`(`name`) on delete RESTRICT on update CASCADE, foreign key(`inventory`) references `Location`(`name`) on delete RESTRICT on update CASCADE, foreign key(`posPrintTemplate`) references `PrintTemplate`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NULL PK
#   posCustomer TEXT NULL
#   inventory TEXT NOT NULL
#   posPrintTemplate TEXT NULL
#   posUI TEXT NOT NULL
#   isShiftOpen boolean NULL
#   itemVisibility TEXT NOT NULL
#   canChangeRate boolean NULL
#   hideUnavailableItems boolean NULL
#   canEditDiscount boolean NULL
#   ignorePricingRule boolean NULL
#   saveButtonColour TEXT NULL
#   cancelButtonColour TEXT NULL
#   submitButtonColour TEXT NULL
#   heldButtonColour TEXT NULL
#   returnButtonColour TEXT NULL
#   buyButtonColour TEXT NULL
#   payButtonColour TEXT NULL
#   payAndPrintButtonColour TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   posPrintTemplate -> PrintTemplate.name
#   inventory -> Location.name
#   posCustomer -> Party.name
# INDEXES:
#   sqlite_autoindex_POSProfile_1: name UNIQUE
#
# -- Table: Party
# CREATE: CREATE TABLE "Party" (`image` text, `name` text NOT NULL, `role` text NOT NULL DEFAULT 'Both', `email` text, `phone` text, `address` text, `defaultAccount` text, `currency` text, `fromLead` text, `loyaltyProgram` text, `loyaltyPoints` integer DEFAULT '0', `outstandingAmount` text, `createdBy` text NOT NULL, `modifiedBy` text NOT NULL, `created` datetime NOT NULL, `modified` datetime NOT NULL, `gstType` text DEFAULT 'Unregistered', `gstin` text, FOREIGN KEY (`address`) REFERENCES `Address` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`defaultAccount`) REFERENCES `Account` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`currency`) REFERENCES `Currency` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`fromLead`) REFERENCES `Lead` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, FOREIGN KEY (`loyaltyProgram`) REFERENCES `LoyaltyProgram` (`name`) ON DELETE RESTRICT ON UPDATE CASCADE, PRIMARY KEY (`name`))
# COLUMNS:
#   image TEXT NULL
#   name TEXT NOT NULL PK
#   role TEXT NOT NULL
#   email TEXT NULL
#   phone TEXT NULL
#   address TEXT NULL
#   defaultAccount TEXT NULL
#   currency TEXT NULL
#   fromLead TEXT NULL
#   loyaltyProgram TEXT NULL
#   loyaltyPoints INTEGER NULL
#   outstandingAmount TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   gstType TEXT NULL
#   gstin TEXT NULL
# FOREIGN KEYS:
#   loyaltyProgram -> LoyaltyProgram.name
#   fromLead -> Lead.name
#   currency -> Currency.name
#   defaultAccount -> Account.name
#   address -> Address.name
# INDEXES:
#   sqlite_autoindex_Party_1: name UNIQUE
# SAMPLE DATA:
#   {'image': None, 'name': 'Roy Rolston', 'role': 'Customer', 'email': 'roy-rolston@partiesunited.co', 'phone': '+91 8364-764417', 'address': None, 'defaultAccount': 'Debtors', 'currency': 'INR', 'fromLead': None, 'loyaltyProgram': None, 'loyaltyPoints': 0, 'outstandingAmount': '0.00000000000', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.754Z', 'modified': '2025-08-05T15:57:28.754Z', 'gstType': 'Registered Regular', 'gstin': '27YQPCH7868M1Z4'}
#   {'image': None, 'name': 'Aloysius Albuquerque', 'role': 'Customer', 'email': 'aloysius.albuquerque-418@gmail.com', 'phone': '+91 9624-847744', 'address': None, 'defaultAccount': 'Debtors', 'currency': 'INR', 'fromLead': None, 'loyaltyProgram': None, 'loyaltyPoints': 0, 'outstandingAmount': '0.00000000000', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.759Z', 'modified': '2025-08-05T15:57:28.759Z', 'gstType': 'Consumer', 'gstin': None}
#   {'image': None, 'name': 'James', 'role': 'Customer', 'email': None, 'phone': None, 'address': None, 'defaultAccount': 'Debtors', 'currency': 'INR', 'fromLead': None, 'loyaltyProgram': None, 'loyaltyPoints': 0, 'outstandingAmount': '0.00000000000', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:28.764Z', 'modified': '2025-08-05T15:58:25.586Z', 'gstType': 'Consumer', 'gstin': None}
#
# -- Table: PatchRun
# CREATE: CREATE TABLE `PatchRun` (`name` text not null, `failed` boolean default '0', `version` text default '0.0.0', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   failed boolean NULL
#   version TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_PatchRun_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'updateSchemas', 'failed': 0, 'version': '0.0.0', 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.145Z', 'modified': '2025-08-05T15:57:26.145Z'}
#   {'name': 'testPatch', 'failed': 0, 'version': '0.0.0', 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.150Z', 'modified': '2025-08-05T15:57:26.150Z'}
#   {'name': 'fixRoundOffAccount', 'failed': 0, 'version': '0.0.0', 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.157Z', 'modified': '2025-08-05T15:57:26.157Z'}
#
# -- Table: Payment
# CREATE: CREATE TABLE `Payment` (`name` text not null, `numberSeries` text not null default 'PAY-', `party` text not null, `date` datetime not null, `paymentType` text not null, `account` text not null, `paymentAccount` text not null, `paymentMethod` text not null default 'Cash', `clearanceDate` date, `referenceId` text, `referenceDate` date, `amount` text not null, `writeoff` text, `attachment` text, `referenceType` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, `submitted` boolean not null, `cancelled` boolean not null, foreign key(`numberSeries`) references `NumberSeries`(`name`) on delete RESTRICT on update CASCADE, foreign key(`party`) references `Party`(`name`) on delete RESTRICT on update CASCADE, foreign key(`account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, foreign key(`paymentAccount`) references `Account`(`name`) on delete RESTRICT on update CASCADE, foreign key(`paymentMethod`) references `PaymentMethod`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   numberSeries TEXT NOT NULL
#   party TEXT NOT NULL
#   date datetime NOT NULL
#   paymentType TEXT NOT NULL
#   account TEXT NOT NULL
#   paymentAccount TEXT NOT NULL
#   paymentMethod TEXT NOT NULL
#   clearanceDate date NULL
#   referenceId TEXT NULL
#   referenceDate date NULL
#   amount TEXT NOT NULL
#   writeoff TEXT NULL
#   attachment TEXT NULL
#   referenceType TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   submitted boolean NOT NULL
#   cancelled boolean NOT NULL
# FOREIGN KEYS:
#   paymentMethod -> PaymentMethod.name
#   paymentAccount -> Account.name
#   account -> Account.name
#   party -> Party.name
#   numberSeries -> NumberSeries.name
# INDEXES:
#   sqlite_autoindex_Payment_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'PAY-1001', 'numberSeries': 'PAY-', 'party': 'Only Fulls', 'date': '2024-09-01T01:00:00.000Z', 'paymentType': 'Pay', 'account': 'Cash', 'paymentAccount': 'Creditors', 'paymentMethod': 'Cash', 'clearanceDate': None, 'referenceId': None, 'referenceDate': None, 'amount': '17886.40000000000', 'writeoff': '0.00000000000', 'attachment': None, 'referenceType': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:58:19.210Z', 'modified': '2025-08-05T15:58:19.247Z', 'submitted': 1, 'cancelled': 0}
#   {'name': 'PAY-1002', 'numberSeries': 'PAY-', 'party': 'Just Epaulettes', 'date': '2024-09-01T01:00:00.000Z', 'paymentType': 'Pay', 'account': 'Cash', 'paymentAccount': 'Creditors', 'paymentMethod': 'Cash', 'clearanceDate': None, 'referenceId': None, 'referenceDate': None, 'amount': '29488.20000000000', 'writeoff': '0.00000000000', 'attachment': None, 'referenceType': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:58:19.301Z', 'modified': '2025-08-05T15:58:19.323Z', 'submitted': 1, 'cancelled': 0}
#   {'name': 'PAY-1003', 'numberSeries': 'PAY-', 'party': 'Lankness Feet Fomenters', 'date': '2024-09-01T01:00:00.000Z', 'paymentType': 'Pay', 'account': 'Cash', 'paymentAccount': 'Creditors', 'paymentMethod': 'Cash', 'clearanceDate': None, 'referenceId': None, 'referenceDate': None, 'amount': '153364.60000000000', 'writeoff': '0.00000000000', 'attachment': None, 'referenceType': None, 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:58:19.375Z', 'modified': '2025-08-05T15:58:19.396Z', 'submitted': 1, 'cancelled': 0}
#
# -- Table: PaymentFor
# CREATE: CREATE TABLE `PaymentFor` (`name` text not null, `referenceType` text not null, `referenceName` text not null, `amount` text not null, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   referenceType TEXT NOT NULL
#   referenceName TEXT NOT NULL
#   amount TEXT NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# INDEXES:
#   sqlite_autoindex_PaymentFor_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'w1eqbi-mdyq49ak', 'referenceType': 'PurchaseInvoice', 'referenceName': 'PINV-1001', 'amount': '17886.40000000000', 'idx': 0, 'parent': 'PAY-1001', 'parentSchemaName': 'Payment', 'parentFieldname': 'for'}
#   {'name': 'm5o0nf-mdyq49ak', 'referenceType': 'PurchaseInvoice', 'referenceName': 'PINV-1002', 'amount': '29488.20000000000', 'idx': 0, 'parent': 'PAY-1002', 'parentSchemaName': 'Payment', 'parentFieldname': 'for'}
#   {'name': 'vs0jd3-mdyq49al', 'referenceType': 'PurchaseInvoice', 'referenceName': 'PINV-1003', 'amount': '153364.60000000000', 'idx': 0, 'parent': 'PAY-1003', 'parentSchemaName': 'Payment', 'parentFieldname': 'for'}
#
# -- Table: PaymentMethod
# CREATE: CREATE TABLE `PaymentMethod` (`name` text, `type` text not null, `account` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NULL PK
#   type TEXT NOT NULL
#   account TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   account -> Account.name
# INDEXES:
#   sqlite_autoindex_PaymentMethod_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'Cash', 'type': 'Cash', 'account': None, 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.279Z', 'modified': '2025-08-05T15:57:26.279Z'}
#   {'name': 'Bank', 'type': 'Bank', 'account': None, 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.279Z', 'modified': '2025-08-05T15:57:26.279Z'}
#   {'name': 'Transfer', 'type': 'Bank', 'account': None, 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.279Z', 'modified': '2025-08-05T15:57:26.279Z'}
#
# -- Table: PriceList
# CREATE: CREATE TABLE `PriceList` (`name` text not null, `isEnabled` boolean default '1', `isSales` boolean default '1', `isPurchase` boolean default '0', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   isEnabled boolean NULL
#   isSales boolean NULL
#   isPurchase boolean NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_PriceList_1: name UNIQUE
#
# -- Table: PriceListItem
# CREATE: CREATE TABLE `PriceListItem` (`name` text not null, `item` text not null, `unit` text, `rate` text not null, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, foreign key(`unit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   unit TEXT NULL
#   rate TEXT NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   unit -> UOM.name
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_PriceListItem_1: name UNIQUE
#
# -- Table: PricingRule
# CREATE: CREATE TABLE `PricingRule` (`name` text not null, `numberSeries` text not null default 'PRLE-', `isEnabled` boolean default '1', `title` text not null, `discountType` text not null, `isCouponCodeBased` boolean default '0', `priority` text not null, `priceDiscountType` text, `discountRate` text, `discountPercentage` float, `discountAmount` text, `freeItem` text, `freeItemQuantity` float, `freeItemUnit` text, `freeItemRate` text, `roundFreeItemQty` boolean default '0', `roundingMethod` text not null default 'round', `isRecursive` boolean default '0', `recurseEvery` float, `minQuantity` float, `maxQuantity` float, `minAmount` text, `maxAmount` text, `validFrom` date, `validTo` date, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`numberSeries`) references `NumberSeries`(`name`) on delete RESTRICT on update CASCADE, foreign key(`freeItem`) references `Item`(`name`) on delete RESTRICT on update CASCADE, foreign key(`freeItemUnit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   numberSeries TEXT NOT NULL
#   isEnabled boolean NULL
#   title TEXT NOT NULL
#   discountType TEXT NOT NULL
#   isCouponCodeBased boolean NULL
#   priority TEXT NOT NULL
#   priceDiscountType TEXT NULL
#   discountRate TEXT NULL
#   discountPercentage float NULL
#   discountAmount TEXT NULL
#   freeItem TEXT NULL
#   freeItemQuantity float NULL
#   freeItemUnit TEXT NULL
#   freeItemRate TEXT NULL
#   roundFreeItemQty boolean NULL
#   roundingMethod TEXT NOT NULL
#   isRecursive boolean NULL
#   recurseEvery float NULL
#   minQuantity float NULL
#   maxQuantity float NULL
#   minAmount TEXT NULL
#   maxAmount TEXT NULL
#   validFrom date NULL
#   validTo date NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   freeItemUnit -> UOM.name
#   freeItem -> Item.name
#   numberSeries -> NumberSeries.name
# INDEXES:
#   sqlite_autoindex_PricingRule_1: name UNIQUE
#
# -- Table: PricingRuleDetail
# CREATE: CREATE TABLE `PricingRuleDetail` (`name` text not null, `referenceName` text, `referenceItem` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`referenceName`) references `PricingRule`(`name`) on delete RESTRICT on update CASCADE, foreign key(`referenceItem`) references `Item`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   referenceName TEXT NULL
#   referenceItem TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   referenceItem -> Item.name
#   referenceName -> PricingRule.name
# INDEXES:
#   sqlite_autoindex_PricingRuleDetail_1: name UNIQUE
#
# -- Table: PricingRuleItem
# CREATE: CREATE TABLE `PricingRuleItem` (`name` text not null, `item` text not null, `unit` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, foreign key(`unit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   unit TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   unit -> UOM.name
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_PricingRuleItem_1: name UNIQUE
#
# -- Table: PrintTemplate
# CREATE: CREATE TABLE `PrintTemplate` (`name` text not null, `type` text not null default 'SalesInvoice', `template` text not null, `height` float default '29.7', `width` float default '21', `isCustom` boolean default '1', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   type TEXT NOT NULL
#   template TEXT NOT NULL
#   height float NULL
#   width float NULL
#   isCustom boolean NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_PrintTemplate_1: name UNIQUE
# SAMPLE DATA:
# ...
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   itemCode TEXT NULL
#   description TEXT NULL
#   rate TEXT NOT NULL
#   transferUnit TEXT NULL
#   transferQuantity float NOT NULL
#   unit TEXT NULL
#   batch TEXT NULL
#   quantity float NOT NULL
#   unitConversionFactor float NOT NULL
#   account TEXT NOT NULL
#   tax TEXT NULL
#   amount TEXT NULL
#   setItemDiscountAmount boolean NULL
#   itemDiscountAmount TEXT NULL
#   itemDiscountPercent float NULL
#   hsnCode INTEGER NULL
#   stockNotTransferred float NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   tax -> Tax.name
#   account -> Account.name
#   batch -> Batch.name
#   unit -> UOM.name
#   transferUnit -> UOM.name
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_SalesQuoteItem_1: name UNIQUE
#
# -- Table: SerialNumber
# CREATE: CREATE TABLE `SerialNumber` (`name` text not null, `item` text not null, `description` text, `status` text default 'Inactive', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   description TEXT NULL
#   status TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_SerialNumber_1: name UNIQUE
#
# -- Table: Shipment
# CREATE: CREATE TABLE `Shipment` (`name` text not null, `numberSeries` text not null default 'SHPM-', `party` text not null, `date` datetime not null, `grandTotal` text, `terms` text, `attachment` text, `isReturned` boolean default '0', `backReference` text, `returnAgainst` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, `submitted` boolean not null, `cancelled` boolean not null, foreign key(`numberSeries`) references `NumberSeries`(`name`) on delete RESTRICT on update CASCADE, foreign key(`party`) references `Party`(`name`) on delete RESTRICT on update CASCADE, foreign key(`backReference`) references `SalesInvoice`(`name`) on delete RESTRICT on update CASCADE, foreign key(`returnAgainst`) references `Shipment`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   numberSeries TEXT NOT NULL
#   party TEXT NOT NULL
#   date datetime NOT NULL
#   grandTotal TEXT NULL
#   terms TEXT NULL
#   attachment TEXT NULL
#   isReturned boolean NULL
#   backReference TEXT NULL
#   returnAgainst TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   submitted boolean NOT NULL
#   cancelled boolean NOT NULL
# FOREIGN KEYS:
#   returnAgainst -> Shipment.name
#   backReference -> SalesInvoice.name
#   party -> Party.name
#   numberSeries -> NumberSeries.name
# INDEXES:
#   sqlite_autoindex_Shipment_1: name UNIQUE
#
# -- Table: ShipmentItem
# CREATE: CREATE TABLE `ShipmentItem` (`name` text not null, `item` text not null, `location` text not null, `transferUnit` text default 'Unit', `transferQuantity` float not null default '1', `unit` text default 'Unit', `batch` text, `serialNumber` text, `quantity` float not null default '1', `unitConversionFactor` float not null default '1', `rate` text not null, `amount` text, `itemDiscountAmount` text, `itemDiscountPercent` float, `description` text, `hsnCode` integer, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, foreign key(`location`) references `Location`(`name`) on delete RESTRICT on update CASCADE, foreign key(`transferUnit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, foreign key(`unit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, foreign key(`batch`) references `Batch`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   location TEXT NOT NULL
#   transferUnit TEXT NULL
#   transferQuantity float NOT NULL
#   unit TEXT NULL
#   batch TEXT NULL
#   serialNumber TEXT NULL
#   quantity float NOT NULL
#   unitConversionFactor float NOT NULL
#   rate TEXT NOT NULL
#   amount TEXT NULL
#   itemDiscountAmount TEXT NULL
#   itemDiscountPercent float NULL
#   description TEXT NULL
#   hsnCode INTEGER NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   batch -> Batch.name
#   unit -> UOM.name
#   transferUnit -> UOM.name
#   location -> Location.name
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_ShipmentItem_1: name UNIQUE
#
# -- Table: SingleValue
# CREATE: CREATE TABLE `SingleValue` (`name` text not null, `parent` text not null, `fieldname` text not null, `value` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   parent TEXT NOT NULL
#   fieldname TEXT NOT NULL
#   value TEXT NOT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_SingleValue_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'ujbkdw-mdyq33bt', 'parent': 'Misc', 'fieldname': 'useFullWidth', 'value': '0.0', 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:24.761Z', 'modified': '2025-08-05T15:58:54.735Z'}
#   {'name': 'f9tavj-mdyq33bx', 'parent': 'Defaults', 'fieldname': 'saveButtonColour', 'value': '#9575cd', 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:24.765Z', 'modified': '2025-08-05T15:57:28.432Z'}
#   {'name': 'mqla3g-mdyq33c0', 'parent': 'Defaults', 'fieldname': 'cancelButtonColour', 'value': '#e86674', 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:24.768Z', 'modified': '2025-08-05T15:57:28.435Z'}
#
# -- Table: StockLedgerEntry
# CREATE: CREATE TABLE `StockLedgerEntry` (`name` text not null, `date` datetime, `location` text, `batch` text, `serialNumber` text, `item` text, `rate` text, `quantity` float, `referenceType` text, `referenceName` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, foreign key(`location`) references `Location`(`name`) on delete RESTRICT on update CASCADE, foreign key(`batch`) references `Batch`(`name`) on delete RESTRICT on update CASCADE, foreign key(`serialNumber`) references `SerialNumber`(`name`) on delete RESTRICT on update CASCADE, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   date datetime NULL
#   location TEXT NULL
#   batch TEXT NULL
#   serialNumber TEXT NULL
#   item TEXT NULL
#   rate TEXT NULL
#   quantity float NULL
#   referenceType TEXT NULL
#   referenceName TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# FOREIGN KEYS:
#   item -> Item.name
#   serialNumber -> SerialNumber.name
#   batch -> Batch.name
#   location -> Location.name
# INDEXES:
#   sqlite_autoindex_StockLedgerEntry_1: name UNIQUE
#
# -- Table: StockMovement
# CREATE: CREATE TABLE `StockMovement` (`name` text not null, `numberSeries` text not null default 'SMOV-', `movementType` text not null, `date` datetime not null, `amount` text, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, `submitted` boolean not null, `cancelled` boolean not null, foreign key(`numberSeries`) references `NumberSeries`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   numberSeries TEXT NOT NULL
#   movementType TEXT NOT NULL
#   date datetime NOT NULL
#   amount TEXT NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
#   submitted boolean NOT NULL
#   cancelled boolean NOT NULL
# FOREIGN KEYS:
#   numberSeries -> NumberSeries.name
# INDEXES:
#   sqlite_autoindex_StockMovement_1: name UNIQUE
#
# -- Table: StockMovementItem
# CREATE: CREATE TABLE `StockMovementItem` (`name` text not null, `item` text not null, `fromLocation` text, `toLocation` text, `transferUnit` text default 'Unit', `transferQuantity` float not null default '1', `unit` text default 'Unit', `batch` text, `serialNumber` text, `quantity` float not null default '1', `unitConversionFactor` float not null default '1', `rate` text not null, `amount` text, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`item`) references `Item`(`name`) on delete RESTRICT on update CASCADE, foreign key(`fromLocation`) references `Location`(`name`) on delete RESTRICT on update CASCADE, foreign key(`toLocation`) references `Location`(`name`) on delete RESTRICT on update CASCADE, foreign key(`transferUnit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, foreign key(`unit`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, foreign key(`batch`) references `Batch`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   item TEXT NOT NULL
#   fromLocation TEXT NULL
#   toLocation TEXT NULL
#   transferUnit TEXT NULL
#   transferQuantity float NOT NULL
#   unit TEXT NULL
#   batch TEXT NULL
#   serialNumber TEXT NULL
#   quantity float NOT NULL
#   unitConversionFactor float NOT NULL
#   rate TEXT NOT NULL
#   amount TEXT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   batch -> Batch.name
#   unit -> UOM.name
#   transferUnit -> UOM.name
#   toLocation -> Location.name
#   fromLocation -> Location.name
#   item -> Item.name
# INDEXES:
#   sqlite_autoindex_StockMovementItem_1: name UNIQUE
#
# -- Table: Tax
# CREATE: CREATE TABLE `Tax` (`name` text not null, `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_Tax_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'GST-28', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:27.855Z', 'modified': '2025-08-05T15:57:27.855Z'}
#   {'name': 'GST-18', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:27.867Z', 'modified': '2025-08-05T15:57:27.867Z'}
#   {'name': 'GST-12', 'createdBy': 'i771468@gmail.com', 'modifiedBy': 'i771468@gmail.com', 'created': '2025-08-05T15:57:27.878Z', 'modified': '2025-08-05T15:57:27.878Z'}
#
# -- Table: TaxDetail
# CREATE: CREATE TABLE `TaxDetail` (`name` text not null, `account` text not null, `payment_account` text, `rate` float not null, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, foreign key(`payment_account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   account TEXT NOT NULL
#   payment_account TEXT NULL
#   rate float NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   payment_account -> Account.name
#   account -> Account.name
# INDEXES:
#   sqlite_autoindex_TaxDetail_1: name UNIQUE
# SAMPLE DATA:
#   {'name': '4ac534-mdyq35pq', 'account': 'CGST', 'payment_account': None, 'rate': 14.0, 'idx': 0, 'parent': 'GST-28', 'parentSchemaName': 'Tax', 'parentFieldname': 'details'}
#   {'name': '9nzf6g-mdyq35pq', 'account': 'SGST', 'payment_account': None, 'rate': 14.0, 'idx': 1, 'parent': 'GST-28', 'parentSchemaName': 'Tax', 'parentFieldname': 'details'}
#   {'name': '76b49c-mdyq35q2', 'account': 'CGST', 'payment_account': None, 'rate': 9.0, 'idx': 0, 'parent': 'GST-18', 'parentSchemaName': 'Tax', 'parentFieldname': 'details'}
#
# -- Table: TaxSummary
# CREATE: CREATE TABLE `TaxSummary` (`name` text not null, `account` text not null, `from_account` text, `rate` float not null, `amount` text not null, `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, foreign key(`from_account`) references `Account`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   account TEXT NOT NULL
#   from_account TEXT NULL
#   rate float NOT NULL
#   amount TEXT NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   from_account -> Account.name
#   account -> Account.name
# INDEXES:
#   sqlite_autoindex_TaxSummary_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'diuvf1-mdyq3irg', 'account': 'CGST', 'from_account': None, 'rate': 9.0, 'amount': '634.32000000000', 'idx': 0, 'parent': 'SINV-1034', 'parentSchemaName': 'SalesInvoice', 'parentFieldname': 'taxes'}
#   {'name': '0ilbds-mdyq3irg', 'account': 'SGST', 'from_account': None, 'rate': 9.0, 'amount': '634.32000000000', 'idx': 1, 'parent': 'SINV-1034', 'parentSchemaName': 'SalesInvoice', 'parentFieldname': 'taxes'}
#   {'name': 'uterhi-mdyq3q42', 'account': 'CGST', 'from_account': None, 'rate': 9.0, 'amount': '802.98000000000', 'idx': 0, 'parent': 'SINV-1105', 'parentSchemaName': 'SalesInvoice', 'parentFieldname': 'taxes'}
#
# -- Table: UOM
# CREATE: CREATE TABLE `UOM` (`name` text not null, `isWhole` boolean default '0', `createdBy` text not null, `modifiedBy` text not null, `created` datetime not null, `modified` datetime not null, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   isWhole boolean NULL
#   createdBy TEXT NOT NULL
#   modifiedBy TEXT NOT NULL
#   created datetime NOT NULL
#   modified datetime NOT NULL
# INDEXES:
#   sqlite_autoindex_UOM_1: name UNIQUE
# SAMPLE DATA:
#   {'name': 'Unit', 'isWhole': 1, 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.255Z', 'modified': '2025-08-05T15:57:26.255Z'}
#   {'name': 'Kg', 'isWhole': 0, 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.258Z', 'modified': '2025-08-05T15:57:26.258Z'}
#   {'name': 'Gram', 'isWhole': 0, 'createdBy': '__SYSTEM__', 'modifiedBy': '__SYSTEM__', 'created': '2025-08-05T15:57:26.261Z', 'modified': '2025-08-05T15:57:26.261Z'}
#
# -- Table: UOMConversionItem
# CREATE: CREATE TABLE `UOMConversionItem` (`name` text not null, `uom` text not null, `conversionFactor` float not null default '1', `idx` integer not null, `parent` text not null, `parentSchemaName` text not null, `parentFieldname` text not null, foreign key(`uom`) references `UOM`(`name`) on delete RESTRICT on update CASCADE, primary key (`name`))
# COLUMNS:
#   name TEXT NOT NULL PK
#   uom TEXT NOT NULL
#   conversionFactor float NOT NULL
#   idx INTEGER NOT NULL
#   parent TEXT NOT NULL
#   parentSchemaName TEXT NOT NULL
#   parentFieldname TEXT NOT NULL
# FOREIGN KEYS:
#   uom -> UOM.name
# INDEXES:
#   sqlite_autoindex_UOMConversionItem_1: name UNIQUE
#
# Schema analysis saved to schema_analysis.json

# %%
#short schema 

import sqlite3

def analyze_frappe_patterns(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get all tables
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%'")
    tables = [row[0] for row in cursor.fetchall()]
    
    child_tables = []
    master_tables = []
    
    for table in tables:
        # Check column names
        cursor.execute(f"PRAGMA table_info({table})")
        columns = [col[1] for col in cursor.fetchall()]
        
        # Detect Frappe child table pattern
        has_parent = 'parent' in columns
        has_parenttype = 'parenttype' in columns
        has_parentfield = 'parentfield' in columns or 'idx' in columns
        
        if has_parent and has_parenttype:
            child_tables.append({
                'table': table,
                'columns': columns,
                'pattern': 'child_table'
            })
            
            # Get sample to understand relationship
            cursor.execute(f"SELECT parent, parenttype, parentfield FROM {table} LIMIT 3")
            samples = cursor.fetchall()
            print(f"\nCHILD TABLE: {table}")
            print(f"Links: {samples}")
            
        else:
            master_tables.append({
                'table': table, 
                'columns': columns,
                'pattern': 'master_table'
            })
    
    print(f"\nSUMMARY:")
    print(f"Child Tables: {[t['table'] for t in child_tables]}")
    print(f"Master Tables: {[t['table'] for t in master_tables]}")
    
    conn.close()
    return {'child_tables': child_tables, 'master_tables': master_tables}

# Quick analysis
patterns = analyze_frappe_patterns("demo.db")
# Out:
# SUMMARY:
# Child Tables: []
# Master Tables: ['PrintTemplate', 'Color', 'Currency', 'NumberSeries', 'Account', 'AccountingLedgerEntry', 'Lead', 'Address', 'ItemGroup', 'UOM', 'UOMConversionItem', 'LoyaltyProgram', 'LoyaltyPointEntry', 'CollectionRulesItems', 'Payment', 'PaymentMethod', 'PaymentFor', 'JournalEntry', 'JournalEntryAccount', 'ItemEnquiry', 'CouponCode', 'AppliedCouponCodes', 'PriceList', 'PriceListItem', 'PricingRule', 'PricingRuleItem', 'PricingRuleDetail', 'Tax', 'TaxDetail', 'TaxSummary', 'Location', 'StockLedgerEntry', 'StockMovement', 'StockMovementItem', 'Batch', 'SerialNumber', 'CustomForm', 'CustomField', 'POSProfile', 'POSOpeningShift', 'POSClosingShift', 'ERPNextSyncQueue', 'FetchFromERPNextQueue', 'IntegrationErrorLog', 'SalesInvoice', 'PurchaseInvoice', 'SalesQuote', 'SalesInvoiceItem', 'PurchaseInvoiceItem', 'SalesQuoteItem', 'Shipment', 'ShipmentItem', 'PurchaseReceipt', 'PurchaseReceiptItem', 'ClosingAmounts', 'ClosingCash', 'DefaultCashDenominations', 'OpeningAmounts', 'OpeningCash', 'PatchRun', 'SingleValue', 'Item', 'Party']

# %%
import sqlite3
import json
import uuid

def convert_frappe_to_universal(db_path, output_file="universal_data.json"):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get all table names
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%'")
    tables = [row[0] for row in cursor.fetchall()]
    
    universal_records = []
    
    # Define child table patterns based on your schema
    child_table_patterns = {
        'JournalEntryAccount': {
            'link_doctype': 'Account',
            'link_field': 'account',
            'additional_fields': ['debit', 'credit', 'idx']
        },
        'SalesInvoiceItem': {
            'link_doctype': 'Item', 
            'link_field': 'item',
            'additional_fields': ['description', 'rate', 'quantity', 'amount', 'tax', 'idx']
        },
        'PurchaseInvoiceItem': {
            'link_doctype': 'Item',
            'link_field': 'item', 
            'additional_fields': ['description', 'rate', 'quantity', 'amount', 'tax', 'idx']
        },
        'TaxDetail': {
            'link_doctype': 'TaxComponent',
            'link_field': 'account',
            'additional_fields': ['rate', 'idx']
        },
        'TaxSummary': {
            'link_doctype': 'TaxComponent', 
            'link_field': 'account',
            'additional_fields': ['rate', 'amount', 'idx']
        },
        'PaymentFor': {
            'link_doctype_field': 'referenceType',  # Dynamic link
            'link_field': 'referenceName',
            'additional_fields': ['amount', 'idx']
        }
    }
    
    for table in tables:
        print(f"Processing table: {table}")
        
        # Get all columns for this table
        cursor.execute(f"PRAGMA table_info({table})")
        columns = {col[1]: col for col in cursor.fetchall()}
        
        # Check if this is a child table
        is_child_table = ('parent' in columns and 
                         'parenttype' in columns and 
                         ('parentfield' in columns or 'idx' in columns))
        
        if is_child_table and table in child_table_patterns:
            # Handle known child table patterns
            pattern = child_table_patterns[table]
            cursor.execute(f"SELECT * FROM {table}")
            rows = cursor.fetchall()
            col_names = [col[1] for col in cursor.execute(f"PRAGMA table_info({table})").fetchall()]
            
            for row in rows:
                row_dict = dict(zip(col_names, row))
                
                # Build child record
                child_data = {
                    'parent': row_dict['parent'],
                    'parenttype': row_dict['parenttype']
                }
                
                # Handle dynamic vs static link doctype
                if 'link_doctype_field' in pattern:
                    child_data['link_doctype'] = row_dict[pattern['link_doctype_field']]
                else:
                    child_data['link_doctype'] = pattern['link_doctype']
                
                child_data['link_name'] = row_dict[pattern['link_field']]
                
                # Add additional fields
                for field in pattern['additional_fields']:
                    if field in row_dict and row_dict[field] is not None:
                        child_data[field] = row_dict[field]
                
                universal_records.append({
                    'doctype': 'Child',
                    'name': None,
                    'data': child_data
                })
        
        elif not is_child_table:
            # Handle master/transaction tables
            cursor.execute(f"SELECT * FROM {table}")
            rows = cursor.fetchall()
            col_names = [col[1] for col in cursor.execute(f"PRAGMA table_info({table})").fetchall()]
            
            for row in rows:
                row_dict = dict(zip(col_names, row))
                
                # Extract name and clean data
                doc_name = row_dict.get('name') or str(uuid.uuid4())
                
                # Remove system fields from data
                clean_data = {k: v for k, v in row_dict.items() 
                             if k not in ['name', 'createdBy', 'modifiedBy', 'created', 'modified']}
                
                universal_records.append({
                    'doctype': table,
                    'name': doc_name,
                    'data': clean_data
                })
    
    # Save to JSON
    with open(output_file, 'w') as f:
        json.dump(universal_records, f, indent=2, default=str)
    
    print(f"\nConversion complete!")
    print(f"Total records: {len(universal_records)}")
    print(f"Output saved to: {output_file}")
    
    # Show summary
    doctype_counts = {}
    for record in universal_records:
        doctype = record['doctype']
        doctype_counts[doctype] = doctype_counts.get(doctype, 0) + 1
    
    print("\nRecord counts by doctype:")
    for doctype, count in sorted(doctype_counts.items()):
        print(f"  {doctype}: {count}")
    
    conn.close()
    return universal_records

# Usage
if __name__ == "__main__":
    records = convert_frappe_to_universal("demo.db")
    
    # Preview first few records
    print("\nFirst 5 records:")
    for i, record in enumerate(records[:5]):
        print(f"{i+1}. {record['doctype']}: {record['name']}")
        if record['doctype'] == 'Child':
            print(f"   {record['data']['parent']} -> {record['data']['link_doctype']}")
# Out:
# Processing table: PrintTemplate
# Processing table: Color
# Processing table: Currency
# Processing table: NumberSeries
# Processing table: Account
# Processing table: AccountingLedgerEntry
# Processing table: Lead
# Processing table: Address
# Processing table: ItemGroup
# Processing table: UOM
# Processing table: UOMConversionItem
# Processing table: LoyaltyProgram
# Processing table: LoyaltyPointEntry
# Processing table: CollectionRulesItems
# Processing table: Payment
# Processing table: PaymentMethod
# Processing table: PaymentFor
# Processing table: JournalEntry
# Processing table: JournalEntryAccount
# Processing table: ItemEnquiry
# Processing table: CouponCode
# Processing table: AppliedCouponCodes
# Processing table: PriceList
# Processing table: PriceListItem
# Processing table: PricingRule
# Processing table: PricingRuleItem
# Processing table: PricingRuleDetail
# Processing table: Tax
# Processing table: TaxDetail
# Processing table: TaxSummary
# Processing table: Location
# Processing table: StockLedgerEntry
# Processing table: StockMovement
# Processing table: StockMovementItem
# Processing table: Batch
# Processing table: SerialNumber
# Processing table: CustomForm
# Processing table: CustomField
# Processing table: POSProfile
# Processing table: POSOpeningShift
# Processing table: POSClosingShift
# Processing table: ERPNextSyncQueue
# Processing table: FetchFromERPNextQueue
# Processing table: IntegrationErrorLog
# Processing table: SalesInvoice
# Processing table: PurchaseInvoice
# Processing table: SalesQuote
# Processing table: SalesInvoiceItem
# Processing table: PurchaseInvoiceItem
# Processing table: SalesQuoteItem
# Processing table: Shipment
# Processing table: ShipmentItem
# Processing table: PurchaseReceipt
# Processing table: PurchaseReceiptItem
# Processing table: ClosingAmounts
# Processing table: ClosingCash
# Processing table: DefaultCashDenominations
# Processing table: OpeningAmounts
# Processing table: OpeningCash
# Processing table: PatchRun
# Processing table: SingleValue
# Processing table: Item
# Processing table: Party
#
# Conversion complete!
# Total records: 5788
# Output saved to: universal_data.json
#
# Record counts by doctype:
#   Account: 79
#   AccountingLedgerEntry: 2313
#   Address: 1
#   Currency: 147
#   Item: 16
#   JournalEntry: 2
#   JournalEntryAccount: 4
#   Location: 1
#   NumberSeries: 9
#   Party: 210
#   PatchRun: 9
#   Payment: 378
#   PaymentFor: 378
#   PaymentMethod: 3
#   PrintTemplate: 14
#   PurchaseInvoice: 113
#   PurchaseInvoiceItem: 166
#   SalesInvoice: 269
#   SalesInvoiceItem: 799
#   SingleValue: 89
#   Tax: 18
#   TaxDetail: 26
#   TaxSummary: 738
#   UOM: 6
#
# First 5 records:
# 1. PrintTemplate: Basic - Sales Invoice
# 2. PrintTemplate: Basic - Quote
# 3. PrintTemplate: Basic - Purchase Invoice
# 4. PrintTemplate: Business-POS - Sales Invoice
# 5. PrintTemplate: Business-POS - Quote

# %%
import sqlite3

# Connect to SQLite DB
conn = sqlite3.connect("demo.db")
cursor = conn.cursor()

# Get all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
tables = [row[0] for row in cursor.fetchall()]

# Collect foreign key relationships
fk_map = {table: [] for table in tables}
for table in tables:
    cursor.execute(f"PRAGMA foreign_key_list({table});")
    for fk in cursor.fetchall():
        # fk format: (id, seq, table, from, to, on_update, on_delete, match)
        fk_map[table].append({
            "from_column": fk[3],
            "to_table": fk[2],
            "to_column": fk[4],
            "on_update": fk[5],
            "on_delete": fk[6]
        })

# Recursive print of schema dependencies
def print_schema_tree(table, level=0, visited=None):
    if visited is None:
        visited = set()
    indent = "  " * level
    print(f"{indent}- {table}")
    visited.add(table)
    for fk in fk_map.get(table, []):
        to_table = fk["to_table"]
        if to_table not in visited:
            print_schema_tree(to_table, level + 1, visited)

# Print all schema trees
for table in tables:
    print_schema_tree(table)
# Out:
# - PrintTemplate
# - Color
# - Currency
# - NumberSeries
# - Account
# - AccountingLedgerEntry
#   - Account
#   - Party
#     - LoyaltyProgram
#     - Lead
#       - Address
#     - Currency
# - Lead
#   - Address
# - Address
# - ItemGroup
#   - Tax
# - UOM
# - UOMConversionItem
#   - UOM
# - LoyaltyProgram
#   - Account
# - LoyaltyPointEntry
#   - SalesInvoice
#     - LoyaltyProgram
#       - Account
#     - SalesQuote
#       - Currency
#       - PriceList
#       - NumberSeries
#     - Shipment
#       - Party
#         - Lead
#           - Address
# - CollectionRulesItems
# - Payment
#   - PaymentMethod
#     - Account
#   - Party
#     - LoyaltyProgram
#     - Lead
#       - Address
#     - Currency
#   - NumberSeries
# - PaymentMethod
#   - Account
# - PaymentFor
# - JournalEntry
#   - NumberSeries
# - JournalEntryAccount
#   - Account
# - ItemEnquiry
# - CouponCode
#   - PricingRule
#     - UOM
#     - Item
#       - Tax
#       - Account
#       - ItemGroup
#     - NumberSeries
# - AppliedCouponCodes
#   - CouponCode
#     - PricingRule
#       - UOM
#       - Item
#         - Tax
#         - Account
#         - ItemGroup
#       - NumberSeries
# - PriceList
# - PriceListItem
#   - UOM
#   - Item
#     - Tax
#     - Account
#     - ItemGroup
# - PricingRule
#   - UOM
#   - Item
#     - Tax
#     - Account
#     - ItemGroup
#   - NumberSeries
# - PricingRuleItem
#   - UOM
#   - Item
#     - Tax
#     - Account
#     - ItemGroup
# - PricingRuleDetail
#   - Item
#     - Tax
#     - Account
#     - UOM
#     - ItemGroup
#   - PricingRule
#     - NumberSeries
# - Tax
# - TaxDetail
#   - Account
# - TaxSummary
#   - Account
# - Location
#   - Address
# - StockLedgerEntry
#   - Item
#     - Tax
#     - Account
#     - UOM
#     - ItemGroup
#   - SerialNumber
#   - Batch
#   - Location
#     - Address
# - StockMovement
#   - NumberSeries
# - StockMovementItem
#   - Batch
#     - Item
#       - Tax
#       - Account
#       - UOM
#       - ItemGroup
#   - Location
#     - Address
# - Batch
#   - Item
#     - Tax
#     - Account
#     - UOM
#     - ItemGroup
# - SerialNumber
#   - Item
#     - Tax
#     - Account
#     - UOM
#     - ItemGroup
# - CustomForm
# - CustomField
# - POSProfile
#   - PrintTemplate
#   - Location
#     - Address
#   - Party
#     - LoyaltyProgram
#       - Account
#     - Lead
#     - Currency
# - POSOpeningShift
# - POSClosingShift
#   - POSOpeningShift
# - ERPNextSyncQueue
# - FetchFromERPNextQueue
# - IntegrationErrorLog
# - SalesInvoice
#   - LoyaltyProgram
#     - Account
#   - SalesQuote
#     - Currency
#     - PriceList
#     - NumberSeries
#   - Shipment
#     - Party
#       - Lead
#         - Address
# - PurchaseInvoice
#   - PurchaseReceipt
#     - Party
#       - LoyaltyProgram
#         - Account
#       - Lead
#         - Address
#       - Currency
#     - NumberSeries
#   - PriceList
# - SalesQuote
#   - Currency
#   - PriceList
#   - NumberSeries
# - SalesInvoiceItem
#   - Tax
#   - Account
#   - Batch
#     - Item
#       - UOM
#       - ItemGroup
# - PurchaseInvoiceItem
#   - Tax
#   - Account
#   - Batch
#     - Item
#       - UOM
#       - ItemGroup
# - SalesQuoteItem
#   - Tax
#   - Account
#   - Batch
#     - Item
#       - UOM
#       - ItemGroup
# - Shipment
#   - SalesInvoice
#     - LoyaltyProgram
#       - Account
#     - SalesQuote
#       - Currency
#       - PriceList
#       - NumberSeries
#     - Party
#       - Lead
#         - Address
# - ShipmentItem
#   - Batch
#     - Item
#       - Tax
#       - Account
#       - UOM
#       - ItemGroup
#   - Location
#     - Address
# - PurchaseReceipt
#   - PurchaseInvoice
#     - Currency
#     - PriceList
#     - Account
#     - Party
#       - LoyaltyProgram
#       - Lead
#         - Address
#     - NumberSeries
# - PurchaseReceiptItem
#   - Batch
#     - Item
#       - Tax
#       - Account
#       - UOM
#       - ItemGroup
#   - Location
#     - Address
# - ClosingAmounts
# - ClosingCash
# - DefaultCashDenominations
# - OpeningAmounts
# - OpeningCash
# - PatchRun
# - SingleValue
# - Item
#   - Tax
#   - Account
#   - UOM
#   - ItemGroup
# - Party
#   - LoyaltyProgram
#     - Account
#   - Lead
#     - Address
#   - Currency

# %%
import sqlite3
import json
from collections import defaultdict

# Connect to your DB
conn = sqlite3.connect("demo.db")
cursor = conn.cursor()

# Get tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
tables = [row[0] for row in cursor.fetchall()]

# Build foreign key map
fk_map = defaultdict(list)
for table in tables:
    cursor.execute(f"PRAGMA foreign_key_list({table});")
    for fk in cursor.fetchall():
        fk_map[table].append({
            "from_column": fk[3],
            "to_table": fk[2],
            "to_column": fk[4]
        })

# Collect all rows per table
table_rows = {}
for table in tables:
    cursor.execute(f"SELECT * FROM {table}")
    columns = [desc[0] for desc in cursor.description]
    table_rows[table] = [dict(zip(columns, row)) for row in cursor.fetchall()]

# Function to recursively build JSON for a root table
def build_json(table, parent_key=None, parent_value=None):
    result = []
    for row in table_rows.get(table, []):
        # If parent filtering is applied, skip rows not matching
        if parent_key and row.get(parent_key) != parent_value:
            continue

        # Build JSON for current row
        obj = dict(row)

        # Handle foreign key children
        for fk in fk_map.get(table, []):
            child_table = fk["to_table"]
            child_key = fk["to_column"]
            from_key = fk["from_column"]
            # Recursively include child objects where FK matches current row
            child_objs = build_json(child_table, child_key, row.get(from_key))
            if child_objs:
                # Store under child table name
                obj[child_table] = child_objs

        # Handle implicit parent-child fields if exist
        if 'parentSchemaName' in row and 'parent' in row:
            child_table_name = row['parentSchemaName']
            child_objs = build_json(child_table_name, 'name', parent_value_field)
            if child_objs:
                obj[child_table_name] = child_objs

        result.append(obj)
    return result

# Example: build all SalesInvoices as JSON
invoices_json = build_json('SalesInvoice')
print(json.dumps(invoices_json, indent=2))
