# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\python\lib\site-packages (5.1.0)

# %%
from pypdf import PdfReader

def discover_pdf_fields(pdf_path):
    reader = PdfReader(pdf_path)
    fields = reader.get_form_text_fields()

    if fields:
        print("Discovered Fields:")
        for field_name, field_value in fields.items():
            print(f"Field Name: {field_name}, Default Value: {field_value}")
    else:
        print("No form fields found.")
        
discover_pdf_fields("f1040.pdf")
# Out:
# Discovered Fields:
# Field Name: f1_01[0], Default Value: None
# Field Name: f1_02[0], Default Value: None
# Field Name: f1_03[0], Default Value: None
# Field Name: f1_04[0], Default Value: None
# Field Name: f1_05[0], Default Value: None
# Field Name: f1_06[0], Default Value: None
# Field Name: f1_07[0], Default Value: None
# Field Name: f1_08[0], Default Value: None
# Field Name: f1_09[0], Default Value: None
# Field Name: f1_10[0], Default Value: None
# Field Name: f1_11[0], Default Value: None
# Field Name: f1_12[0], Default Value: None
# Field Name: f1_13[0], Default Value: None
# Field Name: f1_14[0], Default Value: None
# Field Name: f1_15[0], Default Value: None
# Field Name: f1_16[0], Default Value: None
# Field Name: f1_17[0], Default Value: None
# Field Name: f1_18[0], Default Value: None
# Field Name: f1_19[0], Default Value: None
# Field Name: f1_20[0], Default Value: None
# Field Name: f1_21[0], Default Value: None
# Field Name: f1_22[0], Default Value: None
# Field Name: f1_23[0], Default Value: None
# Field Name: f1_24[0], Default Value: None
# Field Name: f1_25[0], Default Value: None
# Field Name: f1_26[0], Default Value: None
# Field Name: f1_27[0], Default Value: None
# Field Name: f1_28[0], Default Value: None
# Field Name: f1_29[0], Default Value: None
# Field Name: f1_30[0], Default Value: None
# Field Name: f1_31[0], Default Value: None
# Field Name: f1_32[0], Default Value: None
# Field Name: f1_33[0], Default Value: None
# Field Name: f1_34[0], Default Value: None
# Field Name: f1_35[0], Default Value: None
# Field Name: f1_36[0], Default Value: None
# Field Name: f1_37[0], Default Value: None
# Field Name: f1_38[0], Default Value: None
# Field Name: f1_39[0], Default Value: None
# Field Name: f1_40[0], Default Value: None
# Field Name: f1_41[0], Default Value: None
# Field Name: f1_42[0], Default Value: None
# Field Name: f1_43[0], Default Value: None
# Field Name: f1_44[0], Default Value: None
# Field Name: f1_45[0], Default Value: None
# Field Name: f1_46[0], Default Value: None
# Field Name: f1_47[0], Default Value: None
# Field Name: f1_48[0], Default Value: None
# Field Name: f1_49[0], Default Value: None
# Field Name: f1_50[0], Default Value: None
# Field Name: f1_51[0], Default Value: None
# Field Name: f1_52[0], Default Value: None
# Field Name: f1_53[0], Default Value: None
# Field Name: f1_54[0], Default Value: None
# Field Name: f1_55[0], Default Value: None
# Field Name: f1_56[0], Default Value: None
# Field Name: f1_57[0], Default Value: None
# Field Name: f1_58[0], Default Value: None
# Field Name: f1_59[0], Default Value: None
# Field Name: f1_60[0], Default Value: None
# Field Name: f2_01[0], Default Value: None
# Field Name: f2_02[0], Default Value: None
# Field Name: f2_03[0], Default Value: None
# Field Name: f2_04[0], Default Value: None
# Field Name: f2_05[0], Default Value: None
# Field Name: f2_06[0], Default Value: None
# Field Name: f2_07[0], Default Value: None
# Field Name: f2_08[0], Default Value: None
# Field Name: f2_09[0], Default Value: None
# Field Name: f2_10[0], Default Value: None
# Field Name: f2_11[0], Default Value: None
# Field Name: f2_12[0], Default Value: None
# Field Name: f2_13[0], Default Value: None
# Field Name: f2_14[0], Default Value: None
# Field Name: f2_15[0], Default Value: None
# Field Name: f2_16[0], Default Value: None
# Field Name: f2_17[0], Default Value: None
# Field Name: f2_18[0], Default Value: None
# Field Name: f2_19[0], Default Value: None
# Field Name: f2_20[0], Default Value: None
# Field Name: f2_21[0], Default Value: None
# Field Name: f2_22[0], Default Value: None
# Field Name: f2_23[0], Default Value: None
# Field Name: f2_24[0], Default Value: None
# Field Name: f2_25[0], Default Value: None
# Field Name: f2_26[0], Default Value: None
# Field Name: f2_27[0], Default Value: None
# Field Name: f2_28[0], Default Value: None
# Field Name: f2_29[0], Default Value: None
# Field Name: f2_30[0], Default Value: None
# Field Name: f2_31[0], Default Value: None
# Field Name: f2_32[0], Default Value: None
# Field Name: f2_33[0], Default Value: None
# Field Name: f2_34[0], Default Value: None
# Field Name: f2_35[0], Default Value: None
# Field Name: f2_36[0], Default Value: None
# Field Name: f2_37[0], Default Value: None
# Field Name: f2_38[0], Default Value: None
# Field Name: f2_39[0], Default Value: None
# Field Name: f2_40[0], Default Value: None
# Field Name: f2_41[0], Default Value: None
# Field Name: f2_42[0], Default Value: None
# Field Name: f2_43[0], Default Value: None
# Field Name: f2_44[0], Default Value: None

# %%
# !pip install pikepdf
# Out:
# Collecting pikepdf
#   Downloading pikepdf-9.5.2-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: Pillow>=10.0.1 in c:\python\lib\site-packages (from pikepdf) (10.4.0)
# Requirement already satisfied: Deprecated in c:\python\lib\site-packages (from pikepdf) (1.2.16)
# Requirement already satisfied: lxml>=4.8 in c:\python\lib\site-packages (from pikepdf) (5.3.0)
# Requirement already satisfied: packaging in c:\python\lib\site-packages (from pikepdf) (24.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\python\lib\site-packages (from Deprecated->pikepdf) (1.17.2)
# Downloading pikepdf-9.5.2-cp312-cp312-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 3.5/3.5 MB 34.1 MB/s eta 0:00:00
# Installing collected packages: pikepdf
# Successfully installed pikepdf-9.5.2

# %%
import io
import pypdf
import pikepdf

def extract_pypdf_fields(pdf_path):
    """
    Extract fields using PyPDF library's methods
    """
    print("\n--- PyPDF Field Extraction ---")
    try:
        reader = pypdf.PdfReader(pdf_path)
           
        # Form Fields (more comprehensive)
        if reader.get_fields():
            print("\nDetailed Form Fields:")
            for name, field in reader.get_fields().items():
                print(f"  Field Name: {name}")
                print(f"    Type: {field.get('/FT', 'Unknown')}")
                print(f"    Value: {field.get('/V', 'No Value')}")
                print(f"    Flags: {field.get('/Ff', 'No Flags')}")
        else:
            print("No form fields found using PyPDF")
    
    except Exception as e:
        print(f"PyPDF Extraction Error: {e}")

def extract_pikepdf_fields(pdf_path):
    """
    Extract fields using PikePDF library
    """
    print("\n--- PikePDF Field Extraction ---")
    try:
        pdf = pikepdf.Pdf.open(pdf_path)
        
        # Iterate through all form fields
        for page in pdf.pages:
            if '/Annots' in page:
                for annot in page['/Annots']:
                    if '/Subtype' in annot and annot['/Subtype'] == '/Widget':
                        field_details = {
                            'Name': annot.get('/T', 'Unnamed'),
                            'Type': annot.get('/FT', 'Unknown'),
                            'Value': annot.get('/V', 'No Value'),
                            'Flags': annot.get('/Ff', 'No Flags')
                        }
                        print("Field Details:")
                        for key, value in field_details.items():
                            print(f"  {key}: {value}")
    
    except Exception as e:
        print(f"PikePDF Extraction Error: {e}")

def analyze_pdf_fields(pdf_path):
    """
    Comprehensive PDF field analysis
    """
    print(f"Analyzing PDF: {pdf_path}")
    
    # Extract fields using multiple methods
    extract_pypdf_fields(pdf_path)
    
    try:
        extract_pikepdf_fields(pdf_path)
    except ImportError:
        print("PikePDF is not installed. Install with 'pip install pikepdf'")

# Example usage
def main():
    # Replace with your PDF path
    pdf_path = "f1040.pdf"
    analyze_pdf_fields(pdf_path)

if __name__ == "__main__":
    main()

# %%
import io
import pypdf
import pikepdf

def extract_field_labels_pypdf(pdf_path):
    """
    Attempt to extract more meaningful field labels using PyPDF
    """
    print("\n--- PyPDF Field Label Extraction ---")
    try:
        reader = pypdf.PdfReader(pdf_path)
        
        def extract_field_label(field):
            """
            Try to extract a more meaningful label from the field
            """
            # Try different potential label sources
            label_keys = ['/T', '/TU', '/TM', '/Alt']
            
            for key in label_keys:
                if key in field:
                    label = field[key]
                    # Remove any non-printable characters and strip
                    label = ''.join(char for char in label if char.isprintable()).strip()
                    if label:
                        return label
            return "Unnamed Field"

        if reader.get_fields():
            print("\nDetailed Form Field Labels:")
            for name, field in reader.get_fields().items():
                # Try to get a more descriptive label
                label = extract_field_label(field)
                print(f"  Internal Name: {name}")
                print(f"  Extracted Label: {label}")
                print(f"    Type: {field.get('/FT', 'Unknown')}")
                print(f"    Value: {field.get('/V', 'No Value')}")
                print("---")
        else:
            print("No form fields found using PyPDF")
    
    except Exception as e:
        print(f"PyPDF Label Extraction Error: {e}")

def extract_field_labels_pikepdf(pdf_path):
    """
    Attempt to extract field labels using PikePDF
    """
    print("\n--- PikePDF Field Label Extraction ---")
    try:
        pdf = pikepdf.Pdf.open(pdf_path)
        
        def get_field_label(annot):
            """
            Extract label from PDF annotation
            """
            label_keys = ['/T', '/TU', '/TM', '/Alt']
            
            for key in label_keys:
                if key in annot:
                    label = str(annot[key])
                    # Clean and filter the label
                    label = ''.join(char for char in label if char.isprintable()).strip()
                    if label:
                        return label
            return "Unnamed Field"

        found_fields = False
        for page in pdf.pages:
            if '/Annots' in page:
                for annot in page['/Annots']:
                    if '/Subtype' in annot and annot['/Subtype'] == '/Widget':
                        found_fields = True
                        label = get_field_label(annot)
                        field_details = {
                            'Extracted Label': label,
                            'Type': annot.get('/FT', 'Unknown'),
                            'Value': annot.get('/V', 'No Value')
                        }
                        print("Field Details:")
                        for key, value in field_details.items():
                            print(f"  {key}: {value}")
                        print("---")
        
        if not found_fields:
            print("No form fields found using PikePDF")
    
    except Exception as e:
        print(f"PikePDF Label Extraction Error: {e}")

def analyze_pdf_field_labels(pdf_path):
    """
    Comprehensive PDF field label analysis
    """
    print(f"Analyzing PDF: {pdf_path}")
    
    # Extract field labels using multiple methods
    extract_field_labels_pypdf(pdf_path)
    
    try:
        extract_field_labels_pikepdf(pdf_path)
    except ImportError:
        print("PikePDF is not installed. Install with 'pip install pikepdf'")

# Example usage
def main():
    # Replace with your PDF path
    pdf_path = "f1040.pdf"
    analyze_pdf_field_labels(pdf_path)

if __name__ == "__main__":
    main()

# %%
# !pip install pikepdf pdfplumber
# Out:
# Requirement already satisfied: pikepdf in c:\python\lib\site-packages (9.5.2)
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: Pillow>=10.0.1 in c:\python\lib\site-packages (from pikepdf) (10.4.0)
# Requirement already satisfied: Deprecated in c:\python\lib\site-packages (from pikepdf) (1.2.16)
# Requirement already satisfied: lxml>=4.8 in c:\python\lib\site-packages (from pikepdf) (5.3.0)
# Requirement already satisfied: packaging in c:\python\lib\site-packages (from pikepdf) (24.2)
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\python\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\python\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (44.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\python\lib\site-packages (from Deprecated->pikepdf) (1.17.2)
# Requirement already satisfied: cffi>=1.12 in c:\python\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\python\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.5-py3-none-any.whl (59 kB)
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.6 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 1.8/5.6 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.6 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.6 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 4.5/5.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.6 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 4.3 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/3.0 MB 4.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.3/3.0 MB 3.5 MB/s eta 0:00:01
#    ------------------------------- -------- 2.4/3.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 3.8 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.5 pypdfium2-4.30.1

# %%
import pikepdf
import pdfplumber

def extract_detailed_form_info(pdf_path):
    """
    Attempt to extract more detailed form field information
    """
    try:
        # First, try using pikepdf for structural analysis
        pdf = pikepdf.Pdf.open(pdf_path)
        
        print("\n--- Detailed PDF Form Field Analysis ---")
        
        # Use pdfplumber for additional text extraction
        with pdfplumber.open(pdf_path) as plumber_pdf:
            first_page = plumber_pdf.pages[0]
            
            # Extract visible text near form fields
            page_text = first_page.extract_text()
            print("\nPage Text Context:")
            print(page_text)
        
        # Detailed pikepdf annotation parsing
        for page_num, page in enumerate(pdf.pages, 1):
            if '/Annots' in page:
                print(f"\n--- Page {page_num} Annotations ---")
                for annot in page['/Annots']:
                    if '/Subtype' in annot and annot['/Subtype'] == '/Widget':
                        print("\nForm Field Details:")
                        
                        # Extract all available information
                        field_info = {
                            'Internal Name': annot.get('/T', 'No Internal Name'),
                            'Type': annot.get('/FT', 'Unknown Type'),
                            'Rectangle': annot.get('/Rect', 'No Rect'),
                            'Font': annot.get('/DA', 'No Font Info'),
                            'Max Length': annot.get('/MaxLen', 'No Max Length')
                        }
                        
                        # Print field details
                        for key, value in field_info.items():
                            print(f"  {key}: {value}")
    
    except Exception as e:
        print(f"Error extracting PDF form details: {e}")

def analyze_form_field_context(pdf_path):
    """
    Additional context analysis for form fields
    """
    try:
        with pdfplumber.open(pdf_path) as pdf:
            first_page = pdf.pages[0]
            
            # Extract text and words
            words = first_page.extract_words()
            
            print("\n--- Form Field Context Analysis ---")
            for word in words:
                # You might want to filter or process words near form fields
                print(f"Word: {word['text']}, Position: {word['x0']}, {word['top']}")
    
    except Exception as e:
        print(f"Error analyzing form field context: {e}")

def main():
    # Replace with your PDF path
    pdf_path = "f1040.pdf"
    
    # Extract detailed form information
    extract_detailed_form_info(pdf_path)
    
    # Analyze form field context
    analyze_form_field_context(pdf_path)

if __name__ == "__main__":
    main()
# Out:
# --- Detailed PDF Form Field Analysis ---
#
# Page Text Context:
# mroF 1040 Department of the Treasury—Internal Revenue Service 2024
# U.S. Individual Income Tax Return
# OMB No. 1545-0074 IRS Use Only—Do not write or staple in this space.
# For the year Jan. 1–Dec. 31, 2024, or other tax year beginning , 2024, ending , 20 See separate instructions.
# Your first name and middle initial Last name Your social security number
# If joint return, spouse’s first name and middle initial Last name Spouse’s social security number
# Home address (number and street). If you have a P.O. box, see instructions. Apt. no. Presidential Election Campaign
# Check here if you, or your
# spouse if filing jointly, want $3
# City, town, or post office. If you have a foreign address, also complete spaces below. State ZIP code
# to go to this fund. Checking a
# box below will not change
# Foreign country name Foreign province/state/county Foreign postal code your tax or refund.
# You Spouse
# Filing Status Single Head of household (HOH)
# Married filing jointly (even if only one had income)
# Check only
# one box. Married filing separately (MFS) Qualifying surviving spouse (QSS)
# If you checked the MFS box, enter the name of your spouse. If you checked the HOH or QSS box, enter the child’s name if the
# qualifying person is a child but not your dependent:
# If treating a nonresident alien or dual-status alien spouse as a U.S. resident for the entire tax year, check the box and enter
# their name (see instructions and attach statement if required):
# Digital At any time during 2024, did you: (a) receive (as a reward, award, or payment for property or services); or (b) sell,
# Assets exchange, or otherwise dispose of a digital asset (or a financial interest in a digital asset)? (See instructions.) Yes No
# Standard Someone can claim: You as a dependent Your spouse as a dependent
# Deduction Spouse itemizes on a separate return or you were a dual-status alien
# Age/Blindness You: Were born before January 2, 1960 Are blind Spouse: Was born before January 2, 1960 Is blind
# Dependents(see instructions): (2) Social security (3) Relationship (4) Check the box if qualifies for (see instructions):
# (1) First name Last name num b e r to y o u Child tax credit Credit for other dependents
# If more
# than four
# dependents,
# see instructions
# and check
# here . .
# Income 1 a Total amount from Form(s) W-2, box 1 (see instructions) . . . . . . . . . . . . . 1a
# b Household employee wages not reported on Form(s) W-2 . . . . . . . . . . . . . 1b
# Attach Form(s)
# W-2 here. Also c Tip income not reported on line 1a (see instructions) . . . . . . . . . . . . . . 1c
# attach Forms d Medicaid waiver payments not reported on Form(s) W-2 (see instructions) . . . . . . . . 1d
# W-2G and
# e Taxable dependent care benefits from Form 2441, line 26 . . . . . . . . . . . . 1e
# 1099-R if tax
# was withheld. f Employer-provided adoption benefits from Form 8839, line 29 . . . . . . . . . . . 1f
# If you did not g Wages from Form 8919, line 6 . . . . . . . . . . . . . . . . . . . . . 1g
# get a Form
# h Other earned income (see instructions) . . . . . . . . . . . . . . . . . . 1h
# W-2, see
# instructions. i Nontaxable combat pay election (see instructions) . . . . . . . 1i
# z Add lines 1a through 1h . . . . . . . . . . . . . . . . . . . . . . 1z
# Attach Sch. B 2a Tax-exempt interest . . . 2a b Taxable interest . . . . . 2b
# if required. 3a Qualified dividends . . . 3a b Ordinary dividends . . . . . 3b
# 4a IRA distributions . . . . 4a b Taxable amount . . . . . . 4b
# Standard
# 5a Pensions and annuities . . 5a b Taxable amount . . . . . . 5b
# Deduction for—
# • Single or 6a Social security benefits . . 6a b Taxable amount . . . . . . 6b
# Married filing
# c If you elect to use the lump-sum election method, check here (see instructions) . . . . .
# separately,
# $14,600 7 Capital gain or (loss). Attach Schedule D if required. If not required, check here . . . . . 7
# • Married filing
# jointly or 8 Additional income from Schedule 1, line 10 . . . . . . . . . . . . . . . . . 8
# Qualifying
# 9 Add lines 1z, 2b, 3b, 4b, 5b, 6b, 7, and 8. This is your total income . . . . . . . . . . 9
# surviving spouse,
# $29,200 10 Adjustments to income from Schedule 1, line 26 . . . . . . . . . . . . . . . 10
# • Head of
# household, 11 Subtract line 10 from line 9. This is your adjusted gross income . . . . . . . . . . 11
# $21,900 12 Standard deduction or itemized deductions (from Schedule A) . . . . . . . . . . 12
# • If you checked
# any box under 13 Qualified business income deduction from Form 8995 or Form 8995-A . . . . . . . . . 13
# Standard
# Deduction, 14 Add lines 12 and 13 . . . . . . . . . . . . . . . . . . . . . . . . 14
# see instructions. 15 Subtract line 14 from line 11. If zero or less, enter -0-. This is your taxable income . . . . . 15
# For Disclosure, Privacy Act, and Paperwork Reduction Act Notice, see separate instructions. Cat. No. 11320B Form 1040 (2024)
#
# --- Page 1 Annotations ---
#
# Form Field Details:
#   Internal Name: f1_01[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('226.0'), Decimal('717.999'), Decimal('302.4'), Decimal('729.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_02[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('348.4'), Decimal('717.999'), Decimal('424.8'), Decimal('729.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_03[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('439.2'), Decimal('717.999'), Decimal('464.0'), Decimal('729.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 2
#
# Form Field Details:
#   Internal Name: f1_04[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('36.0'), Decimal('689.998'), Decimal('236.85'), Decimal('703.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_05[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('238.6'), Decimal('689.998'), Decimal('467.25'), Decimal('703.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_06[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('469.0'), Decimal('689.998'), Decimal('576.0'), Decimal('703.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 9
#
# Form Field Details:
#   Internal Name: f1_07[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('36.0'), Decimal('666.0'), Decimal('236.85'), Decimal('680.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_08[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('238.6'), Decimal('666.0'), Decimal('467.25'), Decimal('680.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_09[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('469.0'), Decimal('666.0'), Decimal('576.0'), Decimal('680.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 9
#
# Form Field Details:
#   Internal Name: f1_10[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('36.0'), Decimal('641.999'), Decimal('416.85'), Decimal('656.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_11[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('418.6'), Decimal('641.999'), Decimal('467.0'), Decimal('656.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_12[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('36.0'), Decimal('617.998'), Decimal('337.4'), Decimal('631.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_13[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('339.4'), Decimal('617.998'), Decimal('402.2'), Decimal('631.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_14[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('404.2'), Decimal('617.998'), Decimal('467.0'), Decimal('631.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_15[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('36.0'), Decimal('594.0'), Decimal('258.45'), Decimal('608.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f1_16[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal
0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('684.0'), Decimal('576.0'), Decimal('695.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_08[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('672.001'), Decimal('576.0'), Decimal('684.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_09[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('660.002'), Decimal('576.0'), Decimal('672.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_10[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('648.0'), Decimal('576.0'), Decimal('659.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_11[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('624.002'), Decimal('481.65'), Decimal('636.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_12[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('612.0'), Decimal('481.65'), Decimal('623.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_13[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('600.001'), Decimal('481.65'), Decimal('612.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_14[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('588.002'), Decimal('576.0'), Decimal('600.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_15[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('576.0'), Decimal('576.0'), Decimal('587.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_16[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('564.001'), Decimal('481.65'), Decimal('576.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_17[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('552.002'), Decimal('481.65'), Decimal('564.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_18[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('540.0'), Decimal('481.65'), Decimal('551.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_19[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('528.001'), Decimal('481.65'), Decimal('540.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_20[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('516.002'), Decimal('481.65'), Decimal('528.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_21[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('504.0'), Decimal('576.0'), Decimal('515.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_22[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('492.001'), Decimal('576.0'), Decimal('504.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_23[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('480.002'), Decimal('576.0'), Decimal('492.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: c2_4[0]
#   Type: /Btn
#   Rectangle: pikepdf.Array([ Decimal('465.2'), Decimal('469.5'), Decimal('473.2'), Decimal('477.5') ])
#   Font: /ZaDb 5.6 Tf 0 g /ZaDb 5.6 Tf 0 g
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_24[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('468.0'), Decimal('576.0'), Decimal('479.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_25[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('172.8'), Decimal('456.5'), Decimal('302.4'), Decimal('467.501') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 9
#
# Form Field Details:
#   Internal Name: c2_5[0]
#   Type: /Btn
#   Rectangle: pikepdf.Array([ Decimal('377.4'), Decimal('457.001'), Decimal('385.4'), Decimal('465.001') ])
#   Font: /ZaDb 5.6 Tf 0 g /ZaDb 5.6 Tf 0 g
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: c2_5[1]
#   Type: /Btn
#   Rectangle: pikepdf.Array([ Decimal('435.0'), Decimal('457.001'), Decimal('443.0'), Decimal('465.001') ])
#   Font: /ZaDb 5.6 Tf 0 g /ZaDb 5.6 Tf 0 g
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_26[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('172.8'), Decimal('444.498'), Decimal('417.6'), Decimal('455.499') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 17
#
# Form Field Details:
#   Internal Name: f2_27[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('431.986'), Decimal('481.65'), Decimal('443.781') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_28[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('408.002'), Decimal('576.0'), Decimal('420.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_29[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('396.0'), Decimal('481.65'), Decimal('407.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: c2_6[0]
#   Type: /Btn
#   Rectangle: pikepdf.Array([ Decimal('410.4'), Decimal('375.502'), Decimal('418.4'), Decimal('383.502') ])
#   Font: /ZaDb 5.6 Tf 0 g /ZaDb 5.6 Tf 0 g
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: c2_6[1]
#   Type: /Btn
#   Rectangle: pikepdf.Array([ Decimal('511.2'), Decimal('375.502'), Decimal('519.2'), Decimal('383.502') ])
#   Font: /ZaDb 5.6 Tf 0 g /ZaDb 5.6 Tf 0 g
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_30[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('144.0'), Decimal('353.999'), Decimal('295.2'), Decimal('371.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_31[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('331.2'), Decimal('353.999'), Decimal('424.8'), Decimal('371.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_32[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('354.002'), Decimal('576.0'), Decimal('366.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 5
#
# Form Field Details:
#   Internal Name: f2_33[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('325.0'), Decimal('300.002'), Decimal('460.05'), Decimal('320.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_34[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('300.002'), Decimal('576.0'), Decimal('312.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 6
#
# Form Field Details:
#   Internal Name: f2_35[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('325.0'), Decimal('270.0'), Decimal('460.05'), Decimal('289.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_36[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('504.0'), Decimal('270.0'), Decimal('576.0'), Decimal('281.999') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 6
#
# Form Field Details:
#   Internal Name: f2_37[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('134.799'), Decimal('258.001'), Decimal('272.85'), Decimal('270.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_38[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('324.0'), Decimal('258.001'), Decimal('576.0'), Decimal('270.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_39[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('91.599'), Decimal('234.0'), Decimal('215.0'), Decimal('248.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_40[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('447.4'), Decimal('234.0'), Decimal('503.25'), Decimal('248.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 11
#
# Form Field Details:
#   Internal Name: c2_7[0]
#   Type: /Btn
#   Rectangle: pikepdf.Array([ Decimal('511.2'), Decimal('237.0'), Decimal('519.2'), Decimal('245.0') ])
#   Font: /ZaDb 5.6 Tf 0 g /ZaDb 5.6 Tf 0 g
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_41[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('142.599'), Decimal('222.001'), Decimal('460.05'), Decimal('234.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_42[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('499.8'), Decimal('222.001'), Decimal('576.0'), Decimal('234.0') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_43[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('150.599'), Decimal('210.002'), Decimal('460.05'), Decimal('222.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: No Max Length
#
# Form Field Details:
#   Internal Name: f2_44[0]
#   Type: /Tx
#   Rectangle: pikepdf.Array([ Decimal('499.8'), Decimal('210.002'), Decimal('576.0'), Decimal('222.001') ])
#   Font: /HelveticaLTStd-Bold 8.00 Tf 0.000 0.000 0.502 rg
#   Max Length: 10
#
# --- Form Field Context Analysis ---
# Word: mroF, Position: 36.0960786, 38.58100000000002
# Word: 1040, Position: 43.2, 35.65599999999995
# Word: Department, Position: 97.6, 38.61799999999994
# Word: of, Position: 130.94799999999998, 38.61799999999994
# Word: the, Position: 137.83599999999998, 38.61799999999994
# Word: Treasury—Internal, Position: 147.952, 38.61799999999994
# Word: Revenue, Position: 198.73, 38.61799999999994
# Word: Service, Position: 223.84599999999998, 38.61799999999994
# Word: 2024, Position: 298.0, 38.920999999999935
# Word: U.S., Position: 97.6, 47.230999999999995
# Word: Individual, Position: 123.52, 47.230999999999995
# Word: Income, Position: 178.23999999999998, 47.230999999999995
# Word: Tax, Position: 221.19999999999996, 47.230999999999995
# Word: Return, Position: 244.23999999999992, 47.230999999999995
# Word: OMB, Position: 356.31, 50.99700000000007
# Word: No., Position: 374.468, 50.99700000000007
# Word: 1545-0074, Position: 387.432, 50.99700000000007
# Word: IRS, Position: 432.172, 51.56600000000003
# Word: Use, Position: 443.39200000000005, 51.56600000000003
# Word: Only—Do, Position: 455.61400000000003, 51.56600000000003
# Word: not, Position: 483.17800000000005, 51.56600000000003
# Word: write, Position: 493.516, 51.56600000000003
# Word: or, Position: 508.17400000000004, 51.56600000000003
# Word: staple, Position: 515.2840000000001, 51.56600000000003
# Word: in, Position: 533.176, 51.56600000000003
# Word: this, Position: 539.5120000000001, 51.56600000000003
# Word: space., Position: 550.738, 51.56600000000003
# Word: For, Position: 40.0, 64.49700000000007
# Word: the, Position: 51.69735, 64.49700000000007
# Word: year, Position: 62.90925, 64.49700000000007
# Word: Jan., Position: 77.43950000000001, 64.49700000000007
# Word: 1–Dec., Position: 91.85670000000002, 64.49700000000007
# Word: 31,, Position: 114.40020000000004, 64.49700000000007
# Word: 2024,, Position: 125.49240000000006, 64.49700000000007
# Word: or, Position: 143.9794000000001, 64.49700000000007
# Word: other, Position: 151.8596500000001, 64.49700000000007
# Word: tax, Position: 169.1031000000001, 64.49700000000007
# Word: year, Position: 180.06230000000008, 64.49700000000007
# Word: beginning, Position: 194.59255000000005, 64.49700000000007
# Word: ,, Position: 303.9, 64.49700000000007
# Word: 2024,, Position: 307.63631999999996, 64.49700000000007
# Word: ending, Position: 326.31791999999996, 64.49700000000007
# Word: ,, Position: 426.3, 64.49700000000007
# Word: 20, Position: 430.192, 64.49700000000007
# Word: See, Position: 472.0, 65.49299999999994
# Word: If, Position: 120.759, 152.89700000000005
# Word: you, Position: 126.59, 152.89700000000005
# Word: have, Position: 139.946, 152.89700000000005
# Word: a, Position: 156.802, 152.89700000000005
# Word: foreign, Position: 162.50699999999998, 152.89700000000005
# Word: address,, Position: 186.09699999999998, 152.89700000000005
# Word: also, Position: 215.13999999999996, 152.89700000000005
# Word: complete, Position: 229.91699999999994, 152.89700000000005
# Word: spaces, Position: 261.039, 152.89700000000005
# Word: below., Position: 285.413, 152.89700000000005
# Word: State, Position: 342.4, 152.89700000000005
# Word: ZIP, Position: 407.2, 152.89700000000005
# Word: code, Position: 419.772, 152.89700000000005
# Word: to, Position: 472.0, 158.586
# Word: go, Position: 480.7525, 158.586
# Word: to, Position: 491.4475, 158.586
# Word: this, Position: 500.2, 158.586
# Word: fund., Position: 514.2325, 158.586
# Word: Checking, Position: 533.41, 158.586
# Word: a, Position: 567.1675, 158.586
# Word: box, Position: 472.0, 167.586
# Word: below, Position: 486.7225, 167.586
# Word: will, Position: 508.9375, 167.586
# Word: not, Position: 521.7025, 167.586
# Word: change, Position: 534.625, 167.586
# Word: Foreign, Position: 40.0, 176.8950000000001
# Word: country, Position: 65.536, 176.8950000000001
# Word: name, Position: 91.07900000000001, 176.8950000000001
# Word: Foreign, Position: 263.2, 176.8950000000001
# Word: province/state/county, Position: 288.736, 176.8950000000001
# Word: Foreign, Position: 407.2, 176.8950000000001
# Word: postal, Position: 430.94848, 176.8950000000001
# Word: code, Position: 450.60217, 176.8950000000001
# Word: your, Position: 472.0, 176.586
# Word: tax, Position: 488.8075, 176.586
# Word: or, Position: 501.1675, 176.586
# Word: refund., Position: 510.055, 176.586
# Word: You, Position: 514.8, 187.524
# Word: Spouse, Position: 550.8, 187.524
# Word: Filing, Position: 36.0, 201.4899999999999
# Word: Status, Position: 61.641, 201.4899999999999
# Word: Single, Position: 115.2, 201.423
# Word: Head, Position: 381.6, 201.423
# Word: of, Position: 402.93600000000004, 201.423
# Word: household, Position: 412.12, 201.423
# Word: (HOH), Position: 451.68800000000005, 201.423
# Word: Married, Position: 115.2, 213.42200000000003
# Word: filing, Position: 144.832, 213.42200000000003
# Word: jointly, Position: 163.792, 213.42200000000003
# Word: (even, Position: 186.904, 213.42200000000003
# Word: if, Position: 208.24000000000004, 213.42200000000003
# Word: only, Position: 214.60800000000003, 213.42200000000003
# Word: one, Position: 231.64800000000002, 213.42200000000003
# Word: had, Position: 247.20800000000003, 213.42200000000003
# ...
# Word: ., Position: 288.0, 537.422
# Word: ., Position: 300.0, 537.422
# Word: ., Position: 312.0, 537.422
# Word: ., Position: 324.0, 537.422
# Word: ., Position: 336.0, 537.422
# Word: ., Position: 348.0, 537.422
# Word: ., Position: 360.0, 537.422
# Word: ., Position: 372.0, 537.422
# Word: ., Position: 384.0, 537.422
# Word: ., Position: 396.0, 537.422
# Word: ., Position: 408.0, 537.422
# Word: ., Position: 420.0, 537.422
# Word: ., Position: 432.0, 537.422
# Word: ., Position: 444.0, 537.422
# Word: ., Position: 456.0, 537.422
# Word: ., Position: 468.0, 537.422
# Word: 1z, Position: 488.9, 537.454
# Word: Attach, Position: 36.0, 550.854
# Word: Sch., Position: 58.302, 550.854
# Word: B, Position: 74.381, 550.854
# Word: 2a, Position: 96.26, 549.456
# Word: Tax-exempt, Position: 115.20400000000001, 549.424
# Word: interest, Position: 160.39600000000002, 549.424
# Word: ., Position: 192.00400000000002, 549.424
# Word: ., Position: 204.00400000000002, 549.424
# Word: ., Position: 216.00400000000002, 549.424
# Word: 2a, Position: 236.68, 549.456
# Word: b, Position: 338.4, 549.456
# Word: Taxable, Position: 347.736, 549.424
# Word: interest, Position: 378.104, 549.424
# Word: ., Position: 420.0, 549.424
# Word: ., Position: 432.0, 549.424
# Word: ., Position: 444.0, 549.424
# Word: ., Position: 456.0, 549.424
# Word: ., Position: 468.0, 549.424
# Word: 2b, Position: 488.532, 549.456
# Word: if, Position: 36.0, 559.254
# Word: required., Position: 41.572, 559.254
# Word: 3a, Position: 96.26, 561.455
# Word: Qualified, Position: 115.20400000000001, 561.423
# Word: dividends, Position: 148.988, 561.423
# Word: ., Position: 192.00400000000002, 561.423
# Word: ., Position: 204.00400000000002, 561.423
# Word: ., Position: 216.00400000000002, 561.423
# Word: 3a, Position: 236.68, 561.455
# Word: b, Position: 338.4, 561.455
# Word: Ordinary, Position: 347.736, 561.423
# Word: dividends, Position: 380.63199999999995, 561.423
# Word: ., Position: 420.0, 561.423
# Word: ., Position: 432.0, 561.423
# Word: ., Position: 444.0, 561.423
# Word: ., Position: 456.0, 561.423
# Word: ., Position: 468.0, 561.423
# Word: 3b, Position: 488.532, 561.455
# Word: 4a, Position: 96.352, 573.454
# Word: IRA, Position: 115.2, 573.422
# Word: distributions, Position: 130.16, 573.422
# Word: ., Position: 180.0, 573.422
# Word: ., Position: 192.0, 573.422
# Word: ., Position: 204.0, 573.422
# Word: ., Position: 216.0, 573.422
# Word: 4a, Position: 236.68, 573.454
# Word: b, Position: 338.4, 573.454
# Word: Taxable, Position: 347.736, 573.422
# Word: amount, Position: 378.104, 573.422
# Word: ., Position: 408.0, 573.422
# Word: ., Position: 420.0, 573.422
# Word: ., Position: 432.0, 573.422
# Word: ., Position: 444.0, 573.422
# Word: ., Position: 456.0, 573.422
# Word: ., Position: 468.0, 573.422
# Word: 4b, Position: 488.532, 573.454
# Word: Standard, Position: 31.8, 581.723
# Word: 5a, Position: 96.352, 585.456
# Word: Pensions, Position: 115.2, 585.424
# Word: and, Position: 150.168, 585.424
# Word: annuities, Position: 165.88, 585.424
# Word: ., Position: 204.0, 585.424
# Word: ., Position: 216.0, 585.424
# Word: 5a, Position: 236.68, 585.456
# Word: b, Position: 338.4, 585.456
# Word: Taxable, Position: 347.736, 585.424
# Word: amount, Position: 378.104, 585.424
# Word: ., Position: 408.0, 585.424
# Word: ., Position: 420.0, 585.424
# Word: ., Position: 432.0, 585.424
# Word: ., Position: 444.0, 585.424
# Word: ., Position: 420.0, 716.922
# Word: ., Position: 432.0, 716.922
# Word: ., Position: 444.0, 716.922
# Word: ., Position: 456.0, 716.922
# Word: ., Position: 468.0, 716.922
# Word: 15, Position: 488.752, 717.454
# Word: For, Position: 36.0, 730.024
# Word: Disclosure,, Position: 49.097, 730.024
# Word: Privacy, Position: 88.493, 730.024
# Word: Act,, Position: 114.946, 730.024
# Word: and, Position: 130.115, 730.024
# Word: Paperwork, Position: 144.507, 730.024
# Word: Reduction, Position: 182.87400000000005, 730.024
# Word: Act, Position: 219.03600000000006, 730.024
# Word: Notice,, Position: 232.25900000000007, 730.024
# Word: see, Position: 257.92100000000005, 730.024
# Word: separate, Position: 271.66200000000003, 730.024
# Word: instructions., Position: 302.9029999999999, 730.024
# Word: Cat., Position: 409.659, 730.568
# Word: No., Position: 422.43899999999996, 730.568
# Word: 11320B, Position: 433.551, 730.568
# Word: Form, Position: 521.933, 730.71
# Word: 1040, Position: 537.605, 728.388
# Word: (2024), Position: 559.289, 729.924

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
from PyPDF2 import PdfReader
from collections import OrderedDict

def get_fields(obj, tree=None, retval=None, fileobj=None):
    """
    Extracts field data if this PDF contains interactive form fields.
    The *tree* and *retval* parameters are for recursive use.
    :param fileobj: A file object (usually a text file) to write
        a report to on all interactive form fields found.
    :return: A dictionary where each key is a field name, and each
        value is a :class:`Field<PyPDF2.generic.Field>` object. By
        default, the mapping name is used for keys.
    :rtype: dict, or ``None`` if form data could not be located.
    """
    fieldAttributes = {'/FT': 'Field Type', '/Parent': 'Parent', '/T': 'Field Name', '/TU': 'Alternate Field Name',
                    '/TM': 'Mapping Name', '/Ff': 'Field Flags', '/V': 'Value', '/DV': 'Default Value'}
    if retval is None:
        retval = OrderedDict()
        catalog = obj.trailer["/Root"]
        # get the AcroForm tree
        if "/AcroForm" in catalog:
            tree = catalog["/AcroForm"]
        else:
            return None
    if tree is None:
        return retval
    obj._check_kids(tree, retval, fileobj)
    for attr in fieldAttributes:
        if attr in tree:
            # Tree is a field
            obj._build_field(tree, retval, fileobj, fieldAttributes)
            break
    if "/Fields" in tree:
        fields = tree["/Fields"]
        for f in fields:
            field = f.get_object()
            obj._build_field(field, retval, fileobj, fieldAttributes)
    return retval

def get_form_fields(infile):
    with open(infile, 'rb') as file:
        infile = PdfReader(file)
        fields = get_fields(infile)
        return OrderedDict((k, v.get('/V', '')) for k, v in fields.items())

if __name__ == '__main__':
    from pprint import pprint
    pdf_file_name = 'f1040_filled.pdf'
    pprint(get_form_fields(pdf_file_name))
# Out:
# OrderedDict([('f1_01[0]', ''),
#              ('f1_02[0]', ''),
#              ('f1_03[0]', ''),
#              ('f1_04[0]', ''),
#              ('f1_05[0]', ''),
#              ('f1_06[0]', ''),
#              ('f1_07[0]', ''),
#              ('f1_08[0]', ''),
#              ('f1_09[0]', ''),
#              ('f1_10[0]', ''),
#              ('f1_11[0]', ''),
#              ('f1_12[0]', ''),
#              ('f1_13[0]', ''),
#              ('f1_14[0]', ''),
#              ('f1_15[0]', ''),
#              ('f1_16[0]', ''),
#              ('f1_17[0]', ''),
#              ('Address_ReadOrder[0]', ''),
#              ('c1_1[0]', '/Off'),
#              ('c1_2[0]', '/Off'),
#              ('c1_3[0]', '/Off'),
#              ('c1_3[1]', '/Off'),
#              ('c1_3[2]', '/Off'),
#              ('FilingStatus_ReadOrder[0]', ''),
#              ('f1_18[0]', ''),
#              ('c1_4[0]', '/Off'),
#              ('f1_19[0]', ''),
#              ('c1_5[0]', '/Off'),
#              ('c1_5[1]', '/Off'),
#              ('c1_6[0]', '/Off'),
#              ('c1_7[0]', '/Off'),
#              ('c1_8[0]', '/Off'),
#              ('c1_9[0]', '/Off'),
#              ('c1_10[0]', '/Off'),
#              ('c1_11[0]', '/Off'),
#              ('c1_12[0]', '/Off'),
#              ('c1_13[0]', '/Off'),
#              ('Dependents_ReadOrder[0]', ''),
#              ('f1_20[0]', ''),
#              ('f1_21[0]', ''),
#              ('f1_22[0]', ''),
#              ('c1_14[0]', '/Off'),
#              ('c1_15[0]', '/Off'),
#              ('Row1[0]', ''),
#              ('f1_23[0]', ''),
#              ('f1_24[0]', ''),
#              ('f1_25[0]', ''),
#              ('c1_16[0]', '/Off'),
#              ('c1_17[0]', '/Off'),
#              ('Row2[0]', ''),
#              ('f1_26[0]', ''),
#              ('f1_27[0]', ''),
#              ('f1_28[0]', ''),
#              ('c1_18[0]', '/Off'),
#              ('c1_19[0]', '/Off'),
#              ('Row3[0]', ''),
#              ('f1_29[0]', ''),
#              ('f1_30[0]', ''),
#              ('f1_31[0]', ''),
#              ('c1_20[0]', '/Off'),
#              ('c1_21[0]', '/Off'),
#              ('Row4[0]', ''),
#              ('Table_Dependents[0]', ''),
#              ('f1_32[0]', ''),
#              ('f1_33[0]', ''),
#              ('f1_34[0]', ''),
#              ('f1_35[0]', ''),
#              ('f1_36[0]', ''),
#              ('f1_37[0]', ''),
#              ('f1_38[0]', ''),
#              ('f1_39[0]', ''),
#              ('f1_40[0]', ''),
#              ('f1_41[0]', ''),
#              ('f1_42[0]', ''),
#              ('f1_43[0]', ''),
#              ('f1_44[0]', ''),
#              ('f1_45[0]', ''),
#              ('f1_46[0]', ''),
#              ('f1_47[0]', ''),
#              ('f1_48[0]', ''),
#              ('f1_49[0]', ''),
#              ('f1_50[0]', ''),
#              ('f1_51[0]', ''),
#              ('c1_22[0]', '/Off'),
#              ('c1_23[0]', '/Off'),
#              ('f1_52[0]', ''),
#              ('f1_53[0]', ''),
#              ('f1_54[0]', ''),
#              ('f1_55[0]', ''),
#              ('f1_56[0]', ''),
#              ('Line4a-11_ReadOrder[0]', ''),
#              ('f1_57[0]', ''),
#              ('f1_58[0]', ''),
#              ('f1_59[0]', ''),
#              ('f1_60[0]', ''),
#              ('Page1[0]', ''),
#              ('c2_1[0]', '/Off'),
#              ('c2_2[0]', '/Off'),
#              ('c2_3[0]', '/Off'),
#              ('f2_01[0]', ''),
#              ('f2_02[0]', ''),
#              ('f2_03[0]', ''),
#              ('f2_04[0]', ''),
#              ('f2_05[0]', ''),
#              ('f2_06[0]', ''),
#              ('f2_07[0]', ''),
#              ('f2_08[0]', ''),
#              ('f2_09[0]', ''),
#              ('f2_10[0]', ''),
#              ('f2_11[0]', ''),
#              ('f2_12[0]', ''),
#              ('f2_13[0]', ''),
#              ('f2_14[0]', ''),
#              ('f2_15[0]', ''),
#              ('f2_16[0]', ''),
#              ('f2_17[0]', ''),
#              ('f2_18[0]', ''),
#              ('f2_19[0]', ''),
#              ('f2_20[0]', ''),
#              ('f2_21[0]', ''),
#              ('f2_22[0]', ''),
#              ('f2_23[0]', ''),
#              ('c2_4[0]', '/Off'),
#              ('f2_24[0]', ''),
#              ('f2_25[0]', ''),
#              ('RoutingNo[0]', ''),
#              ('c2_5[0]', '/Off'),
#              ('c2_5[1]', '/Off'),
#              ('f2_26[0]', ''),
#              ('AccountNo[0]', ''),
#              ('f2_27[0]', ''),
#              ('f2_28[0]', ''),
#              ('f2_29[0]', ''),
#              ('c2_6[0]', '/Off'),
#              ('c2_6[1]', '/Off'),
#              ('f2_30[0]', ''),
#              ('f2_31[0]', ''),
#              ('f2_32[0]', ''),
#              ('f2_33[0]', ''),
#              ('f2_34[0]', ''),
#              ('f2_35[0]', ''),
#              ('f2_36[0]', ''),
#              ('f2_37[0]', ''),
#              ('f2_38[0]', ''),
#              ('f2_39[0]', ''),
#              ('f2_40[0]', ''),
#              ('c2_7[0]', '/Off'),
#              ('f2_41[0]', ''),
#              ('f2_42[0]', ''),
#              ('f2_43[0]', ''),
#              ('f2_44[0]', ''),
#              ('Page2[0]', ''),
#              ('topmostSubform[0]', '')])

# %%
# Print the fields in a formatted way
print("PDF Form Fields:")
print("-" * 50)
print(f"{'Field Name':<30} | {'Alternate Label':<30} | {'Value':<30}")
print("-" * 50)
for entry in form_data:
    field_name, alternate_label, value = entry
    print(f"{str(field_name):<30} | {str(alternate_label):<30} | {str(value):<30}")

# Close the PDF
pdf.close()
# Out:
# PDF Form Fields:
# --------------------------------------------------
# Field Name                     | Alternate Label                | Value
# --------------------------------------------------
# topmostSubform[0].Page1[0].f1_01[0] | None                           | None
# topmostSubform[0].Page1[0].f1_02[0] | None                           | None
# topmostSubform[0].Page1[0].f1_03[0] | None                           | None
# topmostSubform[0].Page1[0].f1_04[0] | None                           | None
# topmostSubform[0].Page1[0].f1_05[0] | None                           | None
# topmostSubform[0].Page1[0].f1_06[0] | None                           | None
# topmostSubform[0].Page1[0].f1_07[0] | None                           | None
# topmostSubform[0].Page1[0].f1_08[0] | None                           | None
# topmostSubform[0].Page1[0].f1_09[0] | None                           | None
# topmostSubform[0].Page1[0].Address_ReadOrder[0].f1_10[0] | None                           | None
# topmostSubform[0].Page1[0].Address_ReadOrder[0].f1_11[0] | None                           | None
# topmostSubform[0].Page1[0].Address_ReadOrder[0].f1_12[0] | None                           | None
# topmostSubform[0].Page1[0].Address_ReadOrder[0].f1_13[0] | None                           | None
# topmostSubform[0].Page2[0].f2_21[0] | None                           | None
# topmostSubform[0].Page2[0].f2_22[0] | None                           | None
# topmostSubform[0].Page2[0].f2_23[0] | None                           | None
# topmostSubform[0].Page2[0].c2_4[0] | None                           | Off
# topmostSubform[0].Page2[0].f2_24[0] | None                           | None
# topmostSubform[0].Page2[0].RoutingNo[0].f2_25[0] | None                           | None
# topmostSubform[0].Page2[0].RoutingNo[0] | None                           | None
# topmostSubform[0].Page2[0].c2_5[0] | None                           | Off
# topmostSubform[0].Page2[0].c2_5[1] | None                           | Off
# topmostSubform[0].Page2[0].AccountNo[0].f2_26[0] | None                           | None
# topmostSubform[0].Page2[0].AccountNo[0] | None                           | None
# topmostSubform[0].Page2[0].f2_27[0] | None                           | None
# topmostSubform[0].Page2[0].f2_28[0] | None                           | None
# topmostSubform[0].Page2[0].f2_29[0] | None                           | None
# topmostSubform[0].Page2[0].c2_6[0] | None                           | Off
# topmostSubform[0].Page2[0].c2_6[1] | None                           | Off
# topmostSubform[0].Page2[0].f2_30[0] | None                           | None
# topmostSubform[0].Page2[0].f2_31[0] | None                           | None
# topmostSubform[0].Page2[0].f2_32[0] | None                           | None
# topmostSubform[0].Page2[0].f2_33[0] | None                           | None
# topmostSubform[0].Page2[0].f2_34[0] | None                           | None
# topmostSubform[0].Page2[0].f2_35[0] | None                           | None
# topmostSubform[0].Page2[0].f2_36[0] | None                           | None
# topmostSubform[0].Page2[0].f2_37[0] | None                           | None
# topmostSubform[0].Page2[0].f2_38[0] | None                           | None
# topmostSubform[0].Page2[0].f2_39[0] | None                           | None
# topmostSubform[0].Page2[0].f2_40[0] | None                           | None
# topmostSubform[0].Page2[0].c2_7[0] | None                           | Off
# topmostSubform[0].Page2[0].f2_41[0] | None                           | None
# topmostSubform[0].Page2[0].f2_42[0] | None                           | None
# topmostSubform[0].Page2[0].f2_43[0] | None                           | None
# topmostSubform[0].Page2[0].f2_44[0] | None                           | None
# topmostSubform[0].Page2[0]     | None                           | None
# topmostSubform[0]              | None                           | None

# %%
from PyPDF2 import PdfReader, PdfWriter
from collections import OrderedDict

def get_fields(obj, tree=None, retval=None, fileobj=None):
    # Your original function to extract fields
    fieldAttributes = {'/FT': 'Field Type', '/Parent': 'Parent', '/T': 'Field Name', '/TU': 'Alternate Field Name',
                    '/TM': 'Mapping Name', '/Ff': 'Field Flags', '/V': 'Value', '/DV': 'Default Value'}
    if retval is None:
        retval = OrderedDict()
        catalog = obj.trailer["/Root"]
        if "/AcroForm" in catalog:
            tree = catalog["/AcroForm"]
        else:
            return None
    if tree is None:
        return retval
    obj._check_kids(tree, retval, fileobj)
    for attr in fieldAttributes:
        if attr in tree:
            obj._build_field(tree, retval, fileobj, fieldAttributes)
            break
    if "/Fields" in tree:
        fields = tree["/Fields"]
        for f in fields:
            field = f.get_object()
            obj._build_field(field, retval, fileobj, fieldAttributes)
    return retval

def get_form_fields(infile):
    with open(infile, 'rb') as file:
        infile = PdfReader(file)
        fields = get_fields(infile)
        return OrderedDict((k, v.get('/V', '')) for k, v in fields.items())

def fill_pdf_fields(input_pdf, output_pdf):
    # Read the input PDF and get the fields
    with open(input_pdf, 'rb') as infile:
        reader = PdfReader(infile)
        writer = PdfWriter()

        # Get form fields and values
        fields = get_form_fields(input_pdf)

        # Copy all pages and fill the fields
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            writer.add_page(page)

        # Fill the fields in the output PDF
        for field, value in fields.items():
            # Set field value by matching field names
            writer.update_page_form_field_values(reader.pages[0], {field: value})

        # Save the filled PDF
        with open(output_pdf, 'wb') as outfile:
            writer.write(outfile)

# Example usage
input_pdf = 'f1040_filled.pdf'
output_pdf = 'f1040_output.pdf'
fill_pdf_fields(input_pdf, output_pdf)

# %%
from PyPDF2 import PdfReader
from collections import OrderedDict

def get_fields(obj, tree=None, retval=None, fileobj=None):
    fieldAttributes = {'/FT': 'Field Type', '/Parent': 'Parent', '/T': 'Field Name', '/TU': 'Alternate Field Name',
                    '/TM': 'Mapping Name', '/Ff': 'Field Flags', '/V': 'Value', '/DV': 'Default Value'}
    if retval is None:
        retval = OrderedDict()
        catalog = obj.trailer["/Root"]
        if "/AcroForm" in catalog:
            tree = catalog["/AcroForm"]
        else:
            return None
    if tree is None:
        return retval
    obj._check_kids(tree, retval, fileobj)
    for attr in fieldAttributes:
        if attr in tree:
            obj._build_field(tree, retval, fileobj, fieldAttributes)
            break
    if "/Fields" in tree:
        fields = tree["/Fields"]
        for f in fields:
            field = f.get_object()
            obj._build_field(field, retval, fileobj, fieldAttributes)
    return retval

def get_form_fields(infile):
    with open(infile, 'rb') as file:
        infile = PdfReader(file)
        fields = get_fields(infile)
        
        # Let's print the raw field names and values
        raw_fields = {}
        for k, v in fields.items():
            raw_fields[k] = v.get('/V', '')
        
        print("Extracted Fields and Values:")
        for key, value in raw_fields.items():
            print(f"Field Name: {key}, Value: {value}")
            
        return raw_fields

if __name__ == '__main__':
    from pprint import pprint
    pdf_file_name = 'f1040_filled.pdf'
    pprint(get_form_fields(pdf_file_name))
# Out:
# Extracted Fields and Values:
# Field Name: f1_01[0], Value:
# Field Name: f1_02[0], Value:
# Field Name: f1_03[0], Value:
# Field Name: f1_04[0], Value:
# Field Name: f1_05[0], Value:
# Field Name: f1_06[0], Value:
# Field Name: f1_07[0], Value:
# Field Name: f1_08[0], Value:
# Field Name: f1_09[0], Value:
# Field Name: f1_10[0], Value:
# Field Name: f1_11[0], Value:
# Field Name: f1_12[0], Value:
# Field Name: f1_13[0], Value:
# Field Name: f1_14[0], Value:
# Field Name: f1_15[0], Value:
# Field Name: f1_16[0], Value:
# Field Name: f1_17[0], Value:
# Field Name: Address_ReadOrder[0], Value:
# Field Name: c1_1[0], Value: /Off
# Field Name: c1_2[0], Value: /Off
# Field Name: c1_3[0], Value: /Off
# Field Name: c1_3[1], Value: /Off
# Field Name: c1_3[2], Value: /Off
# Field Name: FilingStatus_ReadOrder[0], Value:
# Field Name: f1_18[0], Value:
# Field Name: c1_4[0], Value: /Off
# Field Name: f1_19[0], Value:
# Field Name: c1_5[0], Value: /Off
# Field Name: c1_5[1], Value: /Off
# Field Name: c1_6[0], Value: /Off
# Field Name: c1_7[0], Value: /Off
# Field Name: c1_8[0], Value: /Off
# Field Name: c1_9[0], Value: /Off
# Field Name: c1_10[0], Value: /Off
# Field Name: c1_11[0], Value: /Off
# Field Name: c1_12[0], Value: /Off
# Field Name: c1_13[0], Value: /Off
# Field Name: Dependents_ReadOrder[0], Value:
# Field Name: f1_20[0], Value:
# Field Name: f1_21[0], Value:
# Field Name: f1_22[0], Value:
# Field Name: c1_14[0], Value: /Off
# Field Name: c1_15[0], Value: /Off
# Field Name: Row1[0], Value:
# Field Name: f1_23[0], Value:
# Field Name: f1_24[0], Value:
# Field Name: f1_25[0], Value:
# Field Name: c1_16[0], Value: /Off
# Field Name: c1_17[0], Value: /Off
# Field Name: Row2[0], Value:
# Field Name: f1_26[0], Value:
# Field Name: f1_27[0], Value:
# Field Name: f1_28[0], Value:
# Field Name: c1_18[0], Value: /Off
# Field Name: c1_19[0], Value: /Off
# Field Name: Row3[0], Value:
# Field Name: f1_29[0], Value:
# Field Name: f1_30[0], Value:
# Field Name: f1_31[0], Value:
# Field Name: c1_20[0], Value: /Off
# Field Name: c1_21[0], Value: /Off
# Field Name: Row4[0], Value:
# Field Name: Table_Dependents[0], Value:
# Field Name: f1_32[0], Value:
# Field Name: f1_33[0], Value:
# Field Name: f1_34[0], Value:
# Field Name: f1_35[0], Value:
# Field Name: f1_36[0], Value:
# Field Name: f1_37[0], Value:
# Field Name: f1_38[0], Value:
# Field Name: f1_39[0], Value:
# Field Name: f1_40[0], Value:
# Field Name: f1_41[0], Value:
# Field Name: f1_42[0], Value:
# Field Name: f1_43[0], Value:
# Field Name: f1_44[0], Value:
# Field Name: f1_45[0], Value:
# Field Name: f1_46[0], Value:
# Field Name: f1_47[0], Value:
# Field Name: f1_48[0], Value:
# Field Name: f1_49[0], Value:
# Field Name: f1_50[0], Value:
# Field Name: f1_51[0], Value:
# Field Name: c1_22[0], Value: /Off
# Field Name: c1_23[0], Value: /Off
# Field Name: f1_52[0], Value:
# Field Name: f1_53[0], Value:
# Field Name: f1_54[0], Value:
# Field Name: f1_55[0], Value:
# Field Name: f1_56[0], Value:
# Field Name: Line4a-11_ReadOrder[0], Value:
# Field Name: f1_57[0], Value:
# Field Name: f1_58[0], Value:
# Field Name: f1_59[0], Value:
# Field Name: f1_60[0], Value:
# Field Name: Page1[0], Value:
# Field Name: c2_1[0], Value: /Off
# Field Name: c2_2[0], Value: /Off
# Field Name: c2_3[0], Value: /Off
# Field Name: f2_01[0], Value:
# Field Name: f2_02[0], Value:
# Field Name: f2_03[0], Value:
# Field Name: f2_04[0], Value:
# Field Name: f2_05[0], Value:
# Field Name: f2_06[0], Value:
# Field Name: f2_07[0], Value:
# Field Name: f2_08[0], Value:
# Field Name: f2_09[0], Value:
# Field Name: f2_10[0], Value:
# Field Name: f2_11[0], Value:
# Field Name: f2_12[0], Value:
# Field Name: f2_13[0], Value:
# Field Name: f2_14[0], Value:
# Field Name: f2_15[0], Value:
# Field Name: f2_16[0], Value:
# Field Name: f2_17[0], Value:
# Field Name: f2_18[0], Value:
# Field Name: f2_19[0], Value:
# Field Name: f2_20[0], Value:
# Field Name: f2_21[0], Value:
# Field Name: f2_22[0], Value:
# Field Name: f2_23[0], Value:
# Field Name: c2_4[0], Value: /Off
# Field Name: f2_24[0], Value:
# Field Name: f2_25[0], Value:
# Field Name: RoutingNo[0], Value:
# Field Name: c2_5[0], Value: /Off
# Field Name: c2_5[1], Value: /Off
# Field Name: f2_26[0], Value:
# Field Name: AccountNo[0], Value:
# Field Name: f2_27[0], Value:
# Field Name: f2_28[0], Value:
# Field Name: f2_29[0], Value:
# Field Name: c2_6[0], Value: /Off
# Field Name: c2_6[1], Value: /Off
# Field Name: f2_30[0], Value:
# Field Name: f2_31[0], Value:
# Field Name: f2_32[0], Value:
# Field Name: f2_33[0], Value:
# Field Name: f2_34[0], Value:
# Field Name: f2_35[0], Value:
# Field Name: f2_36[0], Value:
# Field Name: f2_37[0], Value:
# Field Name: f2_38[0], Value:
# Field Name: f2_39[0], Value:
# Field Name: f2_40[0], Value:
# Field Name: c2_7[0], Value: /Off
# Field Name: f2_41[0], Value:
# Field Name: f2_42[0], Value:
# Field Name: f2_43[0], Value:
# Field Name: f2_44[0], Value:
# Field Name: Page2[0], Value:
# Field Name: topmostSubform[0], Value:
# {'AccountNo[0]': '',
#  'Address_ReadOrder[0]': '',
#  'Dependents_ReadOrder[0]': '',
#  'FilingStatus_ReadOrder[0]': '',
#  'Line4a-11_ReadOrder[0]': '',
#  'Page1[0]': '',
#  'Page2[0]': '',
#  'RoutingNo[0]': '',
#  'Row1[0]': '',
#  'Row2[0]': '',
#  'Row3[0]': '',
#  'Row4[0]': '',
#  'Table_Dependents[0]': '',
#  'c1_10[0]': '/Off',
#  'c1_11[0]': '/Off',
#  'c1_12[0]': '/Off',
#  'c1_13[0]': '/Off',
#  'c1_14[0]': '/Off',
#  'c1_15[0]': '/Off',
#  'c1_16[0]': '/Off',
#  'c1_17[0]': '/Off',
#  'c1_18[0]': '/Off',
#  'c1_19[0]': '/Off',
#  'c1_1[0]': '/Off',
#  'c1_20[0]': '/Off',
#  'c1_21[0]': '/Off',
#  'c1_22[0]': '/Off',
#  'c1_23[0]': '/Off',
#  'c1_2[0]': '/Off',
#  'c1_3[0]': '/Off',
#  'c1_3[1]': '/Off',
#  'c1_3[2]': '/Off',
#  'c1_4[0]': '/Off',
#  'c1_5[0]': '/Off',
#  'c1_5[1]': '/Off',
#  'c1_6[0]': '/Off',
#  'c1_7[0]': '/Off',
#  'c1_8[0]': '/Off',
#  'c1_9[0]': '/Off',
#  'c2_1[0]': '/Off',
#  'c2_2[0]': '/Off',
#  'c2_3[0]': '/Off',
#  'c2_4[0]': '/Off',
#  'c2_5[0]': '/Off',
#  'c2_5[1]': '/Off',
#  'c2_6[0]': '/Off',
#  'c2_6[1]': '/Off',
#  'c2_7[0]': '/Off',
#  'f1_01[0]': '',
#  'f1_02[0]': '',
#  'f1_03[0]': '',
#  'f1_04[0]': '',
#  'f1_05[0]': '',
#  'f1_06[0]': '',
#  'f1_07[0]': '',
#  'f1_08[0]': '',
#  'f1_09[0]': '',
#  'f1_10[0]': '',
#  'f1_11[0]': '',
#  'f1_12[0]': '',
#  'f1_13[0]': '',
#  'f1_14[0]': '',
#  'f1_15[0]': '',
#  'f1_16[0]': '',
#  'f1_17[0]': '',
#  'f1_18[0]': '',
#  'f1_19[0]': '',
#  'f1_20[0]': '',
#  'f1_21[0]': '',
#  'f1_22[0]': '',
#  'f1_23[0]': '',
#  'f1_24[0]': '',
#  'f1_25[0]': '',
#  'f1_26[0]': '',
#  'f1_27[0]': '',
#  'f1_28[0]': '',
#  'f1_29[0]': '',
#  'f1_30[0]': '',
#  'f1_31[0]': '',
#  'f1_32[0]': '',
#  'f1_33[0]': '',
#  'f1_34[0]': '',
#  'f1_35[0]': '',
#  'f1_36[0]': '',
#  'f1_37[0]': '',
#  'f1_38[0]': '',
#  'f1_39[0]': '',
#  'f1_40[0]': '',
#  'f1_41[0]': '',
#  'f1_42[0]': '',
#  'f1_43[0]': '',
#  'f1_44[0]': '',
#  'f1_45[0]': '',
#  'f1_46[0]': '',
#  'f1_47[0]': '',
#  'f1_48[0]': '',
#  'f1_49[0]': '',
#  'f1_50[0]': '',
#  'f1_51[0]': '',
#  'f1_52[0]': '',
#  'f1_53[0]': '',
#  'f1_54[0]': '',
#  'f1_55[0]': '',
#  'f1_56[0]': '',
#  'f1_57[0]': '',
#  'f1_58[0]': '',
#  'f1_59[0]': '',
#  'f1_60[0]': '',
#  'f2_01[0]': '',
#  'f2_02[0]': '',
#  'f2_03[0]': '',
#  'f2_04[0]': '',
#  'f2_05[0]': '',
#  'f2_06[0]': '',
#  'f2_07[0]': '',
#  'f2_08[0]': '',
#  'f2_09[0]': '',
#  'f2_10[0]': '',
#  'f2_11[0]': '',
#  'f2_12[0]': '',
#  'f2_13[0]': '',
#  'f2_14[0]': '',
#  'f2_15[0]': '',
#  'f2_16[0]': '',
#  'f2_17[0]': '',
#  'f2_18[0]': '',
#  'f2_19[0]': '',
#  'f2_20[0]': '',
#  'f2_21[0]': '',
#  'f2_22[0]': '',
#  'f2_23[0]': '',
#  'f2_24[0]': '',
#  'f2_25[0]': '',
#  'f2_26[0]': '',
#  'f2_27[0]': '',
#  'f2_28[0]': '',
#  'f2_29[0]': '',
#  'f2_30[0]': '',
#  'f2_31[0]': '',
#  'f2_32[0]': '',
#  'f2_33[0]': '',
#  'f2_34[0]': '',
#  'f2_35[0]': '',
#  'f2_36[0]': '',
#  'f2_37[0]': '',
#  'f2_38[0]': '',
#  'f2_39[0]': '',
#  'f2_40[0]': '',
#  'f2_41[0]': '',
#  'f2_42[0]': '',
#  'f2_43[0]': '',
#  'f2_44[0]': '',
#  'topmostSubform[0]': ''}
