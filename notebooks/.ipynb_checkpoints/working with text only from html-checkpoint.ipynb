# %%
# get all text only
# WORKS
# - has tehcnical texts like action texts like -Message, save etc.

# %%
from bs4 import BeautifulSoup
import re

# Specify the path to your HTML file
file_path = 'C:/Users/i7714/Downloads/Search_Sales_Navigator.html'

# Open and read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find and remove all button elements
for button in soup.find_all('button'):
    button.decompose()

# Extract text
text_only = soup.get_text()

# Remove multiple newlines and leave one
cleaned_text = re.sub(r'\n+', '\n', text_only)

# Print the cleaned text
print(cleaned_text)
# Out:
# ﻿
# Search | Sales Navigator
#
#                   Account
#
#                         Settings
#
#
#                           Sales Navigator Coach
#
#
#                         Referrals
#
#                       Who’s Viewed Your Profile
#
#                         Social Selling Index
#
#                 Legal
#
#                     User agreement
#
#                     Privacy policy
#
#                     Cookie policy
#
#                       Your California privacy choices
#
#                 Other
#
#                     Go to LinkedIn.com
#
#                     Log out
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Sales Navigator
#
#                           Home
#
#                       Accounts
#
#                   Leads
#
#
#
#                       Messaging
#
#
#     Actions List
#
#                 Referrals
#
#         Lead
#
#         Account
#
#       talent, 501-1000, 1001-5000, 5001-10,000, 10,000+, Human Resources, Massachusetts, United States, 2nd degree connections, Emil Jacob
#
#       (5 filters)
#
#       Save search to get notified of new results
#
#         Off
#
#
#
#     Pinned filter
#
#
#       Unable to unpin filter
#
#       You must have at least one pinned filter.
#
#       Filter for leads who currently work at one or more companies.
#
#             Find your target leads by filtering by your book of business.
#
#       Find leads most likely to respond to outreach or express an interest in your product or service.
#
#       Leverage your network to find the best path into a company and uncover information to tailor your outreach.
#
#       Identify leads who have changed jobs in the last 90d, posted on LinkedIn in the last 30d, or were in the news in the last 90d. Use this information to personalize your outreach or find leads who are more likely to respond.
#
#       Personas are defined by function, seniority, job title, and geography.
#
#       Leads you viewed in the last 90 days or messaged in the last 2 years on Sales Navigator
#
#       Filter for leads who worked at one or more companies.
#
#             Find past customers by adding a list of your current and past customers.
#
#             Find past colleagues by adding a list of your current and past employers.
#
#           Company
#
#
#             Current company
#
#
#             Company headcount
#
#
#
#             Past company
#
#
#             Company type
#
#
#             Company headquarters location
#
#
#           Role
#
#
#             Function
#
#
#
#
#           Human Resources
#
#
#             Current job title
#
#
#             Seniority level
#
#
#             Past job title
#
#
#             Years in current company
#
#
#             Years in current position
#
#
#           Personal
#
#
#             Geography
#
# Try advanced filters to refine your search
# Use the Geography, Industry, and Title filters to find the right people.
#
#
#
#           Massachusetts, United States
#
#
#             Industry
#
#
#             First name
#
#
#             Last name
#
#
#             Profile language
#
#
#             Years of experience
#
#
#             Groups
#
#
#             School
#
#
#
#           Buyer intent
#
#             Following your company
#
#               (0)
#
#
#     Select Following your company filter
#
#         Off
#
#             Viewed your profile recently
#
#               (0)
#
#
#     Select Viewed your profile recently filter
#
#         Off
#
#           Best path in
#
#             Connection
#
#
#
#             Connections of
#
#
#
#             Past colleague
#
#               (0)
#
#
#     Select Past colleague filter
#
#         Off
#
#             Shared experiences
#
#               (0)
#
#
#     Select Shared experiences filter
#
#         Off
#
#           Recent updates
#
#             Changed jobs
#
#               (0)
#
#
#     Select Changed jobs filter
#
#         Off
#
#             Posted on LinkedIn
#
#               (5)
#
#
#     Select Posted on LinkedIn filter
#
#         Off
#
#             Mentioned in news
#
#               (0)
#
#
#     Select Mentioned in news filter
#
#         Off
#
#           Workflow
#
#
#             Persona
#
#             New
#
#             Account lists
#
#
#             Lead lists
#
#
#             People in CRM
#
#
#       To enable filter, upgrade contract
#
#             People you interacted with
#
#
#             Saved leads and accounts
#
#
#
# Search keywords
# Try a keyword search like CEO to cast a wide net for potential leads. Then use filters to refine your search.
#
#
#
#
#
#
#                     Select all
#
#       21 results
#
#
#
#
#
#
#
#         Mutual connections
#
#         Ask David E or Emil for a warm introduction to Matilda.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Melanie.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Andy.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Alex.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Kavitha.
#
#         Mutual connections
#
#         Ask Alisa or Emil for a warm introduction to Justin.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Sam.
#
#         Posts on LinkedIn in the last 30 days
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to David.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Derek.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Molly.
#
#         Mutual connections
#
#         Ask Alena or Emil for a warm introduction to Pratima.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Danijela.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Steve.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Doug.
#
#         Mutual connections
#
#         Ask Alena or Emil for a warm introduction to John.
#
#         Posts on LinkedIn in the last 30 days
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Chris.
#
#         Posts on LinkedIn in the last 30 days
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Angie.
#
#         Posts on LinkedIn in the last 30 days
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Tony.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Dionne.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Brian Thibeault.
#
#         Mutual connection
#
#         Message your 1st degree connection, Emil, for a warm introduction to Mark.
#
#                                 Add Chris Gonzalez to selection
#
#       Chris Gonzalez is reachable
#
#               Chris Gonzalez
#
#  2nd degree connection
#     · 2nd
#
#
#
# Senior Corporate Recruiter
#             NETSCOUT
#
# Greater Boston
#           8 years 9 months in role
#
#           8 years 9 months in company
#
# About:
# Senior Corporate Recruiter with 2
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Angie Boudreau, SHRM-CP to selection
#
#       Angie Boudreau, SHRM-CP is reachable
#
#               Angie Boudreau, SHRM-CP
#
#  2nd degree connection
#     · 2nd
#
#
#
# Associate Director, Strategic Talent Sourcing & Discovery
#             Harvard University
#
# Cambridge, Massachusetts, United States
#           1 year 1 month in role
#
#           4 years 10 months in company
#
# About:
# Talent Acquisition professional wit
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Steve McCarthy to selection
#
#       Steve McCarthy is reachable
#
#               Steve McCarthy
#
#  2nd degree connection
#     · 2nd
#
#
# Sr. Talent Advisor
#             Novo Nordisk
#
# Greater Boston
#           1 year 1 month in role
#
#           1 year 1 month in company
#
# Experience:
#           2015 – 2022
#
#           (
#           7 yrs 4 mos
#           )
#
#         Insulet Corporation
#
#         Sr. Talent Aquisition
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Doug Noble to selection
#
#       Doug Noble is reachable
#
#               Doug Noble
#
#  2nd degree connection
#     · 2nd
#
#
#
# Senior Staffing Consultant - Digital & Creative
#             Beacon Hill
#
# Boston, Massachusetts, United States
#           2 years 10 months in role
#
#           2 years 10 months in company
#
# About:
# I'm an experienced Staffing Profes
# Experience:
#           2017 – 2022
#
#           (
#           4 yrs 9 mos
#           )
#
#         Onward Search | Digital Creative and Technology Talent
#
#         VP of Client Services, Boston
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add John Todd to selection
#
#       John Todd is reachable
#
#               John Todd
#
#  2nd degree connection
#     · 2nd
#
#
#
# Director Talent Acquisition
#             The Vertex Companies LLC
#
# Boston, Massachusetts, United States
#           1 year  in role
#
#           3 years 5 months in company
#
# About:
# Hiring for all Forensics, Contract C
# Experience:
#           2022 – 2023
#
#           (
#           1 yr 8 mos
#           )
#
#         The Vertex Companies LLC
#
#         Talent Acquisition Manager
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Dionne Melo to selection
#
#       Dionne Melo is reachable
#
#               Dionne Melo
#
#  2nd degree connection
#     · 2nd
#
#
#
# Sr Recruiter
#             Softworld, a Kelly Company
#
# Westport, Massachusetts, United States
#            6 months in role
#
#            6 months in company
#
# Experience:
#           2023 – 2024
#
#           (
#           9 mos
#           )
#
#         CVS Health
#
#         Talent Acquisition Partner
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Brian Thibeault AIHR Certified Talent Acquisition Specialist to selection
#
#       Brian Thibeault AIHR Certified Talent Acquisition Specialist is reachable
#
#               Brian Thibeault AIHR Certified Talent Acquisition Specialist
#
#  2nd degree connection
#     · 2nd
#
#
#
# Senior Talent Acquisition Consultant
#             Harvard University
#
# Cambridge, Massachusetts, United States
#           4 years 10 months in role
#
#           6 years 9 months in company
#
# About:
# Passionate recruiter with a drive t
# Experience:
#           2008 – 2010
#
#           (
#           2 yrs 8 mos
#           )
#
#         Zimmerman Advertising
#
#         Talent Acquisition Manager
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Mark Martino to selection
#
#       Mark Martino is reachable
#
#               Mark Martino
#
#  2nd degree connection
#     · 2nd
#
#
# Senior Director of HRIS
#             Berklee College of Music
#
# Boston, Massachusetts, United States
#           17 years 11 months in role
#
#           33 years 11 months in company
#
# About:
# HR business system owner. Ensuri
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Molly MacNeill to selection
#
#       Molly MacNeill is reachable
#
#               Molly MacNeill
#
#  2nd degree connection
#     · 2nd
#
#
#
# Senior Staffing Consultant
#             Beacon Hill Staffing Group
#
# Scituate, Massachusetts, United States
#           4 years 9 months in role
#
#           4 years 9 months in company
#
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Pratima Tothempudi to selection
#
#       Pratima Tothempudi is reachable
#
#               Pratima Tothempudi
#
#  2nd degree connection
#     · 2nd
#
#
# Director, HR Business Partner CMC at Moderna
#             Moderna
#
# Burlington, Massachusetts, United States
#           1 year 3 months in role
#
#           1 year 3 months in company
#
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Danijela Pajevic to selection
#
#       Danijela Pajevic is reachable
#
#               Danijela Pajevic
#
#  2nd degree connection
#     · 2nd
#
#
#
# Global Talent Acquisition, Business Partner - Global Sales & HPEFS
#             Hewlett Packard Enterprise
#
# Boston, Massachusetts, United States
#            5 months in role
#
#           3 years  in company
#
# Experience:
#           2021 – 2024
#
#           (
#           2 yrs 7 mos
#           )
#
#         Hewlett Packard Enterprise
#
#         Global Talent Acquisition, Recruiting Lead
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Tony Melino to selection
#
#       Tony Melino is reachable
#
#               Tony Melino
#
#  2nd degree connection
#     · 2nd
#
#
#
# Sr. Talent Advisor, North America
#             MilliporeSigma
#
# Boston, Massachusetts, United States
#           1 year 11 months in role
#
#           3 years 7 months in company
#
# Experience:
#           2021 – 2023
#
#           (
#           1 yr 9 mos
#           )
#
#         MilliporeSigma
#
#         Talent Acquisition Partner, Life Sciences
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Derek Guilford to selection
#
#       Derek Guilford is reachable
#
#               Derek Guilford
#
#  2nd degree connection
#     · 2nd
#
#
# Lead Talent Attraction Consultant - Go To Market
#             Pegasystems
#
# Greater Boston
#           2 years 5 months in role
#
#           8 years 9 months in company
#
# About:
# Thanks for visiting my LinkedIn pr
# Experience:
#           2016 – 2022
#
#           (
#           6 yrs 5 mos
#           )
#
#         Pegasystems
#
#         Senior Talent Acquisition Consultant - Go To Market
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add David Roberto to selection
#
#       David Roberto is reachable
#
#               David Roberto
#
#  2nd degree connection
#     · 2nd
#
#
#
# Director Of Staffing
#             Bay State Search
#
# Burlington, Massachusetts, United States
#           10 years 6 months in role
#
#           10 years 6 months in company
#
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Justin Spano to selection
#
#       Justin Spano is reachable
#
#               Justin Spano
#
#  2nd degree connection
#     · 2nd
#
#
#             Viewed
#
#             You’ve already seen Justin Spano’s profile before.
#
#
# Senior Talent Acquisition Partner
#             Everbridge
#
# Greater Boston
#           3 years 7 months in role
#
#           3 years 7 months in company
#
# About:
# As a Senior Talent Acquisition Part
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Matilda Hart to selection
#
#       Matilda Hart is reachable
#
#               Matilda Hart
#
#  2nd degree connection
#     · 2nd
#
#
# Manager, Global Talent Acquisition
#             Monster
#
# Greater Boston
#           2 years 9 months in role
#
#           5 years 6 months in company
#
# About:
# Influential and experienced talent
# Experience:
#           2019 – 2022
#
#           (
#           2 yrs 10 mos
#           )
#
#         Monster
#
#         Talent Acquisition Partner
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Sam Oliver (she/her) to selection
#
#       Sam Oliver (she/her) is reachable
#
#               Sam Oliver (she/her)
#
#  2nd degree connection
#     · 2nd
#
#
#
# Senior Staffing Consultant
#             Beacon Hill Staffing Group
#
# Greater Boston
#            10 months in role
#
#            10 months in company
#
# About:
# Technical recruiter with ten years'
# Experience:
#           2015 – 2015
#
#           (
#           9 mos
#           )
#
#         Rapid7
#
#         Junior Talent Scout
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Kavitha K to selection
#
#       Kavitha K is reachable
#
#               Kavitha K
#
#  2nd degree connection
#     · 2nd
#
#
# Principal Recruiter/Diversity Sourcer
#             Capital One
#
# Greater Boston
#           2 years 7 months in role
#
#           2 years 7 months in company
#
# Experience:
#           2018 – 2021
#
#           (
#           3 yrs 2 mos
#           )
#
#         Interactions LLC
#
#         Talent Acquisition Specialist  Thru Hub Recruiting
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Alex Guerra to selection
#
#       Alex Guerra is reachable
#
#               Alex Guerra
#
#  2nd degree connection
#     · 2nd
#
#
# Human Resources Manager
#             Worcester Public Schools
#
# Greater Boston
#            5 months in role
#
#            5 months in company
#
# About:
# • Results-driven Talent Acquisition
# Experience:
#           2022 – 2024
#
#           (
#           1 yr 9 mos
#           )
#
#         Chick-fil-A Restaurants
#
#         Director of Talent Acquisition
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Melanie Ash to selection
#
#       Melanie Ash is reachable
#
#               Melanie Ash
#
#  2nd degree connection
#     · 2nd
#
#
# Senior Recruiter
#             Randstad Technologies US
#
# Greater Boston
#           1 year 10 months in role
#
#           7 years 1 month in company
#
# About:
# Working every day to connect the
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#                                 Add Andy Wilson to selection
#
#       Andy Wilson is reachable
#
#               Andy Wilson
#
#  2nd degree connection
#     · 2nd
#
#
#
# Agency Senior Recruiter
#             Motion Recruitment
#
# Boston, Massachusetts, United States
#            7 months in role
#
#           2 years 6 months in company
#
#
#
#
#
#             InMails get 5x more responses than emails
#
#             Send a personalized message—ask about their interests or mention your mutual connections.
#
# Save lead
# Save this lead to your list and get alerts when they change jobs, post to LinkedIn, and more.
#         Are these results helpful?
#
#           Your feedback helps us improve search results.
#
#
#         0 notifications total
#
#
#                 The Vertex Companies LLC
#
#                 East Weymouth, Massachusetts, United States
#
#                 Engineering Services
#
#
#                   697 employees
#
#           VERTEX is a fast-growth AEC firm that delivers integrated Forensics, Construction Project Advisory, Compliance, and Regulatory solutions on complex projects that span the globe. Having forensics experts working alongside AEC specialists enhances our skills and bolsters the credibility of our expert consultants. It is what we mean when we say we are dedicated to the "Power of AND' We reject the notion that businesses need to be one way OR the other. We believe in linking uncommon behaviors and beliefs to provide unique solutions that better outcomes. It is the audacious belief that a company can be experts who care enough to create results and a great experience while remaining business-centric and environmentally friendly.
# Our Power of And differentiation means:
# We offer Constant Urgency AND Unparalleled Quality
# We offer Forensic Consulting AND Traditional AEC Services
# We offer Boutique Expertise AND Multi-Disciplined Solutions
# We are Entrepreneurial AND Financially Stable
# We are Industry Experts AND Lifetime Learners
# We are Customer Centric AND Colleague Focused
# We Talk the Talk AND Walk the Walk
# We Care About our Clients AND Employees
# Our brand purpose is to better outcomes for our clients, colleagues, and communities. Helping our clients identify and mitigate risks to a project’s physical, environmental, and economic well-being drives every decision we make. Offering career pathways and continuous learning betters outcomes for our employees. And offering highly personalized and customized services to address highly specialized problems, betters the communities where we live and work.
# Our Forensic services generate just outcomes.
# Our Compliance and Regulatory services generate safe and sustainable outcomes.
# Our Project Advisory services generate community-enhancing outcomes.
# VERTEX has over 700 experts who are ready to assist. Contact us today.
#
#     21 results found
