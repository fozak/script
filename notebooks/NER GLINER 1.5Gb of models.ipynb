# %%
# !pip install gliner
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -------------------- ------------------- 5.8/11.3 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 29.5 MB/s eta 0:00:00
# ...

# %%
from gliner import GLiNER

# Initialize GLiNER with the base model
model = GLiNER.from_pretrained("urchade/gliner_medium-v2.1")

# Sample text for entity prediction
text = """
SATURDAY WORKSHOPS

February 22
3-6pm
What will Jose be teaching us in this workshop?



This time, the workshops will be extremely interesting as he will cover the style and sequences of three MAESTROS of Tango: Tete Rusconi, Pupi Castello and Omar Vega, three great dancers who are no longer with us but have left a legacy that will continue forever



We were lucky in the past to have Omar Vega in Boston many times, but never had Tete or Pupi, so we are excited that Jose will be teaching us material from these maestros.

,

The workshops will cover these three milongueros masters, three different concepts, three ways to embrace, three rhythms ,three styles.

Combining figures to learn different ways to use the method



Because they are progressive, so it is suggested that you take the entire 3 hour workshop





If you have any questions about the weekend, please call Vicky at 617-721-4872





Part 1

3pm-4:30pm



break



Part 2

4:45pm-6:15pm





Because they are progressive, so it is suggested that you take the entire 3 hour workshop





	
Price:

﻿

This is a 3 hour workshop plus 15 minute break.



In advance: $70

At the door: $80



Registration page has a problem. Please pre-register as follows:



Venmo @danceunionstudio



Paypal danceunionstudio@gmail.com

SPECIAL: 

MILONGA FOR FRIDAY AND SATURDAY IS ONLY $10 IF YOU ATTEND THE

PRE-MILONGA CLASS OR THE WORKSHOP



 
__________________________________________________________________________



WEEKEND OF DANCING

FEBRUARY 21-22



'TANGO BAR' & 'LATE NIGHT

CAMBALACHE MILONGA'
"""

# Labels for entity prediction
# Most GLiNER models should work best when entity types are in lower case or title case
labels = ["Person", "Place", "Date", "Activity"]

# Perform entity prediction
entities = model.predict_entities(text, labels, threshold=0.5)

# Display predicted entities and their labels
for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# SATURDAY => Date
# February 22 => Date
# Jose => Person
# Tete Rusconi => Person
# Pupi Castello => Person
# Omar Vega => Person
# Omar Vega => Person
# Jose => Person
# Vicky => Person
# FEBRUARY 21-22 => Date
# TANGO BAR => Place
